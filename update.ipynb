# %%
from mergers import *
import pandas as pd
import numpy as np

# %%
# updating fpl_player.csv
previous_seasons = pd.read_csv('data/cleaned_merged_seasons.csv')
this_season = pd.read_csv('data/2022-23/gws/merged_gw.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11904\1293412315.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   previous_seasons = pd.read_csv('data/cleaned_merged_seasons.csv')

# %%
previous_seasons = previous_seasons[previous_seasons['team_x'].notnull()]
previous_seasons = previous_seasons.rename(columns = {
        'season_x': 'season',
        'team_x': 'team'
    })

# %%
previous_seasons
# Out:
#        Unnamed: 0   season                name position           team  \
# 49472       49472  2020-21      Aaron Connolly      FWD       Brighton
# 49473       49473  2020-21     Aaron Cresswell      DEF       West Ham
# 49474       49474  2020-21          Aaron Mooy      MID       Brighton
# 49475       49475  2020-21      Aaron Ramsdale       GK  Sheffield Utd
# 49476       49476  2020-21  Abdoulaye Doucouré      MID        Everton
# ...           ...      ...                 ...      ...            ...
# 98397       98397  2021-22       Wilfred Ndidi      MID      Leicester
# 98398       98398  2021-22        Matt Ritchie      DEF      Newcastle
# 98399       98399  2021-22      Nathan Redmond      MID    Southampton
# 98400       98400  2021-22         Mathew Ryan       GK       Brighton
# 98401       98401  2021-22     Ryan Fredericks      DEF       West Ham
#
#        assists  bonus  bps  clean_sheets  creativity  ...  team_h_score  \
# 49472        0      0   -3             0         0.3  ...           1.0
# 49473        0      0   11             0        11.2  ...           0.0
# 49474        0      0    0             0         0.0  ...           1.0
# 49475        0      0   12             0         0.0  ...           0.0
# 49476        0      0   20             1        44.6  ...           0.0
# ...        ...    ...  ...           ...         ...  ...           ...
# 98397        0      0    0             0         0.0  ...           4.0
# 98398        0      0    3             0         0.0  ...           1.0
# 98399        0      0    5             0         0.0  ...           4.0
# 98400        0      0    0             0         0.0  ...           3.0
# 98401        0      0    0             0         0.0  ...           3.0
#
#        threat  total_points  transfers_balance  transfers_in  transfers_out  \
# 49472    32.0             1                  0             0              0
# 49473     0.0             1                  0             0              0
# 49474     0.0             0                  0             0              0
# 49475     0.0             1                  0             0              0
# 49476     4.0             3                  0             0              0
# ...       ...           ...                ...           ...            ...
# 98397     0.0             0               -202            22            224
# 98398     0.0             1                143           396            253
# 98399     0.0             2                455           683            228
# 98400     0.0             0                 -2             0              2
# 98401     0.0             0                 36           103             67
#
#       value  was_home  yellow_cards  GW
# 49472    55      True             0   1
# 49473    50      True             0   1
# 49474    50      True             0   1
# 49475    50      True             0   1
# 49476    55     False             0   1
# ...     ...       ...           ...  ..
# 98397    48      True             0  38
# 98398    49     False             0  38
# 98399    59     False             0  38
# 98400    45      True             0  38
# 98401    44     False             0  38
#
# [48930 rows x 38 columns]

# %%
this_season
# Out:
#                   name position         team   xP  assists  bonus  bps  \
# 0       Nathan Redmond      MID  Southampton  1.5        0      0    3
# 1     Junior Stanislas      MID  Bournemouth  1.1        0      0    3
# 2        Armando Broja      FWD      Chelsea  2.0        0      0    3
# 3         Fabian Schär      DEF    Newcastle  2.4        0      3   43
# 4          Jonny Evans      DEF    Leicester  1.9        0      0   15
# ...                ...      ...          ...  ...      ...    ...  ...
# 4014         Nick Pope       GK    Newcastle  5.3        0      0   12
# 4015      Oliver Skipp      MID        Spurs  0.5        0      0    0
# 4016    Ryan Sessegnon      DEF        Spurs  2.3        0      0    7
# 4017      Ashley Young      DEF  Aston Villa  1.8        0      0   19
# 4018    Philip Billing      MID  Bournemouth  4.5        0      2   30
#
#       clean_sheets  creativity  element  ...  team_h_score  threat  \
# 0                0         0.0      403  ...             4     0.0
# 1                0         0.0       58  ...             2     0.0
# 2                0         0.3      150  ...             0    19.0
# 3                1        14.6      366  ...             2    25.0
# 4                0         1.3      249  ...             2     0.0
# ...            ...         ...      ...  ...           ...     ...
# 4014             0         0.0      376  ...             1     0.0
# 4015             0         0.0      441  ...             6     0.0
# 4016             0         2.4      436  ...             6     8.0
# 4017             1        19.7      538  ...             1     9.0
# 4018             0        21.8       70  ...             1    35.0
#
#       total_points  transfers_balance  transfers_in transfers_out  value  \
# 0                1                  0             0             0     55
# 1                1                  0             0             0     50
# 2                1                  0             0             0     55
# 3               15                  0             0             0     45
# 4                1                  0             0             0     45
# ...            ...                ...           ...           ...    ...
# 4014             2             624232        644512         20280     52
# 4015             0               -249           348           597     44
# 4016             1               1833          9157          7324     45
# 4017             5                654          1050           396     44
# 4018             9               1333          2105           772     53
#
#       was_home  yellow_cards  GW
# 0        False             0   1
# 1         True             0   1
# 2        False             0   1
# 3         True             0   1
# 4         True             0   1
# ...        ...           ...  ..
# 4014      True             0   8
# 4015      True             0   8
# 4016      True             0   8
# 4017      True             1   8
# 4018     False             0   8
#
# [4019 rows x 36 columns]

# %%
merged_seasons = pd.concat([previous_seasons, this_season])

# %%
merged_seasons
# Out:
#        Unnamed: 0   season                name position           team  \
# 49472     49472.0  2020-21      Aaron Connolly      FWD       Brighton
# 49473     49473.0  2020-21     Aaron Cresswell      DEF       West Ham
# 49474     49474.0  2020-21          Aaron Mooy      MID       Brighton
# 49475     49475.0  2020-21      Aaron Ramsdale       GK  Sheffield Utd
# 49476     49476.0  2020-21  Abdoulaye Doucouré      MID        Everton
# ...           ...      ...                 ...      ...            ...
# 4014          NaN      NaN           Nick Pope       GK      Newcastle
# 4015          NaN      NaN        Oliver Skipp      MID          Spurs
# 4016          NaN      NaN      Ryan Sessegnon      DEF          Spurs
# 4017          NaN      NaN        Ashley Young      DEF    Aston Villa
# 4018          NaN      NaN      Philip Billing      MID    Bournemouth
#
#        assists  bonus  bps  clean_sheets  creativity  ...  threat  \
# 49472        0      0   -3             0         0.3  ...    32.0
# 49473        0      0   11             0        11.2  ...     0.0
# 49474        0      0    0             0         0.0  ...     0.0
# 49475        0      0   12             0         0.0  ...     0.0
# 49476        0      0   20             1        44.6  ...     4.0
# ...        ...    ...  ...           ...         ...  ...     ...
# 4014         0      0   12             0         0.0  ...     0.0
# 4015         0      0    0             0         0.0  ...     0.0
# 4016         0      0    7             0         2.4  ...     8.0
# 4017         0      0   19             1        19.7  ...     9.0
# 4018         0      2   30             0        21.8  ...    35.0
#
#        total_points  transfers_balance  transfers_in  transfers_out  value  \
# 49472             1                  0             0              0     55
# 49473             1                  0             0              0     50
# 49474             0                  0             0              0     50
# 49475             1                  0             0              0     50
# 49476             3                  0             0              0     55
# ...             ...                ...           ...            ...    ...
# 4014              2             624232        644512          20280     52
# 4015              0               -249           348            597     44
# 4016              1               1833          9157           7324     45
# 4017              5                654          1050            396     44
# 4018              9               1333          2105            772     53
#
#       was_home  yellow_cards  GW   xP
# 49472     True             0   1  NaN
# 49473     True             0   1  NaN
# 49474     True             0   1  NaN
# 49475     True             0   1  NaN
# 49476    False             0   1  NaN
# ...        ...           ...  ..  ...
# 4014      True             0   8  5.3
# 4015      True             0   8  0.5
# 4016      True             0   8  2.3
# 4017      True             1   8  1.8
# 4018     False             0   8  4.5
#
# [52949 rows x 39 columns]

# %%
merged_seasons.to_csv('fpl_players.csv')
