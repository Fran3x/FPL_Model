# %% [markdown]
# # Imports

# %%
import os
os.chdir("D:\PulpitE\FPL_ML")

# %%
import pandas as pd
import numpy as np
from vaastav.getters import *

# %%
NEXT_GW = 25

# %%
fixtures = get_fixtures_data()

# %%
df_fixtures = pd.DataFrame(fixtures)

# %%
df_upcoming_fixtures = df_fixtures[df_fixtures["event"] >= NEXT_GW]

# %%
def team_id_to_name(team_id):
    teams = ['Arsenal',
     'Aston Villa',
     'Bournemouth',
     'Brentford',
     'Brighton',
     'Chelsea',
     'Crystal Palace',
     'Everton',
     'Fulham',
     'Leicester City',
     'Leeds United',
     'Liverpool',
     'Manchester City',
     'Manchester Utd',
     'Newcastle Utd',
     "Nott'ham Forest",
     'Southampton',
     'Tottenham',
     'West Ham',
     'Wolves']
    return teams[team_id - 1]

# %%
df_upcoming_fixtures["Squad H"] = df_upcoming_fixtures["team_h"].apply(team_id_to_name)
df_upcoming_fixtures["Squad A"] = df_upcoming_fixtures["team_a"].apply(team_id_to_name)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4928\3776683092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_upcoming_fixtures["Squad H"] = df_upcoming_fixtures["team_h"].apply(team_id_to_name)
# C:\Users\user\AppData\Local\Temp\ipykernel_4928\3776683092.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_upcoming_fixtures["Squad A"] = df_upcoming_fixtures["team_a"].apply(team_id_to_name)

# %%
df_upcoming_fixtures.rename(columns={"event": "gw"}, inplace=True)
# Out:
# C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_upcoming_fixtures
# Out:
#         code    gw  finished  finished_provisional   id          kickoff_time  \
# 232  2293053  25.0     False                 False  244  2023-02-24T20:00:00Z
# 233  2293052  25.0     False                 False  243  2023-02-25T15:00:00Z
# 234  2293054  25.0     False                 False  245  2023-02-25T15:00:00Z
# 235  2293055  25.0     False                 False  246  2023-02-25T15:00:00Z
# 236  2293059  25.0     False                 False  250  2023-02-25T15:00:00Z
# ..       ...   ...       ...                   ...  ...                   ...
# 375  2293185  38.0     False                 False  376  2023-05-28T15:30:00Z
# 376  2293186  38.0     False                 False  377  2023-05-28T15:30:00Z
# 377  2293187  38.0     False                 False  378  2023-05-28T15:30:00Z
# 378  2293188  38.0     False                 False  379  2023-05-28T15:30:00Z
# 379  2293189  38.0     False                 False  380  2023-05-28T15:30:00Z
#
#      minutes  provisional_start_time started  team_a  team_a_score  team_h  \
# 232        0                   False   False      20           NaN       9
# 233        0                   False   False       2           NaN       8
# 234        0                   False   False      17           NaN      11
# 235        0                   False   False       1           NaN      10
# 236        0                   False   False      16           NaN      19
# ..       ...                     ...     ...     ...           ...     ...
# 375        0                   False   False       3           NaN       8
# 376        0                   False   False      18           NaN      11
# 377        0                   False   False      19           NaN      10
# 378        0                   False   False       9           NaN      14
# 379        0                   False   False      12           NaN      17
#
#      team_h_score stats  team_h_difficulty  team_a_difficulty  pulse_id  \
# 232           NaN    []                  2                  2     75154
# 233           NaN    []                  2                  2     75153
# 234           NaN    []                  2                  2     75155
# 235           NaN    []                  4                  3     75156
# 236           NaN    []                  2                  3     75160
# ..            ...   ...                ...                ...       ...
# 375           NaN    []                  2                  2     75286
# 376           NaN    []                  3                  2     75287
# 377           NaN    []                  2                  3     75288
# 378           NaN    []                  2                  4     75289
# 379           NaN    []                  4                  2     75290
#
#             Squad H          Squad A
# 232          Fulham           Wolves
# 233         Everton      Aston Villa
# 234    Leeds United      Southampton
# 235  Leicester City          Arsenal
# 236        West Ham  Nott'ham Forest
# ..              ...              ...
# 375         Everton      Bournemouth
# 376    Leeds United        Tottenham
# 377  Leicester City         West Ham
# 378  Manchester Utd           Fulham
# 379     Southampton        Liverpool
#
# [148 rows x 19 columns]

# %%
df_upcoming_fixtures = df_upcoming_fixtures[["gw", "kickoff_time", "Squad H", "Squad A"]]

# %%
df_upcoming_fixtures.head(15)
# Out:
#        gw          kickoff_time          Squad H          Squad A
# 232  25.0  2023-02-24T20:00:00Z           Fulham           Wolves
# 233  25.0  2023-02-25T15:00:00Z          Everton      Aston Villa
# 234  25.0  2023-02-25T15:00:00Z     Leeds United      Southampton
# 235  25.0  2023-02-25T15:00:00Z   Leicester City          Arsenal
# 236  25.0  2023-02-25T15:00:00Z         West Ham  Nott'ham Forest
# 237  25.0  2023-02-25T17:30:00Z      Bournemouth  Manchester City
# 238  25.0  2023-02-25T19:45:00Z   Crystal Palace        Liverpool
# 239  25.0  2023-02-26T13:30:00Z        Tottenham          Chelsea
# 240  25.0  2023-03-01T19:45:00Z          Arsenal          Everton
# 241  25.0  2023-03-01T20:00:00Z        Liverpool           Wolves
# 242  26.0  2023-03-04T12:30:00Z  Manchester City    Newcastle Utd
# 243  26.0  2023-03-04T15:00:00Z          Arsenal      Bournemouth
# 244  26.0  2023-03-04T15:00:00Z      Aston Villa   Crystal Palace
# 245  26.0  2023-03-04T15:00:00Z         Brighton         West Ham
# 246  26.0  2023-03-04T15:00:00Z          Chelsea     Leeds United

# %%
# fixtures in sample
FIS = 8

CURRENT_SEASON = '2022-23'

# %%
def get_active_players():
    previous_fixtures = pd.read_csv("data/final_dataset.csv")
    name_counts = previous_fixtures.groupby('Name').size()
    filtered_names = name_counts[name_counts >= FIS].index
    result = previous_fixtures[previous_fixtures['Name'].isin(filtered_names)].groupby('Name').tail(1)
    result = result.loc[:, ~result.columns.str.contains('^Unnamed')]
    return result

# %%
active_players = get_active_players()

# %%
active_players[["Name", "Squad"]]
# Out:
#                      Name         Squad
# 18       Brenden-Aaronson  Leeds United
# 38              Che-Adams   Southampton
# 55            Tyler-Adams  Leeds United
# 76       Tosin-Adarabioyo        Fulham
# 101       Rayan-Ait-Nouri        Wolves
# ...                   ...           ...
# 7392        Jordan-Zemura   Bournemouth
# 7404  Oleksandr-Zinchenko       Arsenal
# 7422         Hakim-Ziyech       Chelsea
# 7438           Kurt-Zouma      West Ham
# 7456      Martin-Odegaard       Arsenal
#
# [434 rows x 2 columns]

# %%
picked_columns = ["Name", "gw", "kickoff_time", "Squad", "Squad H", "Squad A", "Was Home"]

# %%
upcoming_player_fixtures_home = active_players.rename(columns={"Squad": "Squad H"}).set_index("Squad H").join(df_upcoming_fixtures.set_index("Squad H")).reset_index(level=0)
upcoming_player_fixtures_home["Squad"] = upcoming_player_fixtures_home["Squad H"]
upcoming_player_fixtures_home["Was Home"] = True
upcoming_player_fixtures_home = upcoming_player_fixtures_home[picked_columns]

# %%
upcoming_player_fixtures_away = active_players.rename(columns={"Squad": "Squad A"}).set_index("Squad A").join(df_upcoming_fixtures.set_index("Squad A")).reset_index(level=0)
upcoming_player_fixtures_away["Squad"] = upcoming_player_fixtures_away["Squad A"]
upcoming_player_fixtures_away["Was Home"] = False
upcoming_player_fixtures_away = upcoming_player_fixtures_away[picked_columns]

# %%
upcoming_player_fixtures = pd.concat([upcoming_player_fixtures_home, upcoming_player_fixtures_away]).sort_values(by=["Name", "gw"])

# %%
upcoming_player_fixtures["Season"] = CURRENT_SEASON

# %%
upcoming_player_fixtures[upcoming_player_fixtures["Name"] == "Gabriel-Dos-Santos"]
# Out:
#                  Name    gw          kickoff_time    Squad          Squad H  \
# 0  Gabriel-Dos-Santos  25.0  2023-03-01T19:45:00Z  Arsenal          Arsenal
# 0  Gabriel-Dos-Santos  25.0  2023-02-25T15:00:00Z  Arsenal   Leicester City
# 1  Gabriel-Dos-Santos  26.0  2023-03-04T15:00:00Z  Arsenal          Arsenal
# 1  Gabriel-Dos-Santos  27.0  2023-03-12T14:00:00Z  Arsenal           Fulham
# 2  Gabriel-Dos-Santos  28.0  2023-03-19T14:00:00Z  Arsenal          Arsenal
# 3  Gabriel-Dos-Santos  29.0  2023-04-01T14:00:00Z  Arsenal          Arsenal
# 2  Gabriel-Dos-Santos  30.0  2023-04-09T15:30:00Z  Arsenal        Liverpool
# 3  Gabriel-Dos-Santos  31.0  2023-04-16T13:00:00Z  Arsenal         West Ham
# 4  Gabriel-Dos-Santos  32.0  2023-04-21T19:00:00Z  Arsenal          Arsenal
# 4  Gabriel-Dos-Santos  33.0  2023-04-26T19:00:00Z  Arsenal  Manchester City
# 5  Gabriel-Dos-Santos  34.0  2023-04-29T16:30:00Z  Arsenal          Arsenal
# 5  Gabriel-Dos-Santos  35.0  2023-05-06T14:00:00Z  Arsenal    Newcastle Utd
# 6  Gabriel-Dos-Santos  36.0  2023-05-13T14:00:00Z  Arsenal          Arsenal
# 6  Gabriel-Dos-Santos  37.0  2023-05-20T14:00:00Z  Arsenal  Nott'ham Forest
# 7  Gabriel-Dos-Santos  38.0  2023-05-28T15:30:00Z  Arsenal          Arsenal
#
#           Squad A  Was Home   Season
# 0         Everton      True  2022-23
# 0         Arsenal     False  2022-23
# 1     Bournemouth      True  2022-23
# 1         Arsenal     False  2022-23
# 2  Crystal Palace      True  2022-23
# 3    Leeds United      True  2022-23
# 2         Arsenal     False  2022-23
# 3         Arsenal     False  2022-23
# 4     Southampton      True  2022-23
# 4         Arsenal     False  2022-23
# 5         Chelsea      True  2022-23
# 5         Arsenal     False  2022-23
# 6        Brighton      True  2022-23
# 6         Arsenal     False  2022-23
# 7          Wolves      True  2022-23

# %%
upcoming_player_fixtures.shape
# Out:
# (6422, 8)
