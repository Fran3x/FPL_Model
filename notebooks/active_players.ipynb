# %%
import os
os.chdir("D:\PulpitE\FPL_ML")

# %%
import pandas as pd
from vaastav import getters

# %%
elements = pd.DataFrame(getters.get_data()["elements"])
elements.shape
# Out:
# (644, 88)

# %%
elements.columns
# Out:
# Index(['chance_of_playing_next_round', 'chance_of_playing_this_round', 'code',
#        'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
#        'cost_change_start_fall', 'dreamteam_count', 'element_type', 'ep_next',
#        'ep_this', 'event_points', 'first_name', 'form', 'id', 'in_dreamteam',
#        'news', 'news_added', 'now_cost', 'photo', 'points_per_game',
#        'second_name', 'selected_by_percent', 'special', 'squad_number',
#        'status', 'team', 'team_code', 'total_points', 'transfers_in',
#        'transfers_in_event', 'transfers_out', 'transfers_out_event',
#        'value_form', 'value_season', 'web_name', 'minutes', 'goals_scored',
#        'assists', 'clean_sheets', 'goals_conceded', 'own_goals',
#        'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards',
#        'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat',
#        'ict_index', 'starts', 'expected_goals', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals_conceded',
#        'influence_rank', 'influence_rank_type', 'creativity_rank',
#        'creativity_rank_type', 'threat_rank', 'threat_rank_type',
#        'ict_index_rank', 'ict_index_rank_type',
#        'corners_and_indirect_freekicks_order',
#        'corners_and_indirect_freekicks_text', 'direct_freekicks_order',
#        'direct_freekicks_text', 'penalties_order', 'penalties_text',
#        'expected_goals_per_90', 'saves_per_90', 'expected_assists_per_90',
#        'expected_goal_involvements_per_90', 'expected_goals_conceded_per_90',
#        'goals_conceded_per_90', 'now_cost_rank', 'now_cost_rank_type',
#        'form_rank', 'form_rank_type', 'points_per_game_rank',
#        'points_per_game_rank_type', 'selected_rank', 'selected_rank_type',
#        'starts_per_90', 'clean_sheets_per_90'],
#       dtype='object')

# %%
current_teams = [
        'Arsenal',
        'Aston Villa',
        'Bournemouth',
        'Brentford',
        'Brighton',
        'Burnley',
        'Chelsea',
        'Crystal Palace',
        'Everton',
        'Fulham',
        'Liverpool',
        'Luton',
        'Manchester City',
        'Manchester Utd',
        'Newcastle Utd',
        "Nott'ham Forest",
        'Sheffield United',
        'Tottenham',
        'West Ham',
        'Wolves'
    ]

# %%
# 2023-24 season
def team_id_to_name(current_teams, team_id):
    return current_teams[team_id - 1]

# %%
elements["team"] = elements["team"].apply(lambda x: team_id_to_name(current_teams, x))
elements["name"] = elements["first_name"] + " " + elements["second_name"]

# %%
elements[~elements["chance_of_playing_this_round"].isna()][["chance_of_playing_next_round", "name", "team"]].head(80).tail(40)
# Out:
#      chance_of_playing_next_round                            name  \
# 154                           0.0                  Kjell Scherpen
# 156                           0.0                     Deniz Undav
# 160                          75.0                    Adam Webster
# 180                           0.0                    Luke McNally
# 183                           0.0                 Michael Obafemi
# 184                           0.0          Bailey Peacock-Farrell
# 188                           0.0                    Bobby Thomas
# 192                           0.0                   Wout Weghorst
# 202                           0.0                    Ethan Ampadu
# 205                           0.0       Pierre-Emerick Aubameyang
# 206                           0.0               César Azpilicueta
# 207                           0.0               Abdul Rahman Baba
# 208                           0.0               Benoît Badiashile
# 209                           0.0               Marcus Bettinelli
# 210                           0.0                   Armando Broja
# 211                           0.0                 Trevoh Chalobah
# 217                           0.0              David Datro Fofana
# 218                           0.0                   Wesley Fofana
# 225                          75.0                    Noni Madueke
# 228                           0.0              Christopher Nkunku
# 229                           0.0               Christian Pulisic
# 231                           0.0                 Gabriel Słonina
# 235                           0.0  Ângelo Gabriel Borges Damaceno
# 244                          75.0                 Cheick Doucouré
# 250                           0.0                     Will Hughes
# 255                         100.0                 Tyrick Mitchell
# 257                           0.0                   Michael Olise
# 258                           0.0                     Luke Plange
# 265                           0.0      Matheus França de Oliveira
# 268                          75.0           Dominic Calvert-Lewin
# 269                           0.0                  Seamus Coleman
# 270                           0.0                       Dele Alli
# 281                           0.0                   Dwight McNeil
# 286                           0.0                     Ellis Simms
# 287                         100.0                 James Tarkowski
# 291                          75.0       Arnaut Danjuma Groeneveld
# 294                          75.0      Andreas Hoelgebaum Pereira
# 295                          75.0                     Tom Cairney
# 296                           0.0      Ivan Neves Abreu Cavaleiro
# 307                           0.0         João Palhinha Gonçalves
#
#                team
# 154        Brighton
# 156        Brighton
# 160        Brighton
# 180         Burnley
# 183         Burnley
# 184         Burnley
# 188         Burnley
# 192         Burnley
# 202         Chelsea
# 205         Chelsea
# 206         Chelsea
# 207         Chelsea
# 208         Chelsea
# 209         Chelsea
# 210         Chelsea
# 211         Chelsea
# 217         Chelsea
# 218         Chelsea
# 225         Chelsea
# 228         Chelsea
# 229         Chelsea
# 231         Chelsea
# 235         Chelsea
# 244  Crystal Palace
# 250  Crystal Palace
# 255  Crystal Palace
# 257  Crystal Palace
# 258  Crystal Palace
# 265  Crystal Palace
# 268         Everton
# 269         Everton
# 270         Everton
# 281         Everton
# 286         Everton
# 287         Everton
# 291         Everton
# 294          Fulham
# 295          Fulham
# 296          Fulham
# 307          Fulham

# %%
elements.to_csv("data/active_players.csv")
