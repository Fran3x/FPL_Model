# %%
import os
os.chdir("D:\PulpitE\FPL_ML")

# %%
import pandas as pd
from datetime import datetime

# %%
team_ratings = pd.read_csv("data/team_ratings_history.csv")

# %%
team_ratings
# Out:
#         Unnamed: 0  Rank     Club Country  Level          Elo        From  \
# 0                0  None  Arsenal     ENG      1  1551.140259  1946-07-07
# 1                1  None  Arsenal     ENG      1  1539.570068  1946-09-01
# 2                2  None  Arsenal     ENG      1  1525.449463  1946-09-05
# 3                3  None  Arsenal     ENG      1  1523.855591  1946-09-08
# 4                4  None  Arsenal     ENG      1  1518.939331  1946-09-12
# ...            ...   ...      ...     ...    ...          ...         ...
# 119848        3750  None  Watford     ENG      2  1561.605835  2023-01-03
# 119849        3751  None  Watford     ENG      2  1567.879761  2023-01-15
# 119850        3752  None  Watford     ENG      2  1563.442261  2023-01-22
# 119851        3753  None  Watford     ENG      2  1563.442261  2023-01-29
# 119852        3754  None  Watford     ENG      2  1563.442261  2023-02-23
#
#                 To
# 0       1946-08-31
# 1       1946-09-04
# 2       1946-09-07
# 3       1946-09-11
# 4       1946-09-14
# ...            ...
# 119848  2023-01-14
# 119849  2023-01-21
# 119850  2023-01-28
# 119851  2023-02-22
# 119852  2023-12-31
#
# [119853 rows x 8 columns]

# %%
# function to assign rating for team
def get_rating_for_team(team_ratings, team_name, date):
    rating = None
    try:
        rating = team_ratings[(team_ratings['From'] <= date.strftime("%Y-%m-%d")) & (team_ratings['Club'] == team_name)].iloc[-1]['Elo']
    except:
        print(team_name, date)
    return rating

# %%
def fbref_to_team_elo(team_name):
    # changes name of a team
    if team_name == "Leicester City":
        return "Leicester"
    if team_name == "Manchester City":
        return "Man City"
    if team_name == "Manchester Utd":
        return "Man United"
    if team_name == "Newcastle Utd":
        return "Newcastle"
    if team_name == "Nott'ham Forest":
        return "Forest"
    if team_name == "Leeds United":
        return "Leeds"
    return team_name

# %%
df = pd.read_csv("data/fpl_fbref_players.csv")

# %%
df.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1        Date  Day            Comp         Round  \
# 0            0             1  2022-08-06  Sat  Premier League   Matchweek 1
# 1            1             2  2022-08-15  Mon  Premier League   Matchweek 2
# 2            2             3  2022-08-22  Mon  Premier League   Matchweek 3
# 3            3             4  2022-08-27  Sat  Premier League   Matchweek 4
# 4            4             5  2022-08-31  Wed  Premier League   Matchweek 5
# 5            5             6  2022-09-03  Sat  Premier League   Matchweek 6
# 6            6            11  2022-10-01  Sat  Premier League   Matchweek 9
# 7            7            13  2022-10-09  Sun  Premier League  Matchweek 10
# 8            8            15  2022-10-16  Sun  Premier League  Matchweek 11
# 9            9            16  2022-10-19  Wed  Premier League  Matchweek 12
# 10          10            17  2022-10-22  Sat  Premier League  Matchweek 13
# 11          11            19  2022-10-29  Sat  Premier League  Matchweek 14
# 12          12            21  2022-11-06  Sun  Premier League  Matchweek 15
# 13          13            23  2022-11-12  Sat  Premier League  Matchweek 16
# 14          14            26  2022-12-26  Mon  Premier League  Matchweek 17
# 15          15            27  2022-12-30  Fri  Premier League  Matchweek 18
# 16          16            28  2023-01-02  Mon  Premier League  Matchweek 19
# 17          17            30  2023-01-14  Sat  Premier League  Matchweek 20
# 18          18            32  2023-01-21  Sat  Premier League  Matchweek 21
#
#    Venue      Squad         Opponent Start  ... GoalsTeams  Team Score  \
# 0   Away  Liverpool           Fulham     Y  ...        2–2           2
# 1   Home  Liverpool   Crystal Palace     Y  ...        1–1           1
# 2   Away  Liverpool   Manchester Utd     Y  ...        1–2           1
# 3   Home  Liverpool      Bournemouth     Y  ...        9–0           9
# 4   Home  Liverpool    Newcastle Utd     Y  ...        2–1           2
# 5   Away  Liverpool          Everton     Y  ...        0–0           0
# 6   Home  Liverpool         Brighton     Y  ...        3–3           3
# 7   Away  Liverpool          Arsenal     Y  ...        2–3           2
# 8   Home  Liverpool  Manchester City     Y  ...        1–0           1
# 9   Home  Liverpool         West Ham     Y  ...        1–0           1
# 10  Away  Liverpool  Nott'ham Forest     Y  ...        0–1           0
# 11  Home  Liverpool     Leeds United     Y  ...        1–2           1
# 12  Away  Liverpool        Tottenham     Y  ...        2–1           2
# 13  Home  Liverpool      Southampton     Y  ...        3–1           3
# 14  Away  Liverpool      Aston Villa     Y  ...        3–1           3
# 15  Home  Liverpool   Leicester City     Y  ...        2–1           2
# 16  Away  Liverpool        Brentford     Y  ...        1–3           1
# 17  Away  Liverpool         Brighton     Y  ...        0–3           0
# 18  Home  Liverpool          Chelsea     Y  ...        0–0           0
#
#     Opp Score   CS  Was Home  GW   FPL   neutral_name  Total Points  \
# 0           2  0.0       0.0   1   7.0  Mohamed-Salah          12.0
# 1           1  0.0       1.0   2   2.0  Mohamed-Salah           2.0
# 2           2  0.0       0.0   3   7.0  Mohamed-Salah           NaN
# 3           0  1.0       1.0   4   3.0  Mohamed-Salah           NaN
# 4           1  0.0       1.0   5   8.0  Mohamed-Salah           NaN
# 5           0  1.0       0.0   6   3.0  Mohamed-Salah           NaN
# 6           3  0.0       1.0   9   5.0  Mohamed-Salah           NaN
# 7           3  0.0       0.0  10   2.0  Mohamed-Salah           NaN
# 8           0  1.0       1.0  11   8.0  Mohamed-Salah           NaN
# 9           0  1.0       1.0  12   3.0  Mohamed-Salah           NaN
# 10          1  0.0       0.0  13   2.0  Mohamed-Salah           NaN
# 11          2  0.0       1.0  14   7.0  Mohamed-Salah           NaN
# 12          1  0.0       0.0  15  12.0  Mohamed-Salah           NaN
# 13          1  0.0       1.0  16   2.0  Mohamed-Salah           NaN
# 14          1  0.0       0.0  17  10.0  Mohamed-Salah           NaN
# 15          1  0.0       1.0  18   2.0  Mohamed-Salah           NaN
# 16          3  0.0       0.0  19   2.0  Mohamed-Salah           NaN
# 17          3  0.0       0.0  20   2.0  Mohamed-Salah           NaN
# 18          0  1.0       1.0  21   3.0  Mohamed-Salah           NaN
#
#     FPL position
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
#
# [19 rows x 51 columns]

# %%
df.head().columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Date', 'Day', 'Comp', 'Round', 'Venue',
#        'Squad', 'Opponent', 'Start', 'Pos', 'Min', 'Gls', 'Ast', 'PK', 'PKatt',
#        'Sh', 'SoT', 'CrdY', 'CrdR', 'Touches', 'Tkl', 'Int', 'Blocks', 'xG',
#        'npxG', 'xAG', 'SCA', 'GCA', 'Cmp', 'Att', 'Cmp%', 'PrgP', 'Carries',
#        'PrgC', 'Att.1', 'Succ', 'Match Report', 'Name', 'Season', 'WDL',
#        'GoalsTeams', 'Team Score', 'Opp Score', 'CS', 'Was Home', 'GW', 'FPL',
#        'neutral_name', 'Total Points', 'FPL position'],
#       dtype='object')

# %%
# %%time
df["Opp rating"] = df.apply(lambda row : get_rating_for_team(team_ratings,
                     fbref_to_team_elo(row['Opponent']), datetime.strptime(row['Date'], '%Y-%m-%d')), axis=1)
# Out:
# CPU times: total: 234 ms
# Wall time: 264 ms

# %%
df.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1        Date  Day            Comp         Round  \
# 0            0             1  2022-08-06  Sat  Premier League   Matchweek 1
# 1            1             2  2022-08-15  Mon  Premier League   Matchweek 2
# 2            2             3  2022-08-22  Mon  Premier League   Matchweek 3
# 3            3             4  2022-08-27  Sat  Premier League   Matchweek 4
# 4            4             5  2022-08-31  Wed  Premier League   Matchweek 5
# 5            5             6  2022-09-03  Sat  Premier League   Matchweek 6
# 6            6            11  2022-10-01  Sat  Premier League   Matchweek 9
# 7            7            13  2022-10-09  Sun  Premier League  Matchweek 10
# 8            8            15  2022-10-16  Sun  Premier League  Matchweek 11
# 9            9            16  2022-10-19  Wed  Premier League  Matchweek 12
# 10          10            17  2022-10-22  Sat  Premier League  Matchweek 13
# 11          11            19  2022-10-29  Sat  Premier League  Matchweek 14
# 12          12            21  2022-11-06  Sun  Premier League  Matchweek 15
# 13          13            23  2022-11-12  Sat  Premier League  Matchweek 16
# 14          14            26  2022-12-26  Mon  Premier League  Matchweek 17
# 15          15            27  2022-12-30  Fri  Premier League  Matchweek 18
# 16          16            28  2023-01-02  Mon  Premier League  Matchweek 19
# 17          17            30  2023-01-14  Sat  Premier League  Matchweek 20
# 18          18            32  2023-01-21  Sat  Premier League  Matchweek 21
#
#    Venue      Squad         Opponent Start  ... Team Score  Opp Score   CS  \
# 0   Away  Liverpool           Fulham     Y  ...          2          2  0.0
# 1   Home  Liverpool   Crystal Palace     Y  ...          1          1  0.0
# 2   Away  Liverpool   Manchester Utd     Y  ...          1          2  0.0
# 3   Home  Liverpool      Bournemouth     Y  ...          9          0  1.0
# 4   Home  Liverpool    Newcastle Utd     Y  ...          2          1  0.0
# 5   Away  Liverpool          Everton     Y  ...          0          0  1.0
# 6   Home  Liverpool         Brighton     Y  ...          3          3  0.0
# 7   Away  Liverpool          Arsenal     Y  ...          2          3  0.0
# 8   Home  Liverpool  Manchester City     Y  ...          1          0  1.0
# 9   Home  Liverpool         West Ham     Y  ...          1          0  1.0
# 10  Away  Liverpool  Nott'ham Forest     Y  ...          0          1  0.0
# 11  Home  Liverpool     Leeds United     Y  ...          1          2  0.0
# 12  Away  Liverpool        Tottenham     Y  ...          2          1  0.0
# 13  Home  Liverpool      Southampton     Y  ...          3          1  0.0
# 14  Away  Liverpool      Aston Villa     Y  ...          3          1  0.0
# 15  Home  Liverpool   Leicester City     Y  ...          2          1  0.0
# 16  Away  Liverpool        Brentford     Y  ...          1          3  0.0
# 17  Away  Liverpool         Brighton     Y  ...          0          3  0.0
# 18  Home  Liverpool          Chelsea     Y  ...          0          0  1.0
#
#     Was Home  GW   FPL   neutral_name  Total Points  FPL position   Opp rating
# 0        0.0   1   7.0  Mohamed-Salah          12.0           NaN  1636.164673
# 1        1.0   2   2.0  Mohamed-Salah           2.0           NaN  1744.510620
# 2        0.0   3   7.0  Mohamed-Salah           NaN           NaN  1782.548950
# 3        1.0   4   3.0  Mohamed-Salah           NaN           NaN  1636.085083
# 4        1.0   5   8.0  Mohamed-Salah           NaN           NaN  1770.085205
# 5        0.0   6   3.0  Mohamed-Salah           NaN           NaN  1691.464355
# 6        1.0   9   5.0  Mohamed-Salah           NaN           NaN  1779.398682
# 7        0.0  10   2.0  Mohamed-Salah           NaN           NaN  1890.421753
# 8        1.0  11   8.0  Mohamed-Salah           NaN           NaN  2042.070801
# 9        1.0  12   3.0  Mohamed-Salah           NaN           NaN  1781.722046
# 10       0.0  13   2.0  Mohamed-Salah           NaN           NaN  1599.286377
# 11       1.0  14   7.0  Mohamed-Salah           NaN           NaN  1685.329956
# 12       0.0  15  12.0  Mohamed-Salah           NaN           NaN  1879.251709
# 13       1.0  16   2.0  Mohamed-Salah           NaN           NaN  1674.645264
# 14       0.0  17  10.0  Mohamed-Salah           NaN           NaN  1744.407715
# 15       1.0  18   2.0  Mohamed-Salah           NaN           NaN  1772.712280
# 16       0.0  19   2.0  Mohamed-Salah           NaN           NaN  1755.423828
# 17       0.0  20   2.0  Mohamed-Salah           NaN           NaN  1802.947266
# 18       1.0  21   3.0  Mohamed-Salah           NaN           NaN  1867.052368
#
# [19 rows x 52 columns]

# %%
df.to_csv("data/fpl_fbref_elo_players.csv")
