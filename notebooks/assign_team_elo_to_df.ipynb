# %%
import os
os.chdir("D:\PulpitE\FPL_ML")

# %%
import pandas as pd
from datetime import datetime

# %%
team_ratings = pd.read_csv("data/team_ratings_history.csv")

# %%
team_ratings
# Out:
#         Unnamed: 0  Rank     Club Country  Level          Elo        From  \
# 0                0  None  Arsenal     ENG      1  1551.140259  1946-07-07
# 1                1  None  Arsenal     ENG      1  1539.570068  1946-09-01
# 2                2  None  Arsenal     ENG      1  1525.449463  1946-09-05
# 3                3  None  Arsenal     ENG      1  1523.855591  1946-09-08
# 4                4  None  Arsenal     ENG      1  1518.939331  1946-09-12
# ...            ...   ...      ...     ...    ...          ...         ...
# 119848        3750  None  Watford     ENG      2  1561.605835  2023-01-03
# 119849        3751  None  Watford     ENG      2  1567.879761  2023-01-15
# 119850        3752  None  Watford     ENG      2  1563.442261  2023-01-22
# 119851        3753  None  Watford     ENG      2  1563.442261  2023-01-29
# 119852        3754  None  Watford     ENG      2  1563.442261  2023-02-23
#
#                 To
# 0       1946-08-31
# 1       1946-09-04
# 2       1946-09-07
# 3       1946-09-11
# 4       1946-09-14
# ...            ...
# 119848  2023-01-14
# 119849  2023-01-21
# 119850  2023-01-28
# 119851  2023-02-22
# 119852  2023-12-31
#
# [119853 rows x 8 columns]

# %%
# function to assign rating for team
def get_rating_for_team(team_ratings, team_name, date):
    rating = None
    try:
        rating = team_ratings[(team_ratings['From'] <= date.strftime("%Y-%m-%d")) & (team_ratings['Club'] == team_name)].iloc[-1]['Elo']
    except:
        print(team_name, date)
    return rating

# %%
def fbref_to_team_elo(team_name):
    # changes name of a team
    if team_name == "Leicester City":
        return "Leicester"
    if team_name == "Manchester City":
        return "Man City"
    if team_name == "Manchester Utd":
        return "Man United"
    if team_name == "Newcastle Utd":
        return "Newcastle"
    if team_name == "Nott'ham Forest":
        return "Forest"
    if team_name == "Leeds United":
        return "Leeds"
    return team_name

# %%
df = pd.read_csv("data/fpl_fbref_players.csv")

# %%
df.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1        Date  Day            Comp         Round  \
# 0            0             0  2022-08-06  Sat  Premier League   Matchweek 1
# 1            1             1  2022-08-13  Sat  Premier League   Matchweek 2
# 2            2             2  2022-08-21  Sun  Premier League   Matchweek 3
# 3            3             4  2022-08-27  Sat  Premier League   Matchweek 4
# 4            4             5  2022-08-30  Tue  Premier League   Matchweek 5
# 5            5             6  2022-09-03  Sat  Premier League   Matchweek 6
# 6            6             9  2022-10-02  Sun  Premier League   Matchweek 9
# 7            7            10  2022-10-09  Sun  Premier League  Matchweek 10
# 8            8            11  2022-10-16  Sun  Premier League  Matchweek 11
# 9            9            12  2022-10-20  Thu  Premier League  Matchweek 12
# 10          10            13  2022-10-23  Sun  Premier League  Matchweek 13
# 11          11            14  2022-10-29  Sat  Premier League  Matchweek 14
# 12          12            15  2022-11-05  Sat  Premier League  Matchweek 15
# 13          13            17  2022-11-12  Sat  Premier League  Matchweek 16
# 14          14            22  2022-12-28  Wed  Premier League  Matchweek 17
# 15          15            23  2022-12-31  Sat  Premier League  Matchweek 18
# 16          16            24  2023-01-04  Wed  Premier League  Matchweek 19
# 17          17            26  2023-01-13  Fri  Premier League  Matchweek 20
# 18          18            28  2023-01-22  Sun  Premier League  Matchweek 21
# 19          19             3  2022-08-06  Sat  Premier League   Matchweek 1
#
#    Venue         Squad         Opponent Start  ... GoalsTeams  Team Score  \
# 0   Home  Leeds United           Wolves     Y  ...        2–1           2
# 1   Away  Leeds United      Southampton     Y  ...        2–2           2
# 2   Home  Leeds United          Chelsea     Y  ...        3–0           3
# 3   Away  Leeds United         Brighton     Y  ...        0–1           0
# 4   Home  Leeds United          Everton     Y  ...        1–1           1
# 5   Away  Leeds United        Brentford     Y  ...        2–5           2
# 6   Home  Leeds United      Aston Villa     Y  ...        0–0           0
# 7   Away  Leeds United   Crystal Palace     Y  ...        1–2           1
# 8   Home  Leeds United          Arsenal     Y  ...        0–1           0
# 9   Away  Leeds United   Leicester City     Y  ...        0–2           0
# 10  Home  Leeds United           Fulham     Y  ...        2–3           2
# 11  Away  Leeds United        Liverpool     Y  ...        2–1           2
# 12  Home  Leeds United      Bournemouth     Y  ...        4–3           4
# 13  Away  Leeds United        Tottenham     Y  ...        3–4           3
# 14  Home  Leeds United  Manchester City     Y  ...        1–3           1
# 15  Away  Leeds United    Newcastle Utd     Y  ...        0–0           0
# 16  Home  Leeds United         West Ham     Y  ...        2–2           2
# 17  Away  Leeds United      Aston Villa     Y  ...        1–2           1
# 18  Home  Leeds United        Brentford     Y  ...        0–0           0
# 19  Away   Southampton        Tottenham     N  ...        1–4           1
#
#     Opp Score   CS  Was Home  GW  FPL      neutral_name  Total Points  \
# 0           1  0.0       1.0   1  2.0  Brenden-Aaronson           2.0
# 1           2  0.0       0.0   2  2.0  Brenden-Aaronson           1.0
# 2           0  1.0       1.0   3  8.0  Brenden-Aaronson           8.0
# 3           1  0.0       0.0   4  2.0  Brenden-Aaronson           1.0
# 4           1  0.0       1.0   5  5.0  Brenden-Aaronson           5.0
# 5           5  0.0       0.0   6  2.0  Brenden-Aaronson           2.0
# 6           0  1.0       1.0   9  3.0  Brenden-Aaronson           3.0
# 7           2  0.0       0.0  10  2.0  Brenden-Aaronson           5.0
# 8           1  0.0       1.0  11  2.0  Brenden-Aaronson           2.0
# 9           2  0.0       0.0  12  2.0  Brenden-Aaronson           2.0
# 10          3  0.0       1.0  13  2.0  Brenden-Aaronson           2.0
# 11          1  0.0       0.0  14  2.0  Brenden-Aaronson           2.0
# 12          3  0.0       1.0  15  2.0  Brenden-Aaronson           2.0
# 13          4  0.0       0.0  16  5.0  Brenden-Aaronson           5.0
# 14          3  0.0       1.0  17  2.0  Brenden-Aaronson           2.0
# 15          0  1.0       0.0  18  3.0  Brenden-Aaronson           3.0
# 16          2  0.0       1.0  19  2.0  Brenden-Aaronson           2.0
# 17          2  0.0       0.0  20  2.0  Brenden-Aaronson           2.0
# 18          0  1.0       1.0  21  3.0  Brenden-Aaronson           3.0
# 19          4  0.0       0.0   1  1.0         Che-Adams           0.0
#
#     FPL position
# 0            MID
# 1            MID
# 2            MID
# 3            MID
# 4            MID
# 5            MID
# 6            MID
# 7            MID
# 8            MID
# 9            MID
# 10           MID
# 11           MID
# 12           MID
# 13           MID
# 14           MID
# 15           MID
# 16           MID
# 17           MID
# 18           MID
# 19           FWD
#
# [20 rows x 51 columns]

# %%
df.head().columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Date', 'Day', 'Comp', 'Round', 'Venue',
#        'Squad', 'Opponent', 'Start', 'Pos', 'Min', 'Gls', 'Ast', 'PK', 'PKatt',
#        'Sh', 'SoT', 'CrdY', 'CrdR', 'Touches', 'Tkl', 'Int', 'Blocks', 'xG',
#        'npxG', 'xAG', 'SCA', 'GCA', 'Cmp', 'Att', 'Cmp%', 'PrgP', 'Carries',
#        'PrgC', 'Att.1', 'Succ', 'Match Report', 'Name', 'Season', 'WDL',
#        'GoalsTeams', 'Team Score', 'Opp Score', 'CS', 'Was Home', 'GW', 'FPL',
#        'neutral_name', 'Total Points', 'FPL position'],
#       dtype='object')

# %%
# %%time
df["Opp rating"] = df.apply(lambda row : get_rating_for_team(team_ratings,
                     fbref_to_team_elo(row['Opponent']), datetime.strptime(row['Date'], '%Y-%m-%d')), axis=1)
# Out:
# FK Metalist 1925 Kharkiv 2022-08-23 00:00:00
# Kryvbas Kryvyi Rih 2022-08-28 00:00:00
# Рух 2022-09-02 00:00:00
# FK Metalist Kharkiv 2022-10-01 00:00:00
# Dynamo Kyiv 2022-10-16 00:00:00
# FK Kolos 2022-10-19 00:00:00
# FC Oleksandriya 2022-10-29 00:00:00
# FK Inhulets 2022-11-05 00:00:00
# Veres Rivne 2022-11-09 00:00:00
# Zorya Luhansk 2022-11-13 00:00:00
# SK Dnipro-1 2022-11-19 00:00:00
# Vorskla Poltava 2022-11-23 00:00:00
# CPU times: total: 1min 19s
# Wall time: 1min 19s

# %%
# %%time
df["Team rating"] = df.apply(lambda row : get_rating_for_team(team_ratings,
                     fbref_to_team_elo(row['Squad']), datetime.strptime(row['Date'], '%Y-%m-%d')), axis=1)
# Out:
# Shakhtar 2022-08-23 00:00:00
# Shakhtar 2022-08-28 00:00:00
# Shakhtar 2022-09-02 00:00:00
# Shakhtar 2022-10-01 00:00:00
# Shakhtar 2022-10-16 00:00:00
# Shakhtar 2022-10-19 00:00:00
# Shakhtar 2022-10-29 00:00:00
# Shakhtar 2022-11-05 00:00:00
# Shakhtar 2022-11-09 00:00:00
# Shakhtar 2022-11-13 00:00:00
# Shakhtar 2022-11-19 00:00:00
# Shakhtar 2022-11-23 00:00:00
# CPU times: total: 1min 23s
# Wall time: 1min 24s

# %%
df.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1        Date  Day            Comp         Round  \
# 0            0             0  2022-08-06  Sat  Premier League   Matchweek 1
# 1            1             1  2022-08-13  Sat  Premier League   Matchweek 2
# 2            2             2  2022-08-21  Sun  Premier League   Matchweek 3
# 3            3             4  2022-08-27  Sat  Premier League   Matchweek 4
# 4            4             5  2022-08-30  Tue  Premier League   Matchweek 5
# 5            5             6  2022-09-03  Sat  Premier League   Matchweek 6
# 6            6             9  2022-10-02  Sun  Premier League   Matchweek 9
# 7            7            10  2022-10-09  Sun  Premier League  Matchweek 10
# 8            8            11  2022-10-16  Sun  Premier League  Matchweek 11
# 9            9            12  2022-10-20  Thu  Premier League  Matchweek 12
# 10          10            13  2022-10-23  Sun  Premier League  Matchweek 13
# 11          11            14  2022-10-29  Sat  Premier League  Matchweek 14
# 12          12            15  2022-11-05  Sat  Premier League  Matchweek 15
# 13          13            17  2022-11-12  Sat  Premier League  Matchweek 16
# 14          14            22  2022-12-28  Wed  Premier League  Matchweek 17
# 15          15            23  2022-12-31  Sat  Premier League  Matchweek 18
# 16          16            24  2023-01-04  Wed  Premier League  Matchweek 19
# 17          17            26  2023-01-13  Fri  Premier League  Matchweek 20
# 18          18            28  2023-01-22  Sun  Premier League  Matchweek 21
# 19          19             3  2022-08-06  Sat  Premier League   Matchweek 1
#
#    Venue         Squad         Opponent Start  ... Opp Score   CS  Was Home  \
# 0   Home  Leeds United           Wolves     Y  ...         1  0.0       1.0
# 1   Away  Leeds United      Southampton     Y  ...         2  0.0       0.0
# 2   Home  Leeds United          Chelsea     Y  ...         0  1.0       1.0
# 3   Away  Leeds United         Brighton     Y  ...         1  0.0       0.0
# 4   Home  Leeds United          Everton     Y  ...         1  0.0       1.0
# 5   Away  Leeds United        Brentford     Y  ...         5  0.0       0.0
# 6   Home  Leeds United      Aston Villa     Y  ...         0  1.0       1.0
# 7   Away  Leeds United   Crystal Palace     Y  ...         2  0.0       0.0
# 8   Home  Leeds United          Arsenal     Y  ...         1  0.0       1.0
# 9   Away  Leeds United   Leicester City     Y  ...         2  0.0       0.0
# 10  Home  Leeds United           Fulham     Y  ...         3  0.0       1.0
# 11  Away  Leeds United        Liverpool     Y  ...         1  0.0       0.0
# 12  Home  Leeds United      Bournemouth     Y  ...         3  0.0       1.0
# 13  Away  Leeds United        Tottenham     Y  ...         4  0.0       0.0
# 14  Home  Leeds United  Manchester City     Y  ...         3  0.0       1.0
# 15  Away  Leeds United    Newcastle Utd     Y  ...         0  1.0       0.0
# 16  Home  Leeds United         West Ham     Y  ...         2  0.0       1.0
# 17  Away  Leeds United      Aston Villa     Y  ...         2  0.0       0.0
# 18  Home  Leeds United        Brentford     Y  ...         0  1.0       1.0
# 19  Away   Southampton        Tottenham     N  ...         4  0.0       0.0
#
#     GW  FPL      neutral_name  Total Points  FPL position   Opp rating  \
# 0    1  2.0  Brenden-Aaronson           2.0           MID  1725.276489
# 1    2  2.0  Brenden-Aaronson           1.0           MID  1667.049927
# 2    3  8.0  Brenden-Aaronson           8.0           MID  1901.388306
# 3    4  2.0  Brenden-Aaronson           1.0           MID  1783.540161
# 4    5  5.0  Brenden-Aaronson           5.0           MID  1688.922485
# 5    6  2.0  Brenden-Aaronson           2.0           MID  1727.113647
# 6    9  3.0  Brenden-Aaronson           3.0           MID  1716.016846
# 7   10  2.0  Brenden-Aaronson           5.0           MID  1748.905396
# 8   11  2.0  Brenden-Aaronson           2.0           MID  1908.041016
# 9   12  2.0  Brenden-Aaronson           2.0           MID  1730.854736
# 10  13  2.0  Brenden-Aaronson           2.0           MID  1669.831543
# 11  14  2.0  Brenden-Aaronson           2.0           MID  1992.204224
# 12  15  2.0  Brenden-Aaronson           2.0           MID  1650.858398
# 13  16  5.0  Brenden-Aaronson           5.0           MID  1872.840210
# 14  17  2.0  Brenden-Aaronson           2.0           MID  2029.863770
# 15  18  3.0  Brenden-Aaronson           3.0           MID  1855.153564
# 16  19  2.0  Brenden-Aaronson           2.0           MID  1749.588989
# 17  20  2.0  Brenden-Aaronson           2.0           MID  1754.206787
# 18  21  3.0  Brenden-Aaronson           3.0           MID  1780.160156
# 19   1  1.0         Che-Adams           0.0           FWD  1866.826172
#
#     Team rating
# 0   1703.435669
# 1   1710.825562
# 2   1711.222290
# 3   1731.332397
# 4   1725.978516
# 5   1723.436768
# 6   1703.110840
# 7   1708.585571
# 8   1709.130737
# 9   1704.655029
# 10  1697.410400
# 11  1685.329956
# 12  1709.350098
# 13  1714.509399
# 14  1711.240234
# 15  1708.104736
# 16  1712.961670
# 17  1713.107910
# 18  1707.010498
# 19  1671.819214
#
# [20 rows x 53 columns]

# %%
df.to_csv("data/fpl_fbref_elo_players.csv")
