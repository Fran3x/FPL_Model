# %% [markdown]
# # Imports

# %%
import os
os.chdir("D:\PulpitE\FPL_ML")

# %%
import pandas as pd
import numpy as np
from vaastav.getters import *
from datetime import datetime

# %% [markdown]
# # Constants

# %%
NEXT_GW = 1

# least number of gameweeks that player had to play
FIS = 1

CURRENT_SEASON = '2023-24'

# %% [markdown]
# # Upcoming fixtures

# %%
fixtures = get_fixtures_data()

# %%
df_fixtures = pd.DataFrame(fixtures)

# %%
df_fixtures
# Out:
#         code  event  finished  finished_provisional   id  \
# 0    2367552    NaN     False                 False   15
# 1    2367713    NaN     False                 False  176
# 2    2367538    1.0      True                  True    1
# 3    2367540    1.0      True                  True    2
# 4    2367539    1.0      True                  True    3
# ..       ...    ...       ...                   ...  ...
# 375  2367913   38.0     False                 False  376
# 376  2367914   38.0     False                 False  377
# 377  2367915   38.0     False                 False  378
# 378  2367916   38.0     False                 False  379
# 379  2367917   38.0     False                 False  380
#
#              kickoff_time  minutes  provisional_start_time started  team_a  \
# 0                    None        0                   False    None       6
# 1                    None        0                   False    None       4
# 2    2023-08-11T19:00:00Z       90                   False    True      13
# 3    2023-08-12T12:00:00Z       90                   False    True      16
# 4    2023-08-12T14:00:00Z       90                   False    True      19
# ..                    ...      ...                     ...     ...     ...
# 375  2024-05-19T15:00:00Z        0                   False   False       2
# 376  2024-05-19T15:00:00Z        0                   False   False      20
# 377  2024-05-19T15:00:00Z        0                   False   False      10
# 378  2024-05-19T15:00:00Z        0                   False   False      19
# 379  2024-05-19T15:00:00Z        0                   False   False      18
#
#      team_a_score  team_h  team_h_score  \
# 0             NaN      12           NaN
# 1             NaN      13           NaN
# 2             3.0       6           0.0
# 3             1.0       1           2.0
# 4             1.0       3           1.0
# ..            ...     ...           ...
# 375           NaN       8           NaN
# 376           NaN      11           NaN
# 377           NaN      12           NaN
# 378           NaN      13           NaN
# 379           NaN      17           NaN
#
#                                                  stats  team_h_difficulty  \
# 0                                                   []                  2
# 1                                                   []                  3
# 2    [{'identifier': 'goals_scored', 'a': [{'value'...                  5
# 3    [{'identifier': 'goals_scored', 'a': [{'value'...                  2
# 4    [{'identifier': 'goals_scored', 'a': [{'value'...                  2
# ..                                                 ...                ...
# 375                                                 []                  3
# 376                                                 []                  2
# 377                                                 []                  2
# 378                                                 []                  2
# 379                                                 []                  3
#
#      team_a_difficulty  pulse_id
# 0                    2     93335
# 1                    5     93496
# 2                    2     93321
# 3                    4     93322
# 4                    2     93323
# ..                 ...       ...
# 375                  2     93696
# 376                  4     93697
# 377                  2     93698
# 378                  5     93699
# 379                  2     93700
#
# [380 rows x 17 columns]

# %%
df_upcoming_fixtures = df_fixtures[df_fixtures["event"] >= NEXT_GW] # also removes rows with no GW number attached (postponed fixtures)

# %%
current_teams = [
        'Arsenal',
        'Aston Villa',
        'Bournemouth',
        'Brentford',
        'Brighton',
        'Burnley',
        'Chelsea',
        'Crystal Palace',
        'Everton',
        'Fulham',
        'Liverpool',
        'Luton',
        'Manchester City',
        'Manchester Utd',
        'Newcastle Utd',
        "Nott'ham Forest",
        'Sheffield United',
        'Tottenham',
        'West Ham',
        'Wolves'
    ]

# %%
# 2023-24 season
def team_id_to_name(current_teams, team_id):
    return current_teams[team_id - 1]

# %%
df_upcoming_fixtures["Squad H"] = df_upcoming_fixtures["team_h"].apply(lambda x: team_id_to_name(current_teams, x))
df_upcoming_fixtures["Squad A"] = df_upcoming_fixtures["team_a"].apply(lambda x: team_id_to_name(current_teams, x))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5840\2597988153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_upcoming_fixtures["Squad H"] = df_upcoming_fixtures["team_h"].apply(lambda x: team_id_to_name(current_teams, x))
# C:\Users\user\AppData\Local\Temp\ipykernel_5840\2597988153.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_upcoming_fixtures["Squad A"] = df_upcoming_fixtures["team_a"].apply(lambda x: team_id_to_name(current_teams, x))

# %%
df_upcoming_fixtures = df_upcoming_fixtures.rename(columns={"event": "GW"})

# %%
# df_upcoming_fixtures

# %%
df_upcoming_fixtures = df_upcoming_fixtures[["GW", "kickoff_time", "Squad H", "Squad A"]]

# %%
df_upcoming_fixtures["kickoff_time"] = df_upcoming_fixtures["kickoff_time"].str[:10]

# %%
df_upcoming_fixtures.shape
# Out:
# (378, 4)

# %%
df_upcoming_fixtures.head(10)
# Out:
#      GW kickoff_time           Squad H          Squad A
# 2   1.0   2023-08-11           Burnley  Manchester City
# 3   1.0   2023-08-12           Arsenal  Nott'ham Forest
# 4   1.0   2023-08-12       Bournemouth         West Ham
# 5   1.0   2023-08-12          Brighton            Luton
# 6   1.0   2023-08-12           Everton           Fulham
# 7   1.0   2023-08-12  Sheffield United   Crystal Palace
# 8   1.0   2023-08-12     Newcastle Utd      Aston Villa
# 9   1.0   2023-08-13         Brentford        Tottenham
# 10  1.0   2023-08-13           Chelsea        Liverpool
# 11  1.0   2023-08-14    Manchester Utd           Wolves

# %% [markdown]
# # Active players

# %%
previous_fixtures = pd.read_csv("data/misc/df_features.csv")

# %%
previous_fixtures.columns
# Out:
# Index(['Ast_2', 'Ast_30', 'Ast_4', 'DEF', 'FPL_points', 'FPL_points_2',
#        'FPL_points_30', 'FPL_points_4', 'FPL_pos', 'FWD', 'GW', 'Gls_2',
#        'Gls_30', 'Gls_4', 'MID', 'Min_2', 'Min_30', 'Min_4', 'Name_original',
#        'Opp_rating', 'Opp_score_2', 'Opp_score_30', 'Opp_score_4', 'Opponent',
#        'Rating_difference', 'Season', 'Team', 'Team_CS_2', 'Team_CS_30',
#        'Team_CS_4', 'Team_rating', 'Team_result_2', 'Team_result_30',
#        'Team_result_4', 'Team_score_2', 'Team_score_30', 'Team_score_4',
#        'Was_home', 'xA_2', 'xA_30', 'xA_4', 'xG_2', 'xG_30', 'xG_4', 'xP'],
#       dtype='object')

# %%
def get_active_players():
    def adjust_team(active_players, row):
        return active_players[active_players["name"] == row["Name_original"]]["team"].iloc[0]
    
    def get_price(active_players, row):
        return active_players[active_players["name"] == row["Name_original"]]["now_cost"].iloc[0]
    
    previous_fixtures = pd.read_csv("data/misc/df_features.csv")
    active_players = pd.read_csv("data/misc/active_players.csv")
    player_names = active_players["name"].to_list()
    print(len(player_names))
    name_counts = previous_fixtures.groupby('Name_original').size()
    filtered_names = name_counts[name_counts >= FIS].index
    print(len(filtered_names))
    filtered_names = [n for n in filtered_names if n in player_names]
    print(len(filtered_names))
    result = previous_fixtures[previous_fixtures['Name_original'].isin(filtered_names)].groupby('Name_original').tail(1).reset_index()
    result = result.loc[:, ~result.columns.str.contains('^Unnamed')]
    result["Team"] = result.apply(lambda x: adjust_team(active_players, x),axis=1)
    result["Price"] = result.apply(lambda x: get_price(active_players, x),axis=1)
    
    return result

# %%
active_players = get_active_players()
active_players[active_players["Name_original"] == "Bryan Mbeumo"][["FPL_pos", "GW", "Season"]]
# Out:
# 665
# 370
# 357
#    FPL_pos  GW   Season
# 45     FWD  38  2022-23

# %%
# active_players_file = pd.read_csv("data/misc/active_players.csv")
# active_players_file.columns

# %%
# active_players_file.iloc[189].head(50)

# %%
# active_players_file[["name", "penalties_order", "team", "status", "chance_of_playing_this_round", "photo", "selected_by_percent"]].sort_values(by=["team"]).head(240).tail(40)

# %%
# active_players[["Name_original", "team"]].head(200).tail(50)

# %%
active_players.columns
# Out:
# Index(['index', 'Ast_2', 'Ast_30', 'Ast_4', 'DEF', 'FPL_points',
#        'FPL_points_2', 'FPL_points_30', 'FPL_points_4', 'FPL_pos', 'FWD', 'GW',
#        'Gls_2', 'Gls_30', 'Gls_4', 'MID', 'Min_2', 'Min_30', 'Min_4',
#        'Name_original', 'Opp_rating', 'Opp_score_2', 'Opp_score_30',
#        'Opp_score_4', 'Opponent', 'Rating_difference', 'Season', 'Team',
#        'Team_CS_2', 'Team_CS_30', 'Team_CS_4', 'Team_rating', 'Team_result_2',
#        'Team_result_30', 'Team_result_4', 'Team_score_2', 'Team_score_30',
#        'Team_score_4', 'Was_home', 'xA_2', 'xA_30', 'xA_4', 'xG_2', 'xG_30',
#        'xG_4', 'xP', 'Price'],
#       dtype='object')

# %%
previous_fixtures[previous_fixtures["Team"] == current_teams[10]]["Name_original"].unique()
# Out:
# array(['Andrew Robertson', 'Cody Gakpo', 'Curtis Jones',
#        'Thiago Alcántara do Nascimento', 'Diogo Teixeira da Silva',
#        'Fabio Henrique Tavares', 'Harvey Elliott', 'Ibrahima Konaté',
#        'Joseph Gomez', 'Joel Matip', 'Jordan Henderson',
#        'Konstantinos Tsimikas', 'Luis Díaz', 'Mohamed Salah',
#        'Nathaniel Phillips', 'Neco Williams', 'Stefan Bajcetic',
#        'Trent Alexander-Arnold', 'Virgil van Dijk'], dtype=object)

# %%
df_upcoming_fixtures.head(30)
# Out:
#      GW kickoff_time           Squad H           Squad A
# 2   1.0   2023-08-11           Burnley   Manchester City
# 3   1.0   2023-08-12           Arsenal   Nott'ham Forest
# 4   1.0   2023-08-12       Bournemouth          West Ham
# 5   1.0   2023-08-12          Brighton             Luton
# 6   1.0   2023-08-12           Everton            Fulham
# 7   1.0   2023-08-12  Sheffield United    Crystal Palace
# 8   1.0   2023-08-12     Newcastle Utd       Aston Villa
# 9   1.0   2023-08-13         Brentford         Tottenham
# 10  1.0   2023-08-13           Chelsea         Liverpool
# 11  1.0   2023-08-14    Manchester Utd            Wolves
# 12  2.0   2023-08-18   Nott'ham Forest  Sheffield United
# 13  2.0   2023-08-19            Fulham         Brentford
# 14  2.0   2023-08-19         Liverpool       Bournemouth
# 15  2.0   2023-08-19            Wolves          Brighton
# 16  2.0   2023-08-19         Tottenham    Manchester Utd
# 17  2.0   2023-08-19   Manchester City     Newcastle Utd
# 18  2.0   2023-08-20       Aston Villa           Everton
# 19  2.0   2023-08-20          West Ham           Chelsea
# 20  2.0   2023-08-21    Crystal Palace           Arsenal
# 21  3.0   2023-08-25           Chelsea             Luton
# 22  3.0   2023-08-26       Bournemouth         Tottenham
# 23  3.0   2023-08-26           Arsenal            Fulham
# 24  3.0   2023-08-26         Brentford    Crystal Palace
# 25  3.0   2023-08-26           Everton            Wolves
# 26  3.0   2023-08-26    Manchester Utd   Nott'ham Forest
# 27  3.0   2023-08-26          Brighton          West Ham
# 28  3.0   2023-08-27           Burnley       Aston Villa
# 29  3.0   2023-08-27  Sheffield United   Manchester City
# 30  3.0   2023-08-27     Newcastle Utd         Liverpool
# 31  4.0   2023-09-01             Luton          West Ham

# %%
active_players.columns
# Out:
# Index(['index', 'Ast_2', 'Ast_30', 'Ast_4', 'DEF', 'FPL_points',
#        'FPL_points_2', 'FPL_points_30', 'FPL_points_4', 'FPL_pos', 'FWD', 'GW',
#        'Gls_2', 'Gls_30', 'Gls_4', 'MID', 'Min_2', 'Min_30', 'Min_4',
#        'Name_original', 'Opp_rating', 'Opp_score_2', 'Opp_score_30',
#        'Opp_score_4', 'Opponent', 'Rating_difference', 'Season', 'Team',
#        'Team_CS_2', 'Team_CS_30', 'Team_CS_4', 'Team_rating', 'Team_result_2',
#        'Team_result_30', 'Team_result_4', 'Team_score_2', 'Team_score_30',
#        'Team_score_4', 'Was_home', 'xA_2', 'xA_30', 'xA_4', 'xG_2', 'xG_30',
#        'xG_4', 'xP', 'Price'],
#       dtype='object')

# %%
active_players["Team"].unique()
# Out:
# array(['Brighton', 'West Ham', 'Brentford', 'Manchester Utd', 'Everton',
#        'Bournemouth', 'Arsenal', 'Fulham', 'Newcastle Utd', 'Liverpool',
#        "Nott'ham Forest", 'Chelsea', 'Manchester City', 'Tottenham',
#        'Aston Villa', 'Wolves', 'Burnley', 'Crystal Palace', 'Luton'],
#       dtype=object)

# %%
for i in range(0,20):
    print(i, current_teams[i], active_players[["Name_original", "Team", "FPL_pos"]][active_players["Team"] == current_teams[i]].shape)
# Out:
# 0 Arsenal (27, 3)
# 1 Aston Villa (22, 3)
# 2 Bournemouth (18, 3)
# 3 Brentford (22, 3)
# 4 Brighton (22, 3)
# 5 Burnley (6, 3)
# 6 Chelsea (20, 3)
# 7 Crystal Palace (18, 3)
# 8 Everton (20, 3)
# 9 Fulham (16, 3)
# 10 Liverpool (18, 3)
# 11 Luton (1, 3)
# 12 Manchester City (20, 3)
# 13 Manchester Utd (24, 3)
# 14 Newcastle Utd (27, 3)
# 15 Nott'ham Forest (22, 3)
# 16 Sheffield United (0, 3)
# 17 Tottenham (21, 3)
# 18 West Ham (16, 3)
# 19 Wolves (17, 3)

# %%
active_players[["Name_original", "Team", "FPL_pos"]][active_players["Team"] == current_teams[3]]
# Out:
#                Name_original       Team FPL_pos
# 2               Aaron Hickey  Brentford     DEF
# 33                   Ben Mee  Brentford     DEF
# 45              Bryan Mbeumo  Brentford     FWD
# 55             Charlie Goode  Brentford     DEF
# 63        Christian Nørgaard  Brentford     MID
# 106            Ethan Pinnock  Brentford     DEF
# 115             Frank Onyeka  Brentford     MID
# 136               Ivan Toney  Brentford     FWD
# 183             Josh Dasilva  Brentford     MID
# 189       Keane Lewis-Potter  Brentford     MID
# 194             Kevin Schade  Brentford     MID
# 201          Kristoffer Ajer  Brentford     DEF
# 219       Mads Bech Sørensen  Brentford     DEF
# 220  Mads Roerslev Rasmussen  Brentford     DEF
# 237           Mathias Jensen  Brentford     MID
# 238        Mathias Jorgensen  Brentford     DEF
# 249         Mikkel Damsgaard  Brentford     MID
# 293               Rico Henry  Brentford     DEF
# 313        Sergi Canós Tenés  Brentford     DEF
# 316         Shandon Baptiste  Brentford     MID
# 346            Vitaly Janelt  Brentford     MID
# 354              Yoane Wissa  Brentford     MID

# %%
active_players[active_players["Name_original"] == "Kai Havertz"]["Team"]
# Out:
# 186    Arsenal
# Name: Team, dtype: object

# %%
active_players.columns
# Out:
# Index(['index', 'Ast_2', 'Ast_30', 'Ast_4', 'DEF', 'FPL_points',
#        'FPL_points_2', 'FPL_points_30', 'FPL_points_4', 'FPL_pos', 'FWD', 'GW',
#        'Gls_2', 'Gls_30', 'Gls_4', 'MID', 'Min_2', 'Min_30', 'Min_4',
#        'Name_original', 'Opp_rating', 'Opp_score_2', 'Opp_score_30',
#        'Opp_score_4', 'Opponent', 'Rating_difference', 'Season', 'Team',
#        'Team_CS_2', 'Team_CS_30', 'Team_CS_4', 'Team_rating', 'Team_result_2',
#        'Team_result_30', 'Team_result_4', 'Team_score_2', 'Team_score_30',
#        'Team_score_4', 'Was_home', 'xA_2', 'xA_30', 'xA_4', 'xG_2', 'xG_30',
#        'xG_4', 'xP', 'Price'],
#       dtype='object')

# %% [markdown]
# # Upcoming home & away logs

# %%
picked_columns = ["Name_original", "GW", "kickoff_time", "Squad", "Squad H", "Squad A", "Was_home", "Opponent", "FPL_pos", "Price"]

# %%
upcoming_player_fixtures_home = active_players.rename(columns={"Team": "Squad H"}).drop(columns=["GW"]).set_index(["Squad H"]).join(df_upcoming_fixtures.set_index(["Squad H"])).reset_index(level=0)
upcoming_player_fixtures_home["Squad"] = upcoming_player_fixtures_home["Squad H"]
upcoming_player_fixtures_home["Was Home"] = 1
# upcoming_player_fixtures_home.loc[upcoming_player_fixtures_home["GW_left"].isnull(), "GW_left"] = 77
# upcoming_player_fixtures_home['C'] = upcoming_player_fixtures_home['GW_left'].fillna(upcoming_player_fixtures_home['GW_right'])
upcoming_player_fixtures_home["Opponent"] = upcoming_player_fixtures_home["Squad A"]
upcoming_player_fixtures_home = upcoming_player_fixtures_home[upcoming_player_fixtures_home["Squad"].isin(current_teams)]
upcoming_player_fixtures_home = upcoming_player_fixtures_home[upcoming_player_fixtures_home["Opponent"].isin(current_teams)]
upcoming_player_fixtures_home = upcoming_player_fixtures_home[picked_columns]

# %%
upcoming_player_fixtures_home[upcoming_player_fixtures_home["Name_original"] == "Kai Havertz"]
# Out:
#     Name_original    GW kickoff_time    Squad  Squad H           Squad A  \
# 247   Kai Havertz   1.0   2023-08-12  Arsenal  Arsenal   Nott'ham Forest
# 248   Kai Havertz   3.0   2023-08-26  Arsenal  Arsenal            Fulham
# 249   Kai Havertz   4.0   2023-09-03  Arsenal  Arsenal    Manchester Utd
# 250   Kai Havertz   6.0   2023-09-24  Arsenal  Arsenal         Tottenham
# 251   Kai Havertz   8.0   2023-10-08  Arsenal  Arsenal   Manchester City
# 252   Kai Havertz  10.0   2023-10-28  Arsenal  Arsenal  Sheffield United
# 253   Kai Havertz  12.0   2023-11-11  Arsenal  Arsenal           Burnley
# 254   Kai Havertz  14.0   2023-12-02  Arsenal  Arsenal            Wolves
# 255   Kai Havertz  17.0   2023-12-16  Arsenal  Arsenal          Brighton
# 256   Kai Havertz  19.0   2023-12-26  Arsenal  Arsenal          West Ham
# 257   Kai Havertz  21.0   2024-01-13  Arsenal  Arsenal    Crystal Palace
# 258   Kai Havertz  23.0   2024-02-03  Arsenal  Arsenal         Liverpool
# 259   Kai Havertz  26.0   2024-02-24  Arsenal  Arsenal     Newcastle Utd
# 260   Kai Havertz  28.0   2024-03-09  Arsenal  Arsenal         Brentford
# 261   Kai Havertz  29.0   2024-03-16  Arsenal  Arsenal           Chelsea
# 262   Kai Havertz  31.0   2024-04-02  Arsenal  Arsenal             Luton
# 263   Kai Havertz  33.0   2024-04-13  Arsenal  Arsenal       Aston Villa
# 264   Kai Havertz  36.0   2024-05-04  Arsenal  Arsenal       Bournemouth
# 265   Kai Havertz  38.0   2024-05-19  Arsenal  Arsenal           Everton
#
#      Was_home          Opponent FPL_pos  Price
# 247       1.0   Nott'ham Forest     FWD     75
# 248       1.0            Fulham     FWD     75
# 249       1.0    Manchester Utd     FWD     75
# 250       1.0         Tottenham     FWD     75
# 251       1.0   Manchester City     FWD     75
# 252       1.0  Sheffield United     FWD     75
# 253       1.0           Burnley     FWD     75
# 254       1.0            Wolves     FWD     75
# 255       1.0          Brighton     FWD     75
# 256       1.0          West Ham     FWD     75
# 257       1.0    Crystal Palace     FWD     75
# 258       1.0         Liverpool     FWD     75
# 259       1.0     Newcastle Utd     FWD     75
# 260       1.0         Brentford     FWD     75
# 261       1.0           Chelsea     FWD     75
# 262       1.0             Luton     FWD     75
# 263       1.0       Aston Villa     FWD     75
# 264       1.0       Bournemouth     FWD     75
# 265       1.0           Everton     FWD     75

# %%
upcoming_player_fixtures_home[upcoming_player_fixtures_home["GW"].isna()]
# Out:
# Empty DataFrame
# Columns: [Name_original, GW, kickoff_time, Squad, Squad H, Squad A, Was_home, Opponent, FPL_pos, Price]
# Index: []

# %%
upcoming_player_fixtures_home['GW'].unique()
# Out:
# array([ 1.,  3.,  4.,  6.,  8., 10., 12., 14., 17., 19., 21., 23., 26.,
#        28., 29., 31., 33., 36., 38.,  2.,  5.,  7.,  9., 15., 16., 18.,
#        20., 22., 24., 30., 32., 34., 35., 37., 11., 13., 25., 27.])

# %%
upcoming_player_fixtures_away = active_players.rename(columns={"Team": "Squad A"}).drop(columns=["GW"]).set_index("Squad A").join(df_upcoming_fixtures.set_index("Squad A")).reset_index(level=0)
upcoming_player_fixtures_away["Squad"] = upcoming_player_fixtures_away["Squad A"]
upcoming_player_fixtures_away["Was Home"] = 0
upcoming_player_fixtures_away["Opponent"] = upcoming_player_fixtures_away["Squad H"]
upcoming_player_fixtures_away = upcoming_player_fixtures_away[upcoming_player_fixtures_away["Squad"].isin(current_teams)]
upcoming_player_fixtures_away = upcoming_player_fixtures_away[upcoming_player_fixtures_away["Opponent"].isin(current_teams)]
upcoming_player_fixtures_away = upcoming_player_fixtures_away[picked_columns]

# %% [markdown]
# # Concating home & away logs

# %%
upcoming_player_fixtures = pd.concat([upcoming_player_fixtures_home, upcoming_player_fixtures_away]).sort_values(by=["Name_original", "GW"])

# %%
upcoming_player_fixtures["Season"] = CURRENT_SEASON
upcoming_player_fixtures["Finished"] = False

# %%
upcoming_player_fixtures = upcoming_player_fixtures.rename(columns={"kickoff_time": "Date"})

# %%
upcoming_player_fixtures["Was_home"] = (upcoming_player_fixtures["Opponent"] == upcoming_player_fixtures["Squad A"]).astype("int64")

# %%
# upcoming_player_fixtures[upcoming_player_fixtures["Name"] == "Gabriel-Dos-Santos"]

# %%
upcoming_player_fixtures[upcoming_player_fixtures["Name_original"] == "Kai Havertz"].head(5)
# Out:
#     Name_original   GW        Date    Squad         Squad H          Squad A  \
# 247   Kai Havertz  1.0  2023-08-12  Arsenal         Arsenal  Nott'ham Forest
# 247   Kai Havertz  2.0  2023-08-21  Arsenal  Crystal Palace          Arsenal
# 248   Kai Havertz  3.0  2023-08-26  Arsenal         Arsenal           Fulham
# 249   Kai Havertz  4.0  2023-09-03  Arsenal         Arsenal   Manchester Utd
# 248   Kai Havertz  5.0  2023-09-16  Arsenal         Everton          Arsenal
#
#      Was_home         Opponent FPL_pos  Price   Season  Finished
# 247         1  Nott'ham Forest     FWD     75  2023-24     False
# 247         0   Crystal Palace     FWD     75  2023-24     False
# 248         1           Fulham     FWD     75  2023-24     False
# 249         1   Manchester Utd     FWD     75  2023-24     False
# 248         0          Everton     FWD     75  2023-24     False

# %%
upcoming_player_fixtures
# Out:
#        Name_original    GW        Date      Squad           Squad H  \
# 1691  Aaron Connolly   1.0  2023-08-12   Brighton          Brighton
# 1669  Aaron Connolly   2.0  2023-08-19   Brighton            Wolves
# 1692  Aaron Connolly   3.0  2023-08-26   Brighton          Brighton
# 1693  Aaron Connolly   4.0  2023-09-02   Brighton          Brighton
# 1670  Aaron Connolly   5.0  2023-09-16   Brighton    Manchester Utd
# ...              ...   ...         ...        ...               ...
# 6132   Yves Bissouma  34.0  2024-04-20  Tottenham         Tottenham
# 6133   Yves Bissouma  35.0  2024-04-27  Tottenham         Tottenham
# 6126   Yves Bissouma  36.0  2024-05-04  Tottenham         Liverpool
# 6134   Yves Bissouma  37.0  2024-05-11  Tottenham         Tottenham
# 6127   Yves Bissouma  38.0  2024-05-19  Tottenham  Sheffield United
#
#               Squad A  Was_home          Opponent FPL_pos  Price   Season  \
# 1691            Luton         1             Luton     FWD     45  2023-24
# 1669         Brighton         0            Wolves     FWD     45  2023-24
# 1692         West Ham         1          West Ham     FWD     45  2023-24
# 1693    Newcastle Utd         1     Newcastle Utd     FWD     45  2023-24
# 1670         Brighton         0    Manchester Utd     FWD     45  2023-24
# ...               ...       ...               ...     ...    ...      ...
# 6132  Manchester City         1   Manchester City     MID     50  2023-24
# 6133          Arsenal         1           Arsenal     MID     50  2023-24
# 6126        Tottenham         0         Liverpool     MID     50  2023-24
# 6134          Burnley         1           Burnley     MID     50  2023-24
# 6127        Tottenham         0  Sheffield United     MID     50  2023-24
#
#       Finished
# 1691     False
# 1669     False
# 1692     False
# 1693     False
# 1670     False
# ...        ...
# 6132     False
# 6133     False
# 6126     False
# 6134     False
# 6127     False
#
# [13517 rows x 12 columns]

# %%
upcoming_player_fixtures.shape
# Out:
# (13517, 12)

# %% [markdown]
# # Loading previous fixtures

# %%
previous_fixtures = pd.read_csv("data/misc/df_features.csv")

# %%
previous_fixtures["Finished"] = True

# %% [markdown]
# # Assigning team elo

# %%
team_ratings = pd.read_csv("data/misc/team_ratings_history.csv")

# %%
# function to assign rating for team
def get_rating_for_team(team_ratings, team_name, date):
    rating = None
    try:
        rating = team_ratings[(team_ratings['From'] <= date.strftime("%Y-%m-%d")) & (team_ratings['Club'] == team_name)].iloc[-1]['Elo']
    except:
        print(team_name, date)
    return rating

# %%
def fbref_to_team_elo(team_name):
    # changes name of a team
    if team_name == "Leicester City":
        return "Leicester"
    if team_name == "Manchester City":
        return "Man City"
    if team_name == "Manchester Utd":
        return "Man United"
    if team_name == "Newcastle Utd":
        return "Newcastle"
    if team_name == "Nott'ham Forest":
        return "Forest"
    if team_name == "Leeds United":
        return "Leeds"
    return team_name

# %%
datetime.strptime(upcoming_player_fixtures['Date'].iloc[1], '%Y-%m-%d')
# Out:
# datetime.datetime(2023, 8, 19, 0, 0)

# %%
upcoming_player_fixtures[upcoming_player_fixtures['Date'].isna()]
# Out:
# Empty DataFrame
# Columns: [Name_original, GW, Date, Squad, Squad H, Squad A, Was_home, Opponent, FPL_pos, Price, Season, Finished]
# Index: []

# %%
# %%time
upcoming_player_fixtures["Opp rating"] = upcoming_player_fixtures.apply(lambda row : get_rating_for_team(team_ratings,
                     fbref_to_team_elo(row['Opponent']), datetime.strptime(row['Date'], '%Y-%m-%d')), axis=1)
# Out:
# CPU times: total: 2min 42s
# Wall time: 2min 43s

# %%
# %%time
upcoming_player_fixtures["Team rating"] = upcoming_player_fixtures.apply(lambda row : get_rating_for_team(team_ratings,
                     fbref_to_team_elo(row['Squad']), datetime.strptime(row['Date'], '%Y-%m-%d')), axis=1)
# Out:
# CPU times: total: 2min 42s
# Wall time: 2min 42s

# %%
upcoming_player_fixtures[upcoming_player_fixtures["Name_original"] == "Gabriel-Dos-Santos"]
# Out:
# Empty DataFrame
# Columns: [Name_original, GW, Date, Squad, Squad H, Squad A, Was_home, Opponent, FPL_pos, Price, Season, Finished, Opp rating, Team rating]
# Index: []

# %%
upcoming_player_fixtures = upcoming_player_fixtures.rename(columns={"Opp rating": "Opp_rating", "Team rating": "Team_rating", "Squad": "Team"})
upcoming_player_fixtures = upcoming_player_fixtures.drop(["Squad H"], axis=1)
upcoming_player_fixtures = upcoming_player_fixtures.drop(["Squad A"], axis=1)

# %%
upcoming_player_fixtures["Rating_difference"] = upcoming_player_fixtures["Team_rating"] - upcoming_player_fixtures["Opp_rating"]

# %%
upcoming_player_fixtures.columns
# Out:
# Index(['Name_original', 'GW', 'Date', 'Team', 'Was_home', 'Opponent',
#        'FPL_pos', 'Price', 'Season', 'Finished', 'Opp_rating', 'Team_rating',
#        'Rating_difference'],
#       dtype='object')

# %%
upcoming_player_fixtures[upcoming_player_fixtures["Name_original"] == "Ben Chilwell"][["Name_original", "Season", "GW", "Was_home"]].tail(45)
# Out:
#      Name_original   Season    GW  Was_home
# 2242  Ben Chilwell  2023-24   1.0         1
# 2214  Ben Chilwell  2023-24   2.0         0
# 2243  Ben Chilwell  2023-24   3.0         1
# 2244  Ben Chilwell  2023-24   4.0         1
# 2215  Ben Chilwell  2023-24   5.0         0
# 2245  Ben Chilwell  2023-24   6.0         1
# 2216  Ben Chilwell  2023-24   7.0         0
# 2217  Ben Chilwell  2023-24   8.0         0
# 2246  Ben Chilwell  2023-24   9.0         1
# 2247  Ben Chilwell  2023-24  10.0         1
# 2218  Ben Chilwell  2023-24  11.0         0
# 2248  Ben Chilwell  2023-24  12.0         1
# 2219  Ben Chilwell  2023-24  13.0         0
# 2249  Ben Chilwell  2023-24  14.0         1
# 2220  Ben Chilwell  2023-24  15.0         0
# 2221  Ben Chilwell  2023-24  16.0         0
# 2250  Ben Chilwell  2023-24  17.0         1
# 2222  Ben Chilwell  2023-24  18.0         0
# 2251  Ben Chilwell  2023-24  19.0         1
# 2223  Ben Chilwell  2023-24  20.0         0
# 2252  Ben Chilwell  2023-24  21.0         1
# 2224  Ben Chilwell  2023-24  22.0         0
# 2253  Ben Chilwell  2023-24  23.0         1
# 2225  Ben Chilwell  2023-24  24.0         0
# 2226  Ben Chilwell  2023-24  25.0         0
# 2254  Ben Chilwell  2023-24  26.0         1
# 2227  Ben Chilwell  2023-24  27.0         0
# 2255  Ben Chilwell  2023-24  28.0         1
# 2228  Ben Chilwell  2023-24  29.0         0
# 2256  Ben Chilwell  2023-24  30.0         1
# 2257  Ben Chilwell  2023-24  31.0         1
# 2229  Ben Chilwell  2023-24  32.0         0
# 2258  Ben Chilwell  2023-24  33.0         1
# 2230  Ben Chilwell  2023-24  34.0         0
# 2231  Ben Chilwell  2023-24  35.0         0
# 2259  Ben Chilwell  2023-24  36.0         1
# 2232  Ben Chilwell  2023-24  37.0         0
# 2260  Ben Chilwell  2023-24  38.0         1

# %% [markdown]
# # Concating previous and upcoming logs

# %%
all_fixtures = pd.concat([previous_fixtures, upcoming_player_fixtures])

# %%
previous_fixtures.columns
# Out:
# Index(['Ast_2', 'Ast_30', 'Ast_4', 'DEF', 'FPL_points', 'FPL_points_2',
#        'FPL_points_30', 'FPL_points_4', 'FPL_pos', 'FWD', 'GW', 'Gls_2',
#        'Gls_30', 'Gls_4', 'MID', 'Min_2', 'Min_30', 'Min_4', 'Name_original',
#        'Opp_rating', 'Opp_score_2', 'Opp_score_30', 'Opp_score_4', 'Opponent',
#        'Rating_difference', 'Season', 'Team', 'Team_CS_2', 'Team_CS_30',
#        'Team_CS_4', 'Team_rating', 'Team_result_2', 'Team_result_30',
#        'Team_result_4', 'Team_score_2', 'Team_score_30', 'Team_score_4',
#        'Was_home', 'xA_2', 'xA_30', 'xA_4', 'xG_2', 'xG_30', 'xG_4', 'xP',
#        'Finished'],
#       dtype='object')

# %%
all_fixtures.shape
# Out:
# (28925, 48)

# %%
all_fixtures.columns
# Out:
# Index(['Ast_2', 'Ast_30', 'Ast_4', 'DEF', 'FPL_points', 'FPL_points_2',
#        'FPL_points_30', 'FPL_points_4', 'FPL_pos', 'FWD', 'GW', 'Gls_2',
#        'Gls_30', 'Gls_4', 'MID', 'Min_2', 'Min_30', 'Min_4', 'Name_original',
#        'Opp_rating', 'Opp_score_2', 'Opp_score_30', 'Opp_score_4', 'Opponent',
#        'Rating_difference', 'Season', 'Team', 'Team_CS_2', 'Team_CS_30',
#        'Team_CS_4', 'Team_rating', 'Team_result_2', 'Team_result_30',
#        'Team_result_4', 'Team_score_2', 'Team_score_30', 'Team_score_4',
#        'Was_home', 'xA_2', 'xA_30', 'xA_4', 'xG_2', 'xG_30', 'xG_4', 'xP',
#        'Finished', 'Date', 'Price'],
#       dtype='object')

# %%
all_fixtures[all_fixtures["Name_original"] == "Kai Havertz"][["Name_original", "Team"]]
# Out:
#      Name_original     Team
# 7975   Kai Havertz  Chelsea
# 7976   Kai Havertz  Chelsea
# 7977   Kai Havertz  Chelsea
# 7978   Kai Havertz  Chelsea
# 7979   Kai Havertz  Chelsea
# ...            ...      ...
# 263    Kai Havertz  Arsenal
# 264    Kai Havertz  Arsenal
# 264    Kai Havertz  Arsenal
# 265    Kai Havertz  Arsenal
# 265    Kai Havertz  Arsenal
#
# [107 rows x 2 columns]

# %% [markdown]
# # Filling missing values

# %%
all_fixtures_before_fill = all_fixtures.copy()

# %%
# all_fixtures = all_fixtures_before_fill

# %%
all_fixtures.columns
# Out:
# Index(['Ast_2', 'Ast_30', 'Ast_4', 'DEF', 'FPL_points', 'FPL_points_2',
#        'FPL_points_30', 'FPL_points_4', 'FPL_pos', 'FWD', 'GW', 'Gls_2',
#        'Gls_30', 'Gls_4', 'MID', 'Min_2', 'Min_30', 'Min_4', 'Name_original',
#        'Opp_rating', 'Opp_score_2', 'Opp_score_30', 'Opp_score_4', 'Opponent',
#        'Rating_difference', 'Season', 'Team', 'Team_CS_2', 'Team_CS_30',
#        'Team_CS_4', 'Team_rating', 'Team_result_2', 'Team_result_30',
#        'Team_result_4', 'Team_score_2', 'Team_score_30', 'Team_score_4',
#        'Was_home', 'xA_2', 'xA_30', 'xA_4', 'xG_2', 'xG_30', 'xG_4', 'xP',
#        'Finished', 'Date', 'Price'],
#       dtype='object')

# %%
columns_to_fill = ['Was_home',
 'Rating_difference',
 'Min_2',
 'Gls_2',
 'Ast_2',
 'xG_2',
 'xA_2',
 'Team_CS_2',
 'Team_score_2',
 'Opp_score_2',
 'Team_result_2',
 'FPL_points_2',
 'Min_4',
 'Gls_4',
 'Ast_4',
 'xG_4',
 'xA_4',
 'Team_CS_4',
 'Team_score_4',
 'Opp_score_4',
 'Team_result_4',
 'FPL_points_4',
 'Min_30',
 'Gls_30',
 'Ast_30',
 'xG_30',
 'xA_30',
 'Team_CS_30',
 'Team_score_30',
 'Opp_score_30',
 'Team_result_30',
 'FPL_points_30',
 'DEF',
 'FWD',
 'MID']

# columns_to_fill.append("FPL_pos")

# # removing position to then ffill it
# all_fixtures.loc[all_fixtures["Season"] == CURRENT_SEASON, "FPL_pos"] = None

for c in ["Was_home", 'Team_rating', 'Opp_rating', 'Rating_difference']:
    if c in columns_to_fill:
        columns_to_fill.remove(c) 

info = ["Name_original", "GW", "Season", "Team", "Opponent", "Was_home", "Team_rating", "Opp_rating", "Price"]

# %%
all_fixtures[columns_to_fill] = all_fixtures.groupby('Name_original')[columns_to_fill].ffill()

# %%
all_fixtures.tail(10)
# Out:
#       Ast_2    Ast_30  Ast_4  DEF  FPL_points  FPL_points_2  FPL_points_30  \
# 6123    0.0  0.033333    0.0  0.0         NaN           1.0       1.733333
# 6130    0.0  0.033333    0.0  0.0         NaN           1.0       1.733333
# 6124    0.0  0.033333    0.0  0.0         NaN           1.0       1.733333
# 6131    0.0  0.033333    0.0  0.0         NaN           1.0       1.733333
# 6125    0.0  0.033333    0.0  0.0         NaN           1.0       1.733333
# 6132    0.0  0.033333    0.0  0.0         NaN           1.0       1.733333
# 6133    0.0  0.033333    0.0  0.0         NaN           1.0       1.733333
# 6126    0.0  0.033333    0.0  0.0         NaN           1.0       1.733333
# 6134    0.0  0.033333    0.0  0.0         NaN           1.0       1.733333
# 6127    0.0  0.033333    0.0  0.0         NaN           1.0       1.733333
#
#       FPL_points_4 FPL_pos  FWD  ...          xA_2  xA_30          xA_4  \
# 6123          0.75     MID  0.0  ...  2.137179e-15   0.02  4.718448e-16
# 6130          0.75     MID  0.0  ...  2.137179e-15   0.02  4.718448e-16
# 6124          0.75     MID  0.0  ...  2.137179e-15   0.02  4.718448e-16
# 6131          0.75     MID  0.0  ...  2.137179e-15   0.02  4.718448e-16
# 6125          0.75     MID  0.0  ...  2.137179e-15   0.02  4.718448e-16
# 6132          0.75     MID  0.0  ...  2.137179e-15   0.02  4.718448e-16
# 6133          0.75     MID  0.0  ...  2.137179e-15   0.02  4.718448e-16
# 6126          0.75     MID  0.0  ...  2.137179e-15   0.02  4.718448e-16
# 6134          0.75     MID  0.0  ...  2.137179e-15   0.02  4.718448e-16
# 6127          0.75     MID  0.0  ...  2.137179e-15   0.02  4.718448e-16
#
#               xG_2     xG_30          xG_4  xP  Finished        Date  Price
# 6123  1.554312e-15  0.006667  6.383782e-16 NaN     False  2024-03-16   50.0
# 6130  1.554312e-15  0.006667  6.383782e-16 NaN     False  2024-03-30   50.0
# 6124  1.554312e-15  0.006667  6.383782e-16 NaN     False  2024-04-02   50.0
# 6131  1.554312e-15  0.006667  6.383782e-16 NaN     False  2024-04-06   50.0
# 6125  1.554312e-15  0.006667  6.383782e-16 NaN     False  2024-04-13   50.0
# 6132  1.554312e-15  0.006667  6.383782e-16 NaN     False  2024-04-20   50.0
# 6133  1.554312e-15  0.006667  6.383782e-16 NaN     False  2024-04-27   50.0
# 6126  1.554312e-15  0.006667  6.383782e-16 NaN     False  2024-05-04   50.0
# 6134  1.554312e-15  0.006667  6.383782e-16 NaN     False  2024-05-11   50.0
# 6127  1.554312e-15  0.006667  6.383782e-16 NaN     False  2024-05-19   50.0
#
# [10 rows x 48 columns]

# %%
all_fixtures[all_fixtures["Name_original"] == "Bryan Mbeumo"][["Name_original", "Season", "GW", "Was_home", "FPL_pos", "Gls_4"]].tail(45)
# Out:
#      Name_original   Season    GW  Was_home FPL_pos  Gls_4
# 1847  Bryan Mbeumo  2022-23  31.0       0.0     FWD   0.00
# 1848  Bryan Mbeumo  2022-23  32.0       1.0     FWD   0.00
# 1849  Bryan Mbeumo  2022-23  33.0       0.0     FWD   0.00
# 1850  Bryan Mbeumo  2022-23  34.0       1.0     FWD   0.25
# 1851  Bryan Mbeumo  2022-23  35.0       0.0     FWD   0.25
# 1852  Bryan Mbeumo  2022-23  36.0       1.0     FWD   0.25
# 1853  Bryan Mbeumo  2022-23  37.0       0.0     FWD   0.50
# 1854  Bryan Mbeumo  2022-23  38.0       1.0     FWD   0.75
# 1311  Bryan Mbeumo  2023-24   1.0       1.0     FWD   0.75
# 1309  Bryan Mbeumo  2023-24   2.0       0.0     FWD   0.75
# 1312  Bryan Mbeumo  2023-24   3.0       1.0     FWD   0.75
# 1313  Bryan Mbeumo  2023-24   4.0       1.0     FWD   0.75
# 1310  Bryan Mbeumo  2023-24   5.0       0.0     FWD   0.75
# 1314  Bryan Mbeumo  2023-24   6.0       1.0     FWD   0.75
# 1311  Bryan Mbeumo  2023-24   7.0       0.0     FWD   0.75
# 1312  Bryan Mbeumo  2023-24   8.0       0.0     FWD   0.75
# 1315  Bryan Mbeumo  2023-24   9.0       1.0     FWD   0.75
# 1313  Bryan Mbeumo  2023-24  10.0       0.0     FWD   0.75
# 1316  Bryan Mbeumo  2023-24  11.0       1.0     FWD   0.75
# 1314  Bryan Mbeumo  2023-24  12.0       0.0     FWD   0.75
# 1317  Bryan Mbeumo  2023-24  13.0       1.0     FWD   0.75
# 1318  Bryan Mbeumo  2023-24  14.0       1.0     FWD   0.75
# 1315  Bryan Mbeumo  2023-24  15.0       0.0     FWD   0.75
# 1316  Bryan Mbeumo  2023-24  16.0       0.0     FWD   0.75
# 1319  Bryan Mbeumo  2023-24  17.0       1.0     FWD   0.75
# 1320  Bryan Mbeumo  2023-24  19.0       1.0     FWD   0.75
# 1317  Bryan Mbeumo  2023-24  20.0       0.0     FWD   0.75
# 1321  Bryan Mbeumo  2023-24  21.0       1.0     FWD   0.75
# 1318  Bryan Mbeumo  2023-24  22.0       0.0     FWD   0.75
# 1322  Bryan Mbeumo  2023-24  23.0       1.0     FWD   0.75
# 1319  Bryan Mbeumo  2023-24  24.0       0.0     FWD   0.75
# 1323  Bryan Mbeumo  2023-24  25.0       1.0     FWD   0.75
# 1320  Bryan Mbeumo  2023-24  26.0       0.0     FWD   0.75
# 1324  Bryan Mbeumo  2023-24  27.0       1.0     FWD   0.75
# 1321  Bryan Mbeumo  2023-24  28.0       0.0     FWD   0.75
# 1322  Bryan Mbeumo  2023-24  29.0       0.0     FWD   0.75
# 1325  Bryan Mbeumo  2023-24  30.0       1.0     FWD   0.75
# 1326  Bryan Mbeumo  2023-24  31.0       1.0     FWD   0.75
# 1323  Bryan Mbeumo  2023-24  32.0       0.0     FWD   0.75
# 1327  Bryan Mbeumo  2023-24  33.0       1.0     FWD   0.75
# 1324  Bryan Mbeumo  2023-24  34.0       0.0     FWD   0.75
# 1325  Bryan Mbeumo  2023-24  35.0       0.0     FWD   0.75
# 1328  Bryan Mbeumo  2023-24  36.0       1.0     FWD   0.75
# 1326  Bryan Mbeumo  2023-24  37.0       0.0     FWD   0.75
# 1329  Bryan Mbeumo  2023-24  38.0       1.0     FWD   0.75

# %%
all_fixtures[all_fixtures["Name_original"] == "Kaoru Mitoma"][["Name_original", "Season", "GW", "Was_home", "FPL_pos", "Gls_4"]].tail(45)
# Out:
#      Name_original   Season    GW  Was_home FPL_pos  Gls_4
# 8121  Kaoru Mitoma  2022-23  28.0       1.0     MID    0.0
# 8122  Kaoru Mitoma  2022-23  35.0       1.0     MID    0.0
# 8123  Kaoru Mitoma  2022-23  36.0       0.0     MID    0.0
# 8124  Kaoru Mitoma  2022-23  25.0       0.0     MID    0.0
# 8125  Kaoru Mitoma  2022-23  37.0       1.0     MID    0.0
# 8126  Kaoru Mitoma  2022-23  32.0       1.0     MID    0.0
# 8127  Kaoru Mitoma  2022-23  38.0       0.0     MID    0.0
# 1957  Kaoru Mitoma  2023-24   1.0       1.0     MID    0.0
# 1935  Kaoru Mitoma  2023-24   2.0       0.0     MID    0.0
# 1958  Kaoru Mitoma  2023-24   3.0       1.0     MID    0.0
# 1959  Kaoru Mitoma  2023-24   4.0       1.0     MID    0.0
# 1936  Kaoru Mitoma  2023-24   5.0       0.0     MID    0.0
# 1960  Kaoru Mitoma  2023-24   6.0       1.0     MID    0.0
# 1937  Kaoru Mitoma  2023-24   7.0       0.0     MID    0.0
# 1961  Kaoru Mitoma  2023-24   8.0       1.0     MID    0.0
# 1938  Kaoru Mitoma  2023-24   9.0       0.0     MID    0.0
# 1962  Kaoru Mitoma  2023-24  10.0       1.0     MID    0.0
# 1939  Kaoru Mitoma  2023-24  11.0       0.0     MID    0.0
# 1963  Kaoru Mitoma  2023-24  12.0       1.0     MID    0.0
# 1940  Kaoru Mitoma  2023-24  13.0       0.0     MID    0.0
# 1941  Kaoru Mitoma  2023-24  14.0       0.0     MID    0.0
# 1964  Kaoru Mitoma  2023-24  15.0       1.0     MID    0.0
# 1965  Kaoru Mitoma  2023-24  16.0       1.0     MID    0.0
# 1942  Kaoru Mitoma  2023-24  17.0       0.0     MID    0.0
# 1943  Kaoru Mitoma  2023-24  18.0       0.0     MID    0.0
# 1966  Kaoru Mitoma  2023-24  19.0       1.0     MID    0.0
# 1944  Kaoru Mitoma  2023-24  20.0       0.0     MID    0.0
# 1967  Kaoru Mitoma  2023-24  21.0       1.0     MID    0.0
# 1945  Kaoru Mitoma  2023-24  22.0       0.0     MID    0.0
# 1968  Kaoru Mitoma  2023-24  23.0       1.0     MID    0.0
# 1946  Kaoru Mitoma  2023-24  24.0       0.0     MID    0.0
# 1947  Kaoru Mitoma  2023-24  25.0       0.0     MID    0.0
# 1969  Kaoru Mitoma  2023-24  26.0       1.0     MID    0.0
# 1948  Kaoru Mitoma  2023-24  27.0       0.0     MID    0.0
# 1970  Kaoru Mitoma  2023-24  28.0       1.0     MID    0.0
# 1971  Kaoru Mitoma  2023-24  29.0       1.0     MID    0.0
# 1949  Kaoru Mitoma  2023-24  30.0       0.0     MID    0.0
# 1950  Kaoru Mitoma  2023-24  31.0       0.0     MID    0.0
# 1972  Kaoru Mitoma  2023-24  32.0       1.0     MID    0.0
# 1951  Kaoru Mitoma  2023-24  33.0       0.0     MID    0.0
# 1973  Kaoru Mitoma  2023-24  34.0       1.0     MID    0.0
# 1952  Kaoru Mitoma  2023-24  35.0       0.0     MID    0.0
# 1974  Kaoru Mitoma  2023-24  36.0       1.0     MID    0.0
# 1953  Kaoru Mitoma  2023-24  37.0       0.0     MID    0.0
# 1975  Kaoru Mitoma  2023-24  38.0       1.0     MID    0.0

# %% [markdown]
# # Saving to file

# %%
all_fixtures.to_csv("data/upcoming/upcoming_fixtures.csv")

# %%
all_fixtures.columns
# Out:
# Index(['Ast_2', 'Ast_30', 'Ast_4', 'DEF', 'FPL_points', 'FPL_points_2',
#        'FPL_points_30', 'FPL_points_4', 'FPL_pos', 'FWD', 'GW', 'Gls_2',
#        'Gls_30', 'Gls_4', 'MID', 'Min_2', 'Min_30', 'Min_4', 'Name_original',
#        'Opp_rating', 'Opp_score_2', 'Opp_score_30', 'Opp_score_4', 'Opponent',
#        'Rating_difference', 'Season', 'Team', 'Team_CS_2', 'Team_CS_30',
#        'Team_CS_4', 'Team_rating', 'Team_result_2', 'Team_result_30',
#        'Team_result_4', 'Team_score_2', 'Team_score_30', 'Team_score_4',
#        'Was_home', 'xA_2', 'xA_30', 'xA_4', 'xG_2', 'xG_30', 'xG_4', 'xP',
#        'Finished', 'Date', 'Price'],
#       dtype='object')

# %%
all_fixtures.shape
# Out:
# (28925, 48)

# %%
all_fixtures["Season"].unique()
# Out:
# array(['2021-22', '2022-23', '2023-24'], dtype=object)
