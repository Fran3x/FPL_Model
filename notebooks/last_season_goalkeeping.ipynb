# %%
import os
os.chdir("D:\PulpitE\FPL_ML")

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup
from bs4 import Comment
import time
import csv

from src.match_names import *
from config import *

pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('data/previous/fpl_players.csv')

# %%
df["team"].unique()
# Out:
# array(['Brighton', 'West Ham', 'Sheffield Utd', 'Everton', 'Fulham',
#        'Wolves', 'Leeds', 'Leicester', 'Liverpool', 'West Brom',
#        'Arsenal', 'Southampton', 'Newcastle', 'Chelsea', 'Crystal Palace',
#        'Spurs', 'Man Utd', 'Man City', 'Aston Villa', 'Burnley',
#        'Watford', 'Norwich', 'Brentford', 'Bournemouth', "Nott'm Forest",
#        'Luton'], dtype=object)

# %%
result = pd.DataFrame()
for t in current_teams_fpl:
    result = result.append(df[(df["season"] == "2022-23") & (df["position"] == "GK") & (df["team"] == t) & (df["minutes"] >= 90)])
    print(t, df[(df["season"] == "2022-23") & (df["position"] == "GK") & (df["team"] == t) & (df["minutes"] >= 90)].shape)
# Out:
# Arsenal (38, 44)
# Aston Villa (36, 44)
# Bournemouth (37, 44)
# Brentford (38, 44)
# Brighton (38, 44)
# Burnley (0, 44)
# Chelsea (37, 44)
# Crystal Palace (38, 44)
# Everton (38, 44)
# Fulham (38, 44)
# Liverpool (38, 44)
# Luton (0, 44)
# Man City (38, 44)
# Man Utd (38, 44)
# Newcastle (37, 44)
# Nott'm Forest (38, 44)
# Sheffield Utd (0, 44)
# Spurs (37, 44)
# West Ham (35, 44)
# Wolves (38, 44)

# %%
result
# Out:
#        Unnamed: 0   season                 name position     team  assists  \
# 50023       50023  2022-23       Aaron Ramsdale       GK  Arsenal        0
# 50599       50599  2022-23       Aaron Ramsdale       GK  Arsenal        0
# 51184       51184  2022-23       Aaron Ramsdale       GK  Arsenal        0
# 51780       51780  2022-23       Aaron Ramsdale       GK  Arsenal        0
# 52382       52382  2022-23       Aaron Ramsdale       GK  Arsenal        0
# ...           ...      ...                  ...      ...      ...      ...
# 72709       72709  2022-23  José Malheiro de Sá       GK   Wolves        0
# 73541       73541  2022-23  José Malheiro de Sá       GK   Wolves        0
# 74448       74448  2022-23       Daniel Bentley       GK   Wolves        0
# 75361       75361  2022-23       Daniel Bentley       GK   Wolves        0
# 76083       76083  2022-23  José Malheiro de Sá       GK   Wolves        0
#
# ...

# %%
result_summary = result.groupby("team")["total_points"].mean().sort_values()

# %%
result_summary.to_csv("data/misc/gk_last_season.csv")

# %%
result_summary
# Out:
# team
# Bournemouth       3.216216
# Nott'm Forest     3.473684
# Spurs             3.486486
# Everton           3.500000
# West Ham          3.514286
# Crystal Palace    3.631579
# Arsenal           3.763158
# Chelsea           3.783784
# Man City          3.789474
# Brighton          3.868421
# Fulham            3.921053
# Aston Villa       3.972222
# Wolves            4.052632
# Man Utd           4.236842
# Liverpool         4.315789
# Brentford         4.368421
# Newcastle         4.405405
# Name: total_points, dtype: float64
