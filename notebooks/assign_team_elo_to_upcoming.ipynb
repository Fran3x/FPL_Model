# %%
import os
os.chdir("D:\PulpitE\FPL_ML")

# %%
import pandas as pd
from datetime import datetime

# %%
team_ratings = pd.read_csv("data/team_ratings_history.csv")

# %%
team_ratings
# Out:
#         Unnamed: 0  Rank              Club Country  Level          Elo  \
# 0                0  None           Arsenal     ENG      1  1551.140259
# 1                1  None           Arsenal     ENG      1  1539.570068
# 2                2  None           Arsenal     ENG      1  1525.449463
# 3                3  None           Arsenal     ENG      1  1523.855591
# 4                4  None           Arsenal     ENG      1  1518.939331
# ...            ...   ...               ...     ...    ...          ...
# 129334        4927    85  Sheffield United     ENG      1  1637.473755
# 129335        4928    86  Sheffield United     ENG      1  1637.473755
# 129336        4929    86  Sheffield United     ENG      1  1637.473755
# 129337        4930    86  Sheffield United     ENG      1  1637.473755
# 129338        4931    86  Sheffield United     ENG      1  1637.473755
#
#               From          To
# 0       1946-07-07  1946-08-31
# 1       1946-09-01  1946-09-04
# 2       1946-09-05  1946-09-07
# 3       1946-09-08  1946-09-11
# 4       1946-09-12  1946-09-14
# ...            ...         ...
# 129334  2023-08-15  2023-08-15
# 129335  2023-08-16  2023-08-18
# 129336  2023-08-19  2023-08-27
# 129337  2023-08-28  2023-08-28
# 129338  2023-08-29  2023-12-31
#
# [129339 rows x 8 columns]

# %%
# function to assign rating for team
def get_rating_for_team(team_ratings, team_name, date):
    rating = None
    try:
        rating = team_ratings[(team_ratings['From'] <= date.strftime("%Y-%m-%d")) & (team_ratings['Club'] == team_name)].iloc[-1]['Elo']
    except:
        print(team_name, date)
    return rating

# %%
def fbref_to_team_elo(team_name):
    # changes name of a team
    if team_name == "Leicester City":
        return "Leicester"
    if team_name == "Manchester City":
        return "Man City"
    if team_name == "Manchester Utd":
        return "Man United"
    if team_name == "Newcastle Utd":
        return "Newcastle"
    if team_name == "Nott'ham Forest":
        return "Forest"
    if team_name == "Leeds United":
        return "Leeds"
    if team_name == "Norwich City":
        return "Norwich"
    if team_name == "Luton Town":
        return "Luton"
    if team_name == "Sheffield Utd":
        return 'Sheffield United'
    return team_name

# %%
# choose correct dataset!
df = pd.read_csv("data/upcoming_fixtures.csv")
# Out:
# C:\users\user\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3369: DtypeWarning: Columns (71) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head(20)
# Out:
#     Unnamed: 0  Ast_2    Ast_30  Ast_4  Baseline_points_2  Baseline_points_30  \
# 0            0    0.0  0.000000   0.00                7.0            7.000000
# 1            1    0.0  0.000000   0.00                7.0            7.000000
# 2            2    0.0  0.000000   0.00                4.5            4.500000
# 3            3    0.0  0.000000   0.00                3.0            4.333333
# 4            4    0.0  0.000000   0.00                5.0            4.750000
# 5            5    0.0  0.000000   0.00                3.5            4.000000
# 6            6    0.0  0.000000   0.00                1.5            3.666667
# 7            7    0.0  0.000000   0.00                1.5            3.285714
# 8            8    0.0  0.000000   0.00                3.5            3.625000
# 9            9    0.5  0.111111   0.25                7.5            4.222222
# 10          10    0.5  0.100000   0.25                5.5            4.000000
# 11          11    0.0  0.090909   0.25                1.5            3.727273
# 12          12    0.0  0.083333   0.25                1.5            3.583333
# 13          13    0.0  0.071429   0.00                2.0            3.461538
# 14          14    0.5  0.133333   0.25                4.0            3.500000
# 15          15    0.5  0.125000   0.25                3.0            3.400000
# 16          16    0.0  0.117647   0.25                4.0            3.562500
# 17          17    0.0  0.111111   0.25                3.0            3.352941
# 18          18    0.5  0.157895   0.25                2.5            3.444444
# 19          19    0.5  0.150000   0.25                5.5            3.578947
#
#     Baseline_points_4  Bonus_2  Bonus_30   Bonus_4  ...  Was_home  xA_2  \
# 0            7.000000      0.0  0.000000  0.000000  ...       0.0  0.10
# 1            7.000000      0.0  0.000000  0.000000  ...       1.0  0.10
# 2            4.500000      0.0  0.000000  0.000000  ...       1.0  0.05
# 3            4.333333      0.5  0.333333  0.333333  ...       0.0  0.05
# 4            4.750000      1.5  0.750000  0.750000  ...       1.0  0.10
# 5            3.250000      1.0  0.600000  0.750000  ...       0.0  0.15
# 6            3.250000      0.0  0.500000  0.750000  ...       1.0  0.15
# 7            2.500000      0.0  0.428571  0.500000  ...       0.0  0.15
# 8            2.500000      0.5  0.500000  0.250000  ...       1.0  0.10
# 9            4.500000      2.0  0.777778  1.000000  ...       0.0  0.15
# 10           4.500000      1.5  0.700000  1.000000  ...       1.0  0.20
# 11           4.500000      0.0  0.636364  1.000000  ...       0.0  0.05
# 12           3.500000      0.0  0.583333  0.750000  ...       0.0  0.10
# 13           1.666667      0.0  0.538462  0.000000  ...       1.0  0.05
# 14           2.666667      2.0  0.642857  0.666667  ...       0.0  0.40
# 15           2.666667      1.0  0.600000  0.666667  ...       1.0  0.35
# 16           4.000000      1.0  0.687500  1.333333  ...       0.0  0.05
# 17           3.000000      1.0  0.647059  1.000000  ...       1.0  0.05
# 18           3.250000      1.5  0.777778  1.250000  ...       1.0  0.10
# 19           4.250000      2.0  0.789474  1.500000  ...       0.0  0.10
#
#        xA_30      xA_4  xG_2     xG_30      xG_4  Finished  Date  Price
# 0   0.100000  0.100000  0.10  0.100000  0.100000      True   NaN    NaN
# 1   0.100000  0.100000  0.10  0.100000  0.100000      True   NaN    NaN
# 2   0.050000  0.050000  0.10  0.100000  0.100000      True   NaN    NaN
# 3   0.066667  0.066667  0.05  0.066667  0.066667      True   NaN    NaN
# 4   0.075000  0.075000  0.05  0.075000  0.075000      True   NaN    NaN
# 5   0.100000  0.100000  0.05  0.060000  0.050000      True   NaN    NaN
# 6   0.100000  0.125000  0.05  0.066667  0.050000      True   NaN    NaN
# 7   0.114286  0.150000  0.05  0.057143  0.050000      True   NaN    NaN
# 8   0.100000  0.125000  0.00  0.050000  0.025000      True   NaN    NaN
# 9   0.122222  0.150000  0.00  0.044444  0.025000      True   NaN    NaN
# 10  0.120000  0.150000  0.05  0.050000  0.025000      True   NaN    NaN
# 11  0.109091  0.100000  0.05  0.045455  0.025000      True   NaN    NaN
# 12  0.116667  0.150000  0.00  0.041667  0.025000      True   NaN    NaN
# 13  0.107143  0.075000  0.00  0.035714  0.000000      True   NaN    NaN
# 14  0.146667  0.250000  0.00  0.033333  0.000000      True   NaN    NaN
# 15  0.137500  0.200000  0.00  0.031250  0.000000      True   NaN    NaN
# 16  0.135294  0.225000  0.00  0.029412  0.000000      True   NaN    NaN
# 17  0.127778  0.200000  0.10  0.038889  0.050000      True   NaN    NaN
# 18  0.131579  0.075000  0.10  0.036842  0.050000      True   NaN    NaN
# 19  0.125000  0.075000  0.05  0.040000  0.075000      True   NaN    NaN
#
# [20 rows x 73 columns]

# %%
df.head().columns
# Out:
# Index(['Unnamed: 0', 'Ast_2', 'Ast_30', 'Ast_4', 'Baseline_points_2',
#        'Baseline_points_30', 'Baseline_points_4', 'Bonus_2', 'Bonus_30',
#        'Bonus_4', 'CrdR_2', 'CrdR_30', 'CrdR_4', 'CrdY_2', 'CrdY_30', 'CrdY_4',
#        'DEF', 'FPL_points', 'FPL_points_2', 'FPL_points_30', 'FPL_points_4',
#        'FPL_pos', 'FWD', 'GK', 'GW', 'Gls_2', 'Gls_30', 'Gls_4', 'ICT_index_2',
#        'ICT_index_30', 'ICT_index_4', 'MID', 'Min_2', 'Min_30', 'Min_4',
#        'Name_original', 'Opp_rating', 'Opp_score_2', 'Opp_score_30',
#        'Opp_score_4', 'Opponent', 'Rating_difference', 'Season', 'Sh_2',
#        'Sh_30', 'Sh_4', 'SoT_2', 'SoT_30', 'SoT_4', 'Start_2', 'Start_30',
#        'Start_4', 'Team', 'Team_CS_2', 'Team_CS_30', 'Team_CS_4',
#        'Team_rating', 'Team_result_2', 'Team_result_30', 'Team_result_4',
#        'Team_score_2', 'Team_score_30', 'Team_score_4', 'Was_home', 'xA_2',
#        'xA_30', 'xA_4', 'xG_2', 'xG_30', 'xG_4', 'Finished', 'Date', 'Price'],
#       dtype='object')

# %%
df["Date"].isna().sum()
# Out:
# 22151

# %%
# %%time
df["Opp rating"] = df.apply(lambda row : get_rating_for_team(team_ratings,
                     fbref_to_team_elo(row['Opponent']), datetime.strptime(row['Date'], '%Y-%m-%d')), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:1, in <module>
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:8736, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8725 from pandas.core.apply import frame_apply
#    8727 op = frame_apply(
#    8728     self,
#    8729     func=func,
#    (...)
#    8734     kwargs=kwargs,
#    8735 )
# -> 8736 return op.apply()
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py:688, in FrameApply.apply(self)
#     685 elif self.raw:
#     686     return self.apply_raw()
# --> 688 return self.apply_standard()
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py:805, in FrameApply.apply_standard(self)
#     804 def apply_standard(self):
# --> 805     results, res_index = self.apply_series_generator()
#     807     # wrap results
#     808     return self.wrap_results(results, res_index)
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py:821, in FrameApply.apply_series_generator(self)
#     818 with option_context("mode.chained_assignment", None):
#     819     for i, v in enumerate(series_gen):
#     820         # ignore SettingWithCopy here in case the user mutates
# --> 821         results[i] = self.f(v)
#     822         if isinstance(results[i], ABCSeries):
#     823             # If we have a view on v, we need to make a copy because
#     824             #  series_generator will swap out the underlying data
#     825             results[i] = results[i].copy(deep=False)
#
# File <timed exec>:2, in <lambda>(row)
#
# TypeError: strptime() argument 1 must be str, not float

# %%
# %%time
df["Team rating"] = df.apply(lambda row : get_rating_for_team(team_ratings,
                     fbref_to_team_elo(row['Squad']), datetime.strptime(row['Date'], '%Y-%m-%d')), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Squad'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File <timed exec>:1, in <module>
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:8736, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8725 from pandas.core.apply import frame_apply
#    8727 op = frame_apply(
#    8728     self,
#    8729     func=func,
#    (...)
#    8734     kwargs=kwargs,
#    8735 )
# -> 8736 return op.apply()
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py:688, in FrameApply.apply(self)
#     685 elif self.raw:
#     686     return self.apply_raw()
# --> 688 return self.apply_standard()
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py:805, in FrameApply.apply_standard(self)
#     804 def apply_standard(self):
# --> 805     results, res_index = self.apply_series_generator()
#     807     # wrap results
#     808     return self.wrap_results(results, res_index)
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py:821, in FrameApply.apply_series_generator(self)
#     818 with option_context("mode.chained_assignment", None):
#     819     for i, v in enumerate(series_gen):
#     820         # ignore SettingWithCopy here in case the user mutates
# --> 821         results[i] = self.f(v)
#     822         if isinstance(results[i], ABCSeries):
#     823             # If we have a view on v, we need to make a copy because
#     824             #  series_generator will swap out the underlying data
#     825             results[i] = results[i].copy(deep=False)
#
# File <timed exec>:2, in <lambda>(row)
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py:942, in Series.__getitem__(self, key)
#     939     return self._values[key]
#     941 elif key_is_scalar:
# --> 942     return self._get_value(key)
#     944 if is_hashable(key):
#     945     # Otherwise index.get_value will raise InvalidIndexError
#     946     try:
#     947         # For labels that don't resolve as scalars like tuples and frozensets
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py:1051, in Series._get_value(self, label, takeable)
#    1048     return self._values[label]
#    1050 # Similar to Index.get_value, but we do not fall back to positional
# -> 1051 loc = self.index.get_loc(label)
#    1052 return self.index._get_values_for_loc(self, loc, label)
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: 'Squad'

# %%
df.head(20)
# Out:
#     Unnamed: 0  Ast_2    Ast_30  Ast_4  Baseline_points_2  Baseline_points_30  \
# 0            0    0.0  0.000000   0.00                7.0            7.000000
# 1            1    0.0  0.000000   0.00                7.0            7.000000
# 2            2    0.0  0.000000   0.00                4.5            4.500000
# 3            3    0.0  0.000000   0.00                3.0            4.333333
# 4            4    0.0  0.000000   0.00                5.0            4.750000
# 5            5    0.0  0.000000   0.00                3.5            4.000000
# 6            6    0.0  0.000000   0.00                1.5            3.666667
# 7            7    0.0  0.000000   0.00                1.5            3.285714
# 8            8    0.0  0.000000   0.00                3.5            3.625000
# 9            9    0.5  0.111111   0.25                7.5            4.222222
# 10          10    0.5  0.100000   0.25                5.5            4.000000
# 11          11    0.0  0.090909   0.25                1.5            3.727273
# 12          12    0.0  0.083333   0.25                1.5            3.583333
# 13          13    0.0  0.071429   0.00                2.0            3.461538
# 14          14    0.5  0.133333   0.25                4.0            3.500000
# 15          15    0.5  0.125000   0.25                3.0            3.400000
# 16          16    0.0  0.117647   0.25                4.0            3.562500
# 17          17    0.0  0.111111   0.25                3.0            3.352941
# 18          18    0.5  0.157895   0.25                2.5            3.444444
# 19          19    0.5  0.150000   0.25                5.5            3.578947
#
#     Baseline_points_4  Bonus_2  Bonus_30   Bonus_4  ...  Was_home  xA_2  \
# 0            7.000000      0.0  0.000000  0.000000  ...       0.0  0.10
# 1            7.000000      0.0  0.000000  0.000000  ...       1.0  0.10
# 2            4.500000      0.0  0.000000  0.000000  ...       1.0  0.05
# 3            4.333333      0.5  0.333333  0.333333  ...       0.0  0.05
# 4            4.750000      1.5  0.750000  0.750000  ...       1.0  0.10
# 5            3.250000      1.0  0.600000  0.750000  ...       0.0  0.15
# 6            3.250000      0.0  0.500000  0.750000  ...       1.0  0.15
# 7            2.500000      0.0  0.428571  0.500000  ...       0.0  0.15
# 8            2.500000      0.5  0.500000  0.250000  ...       1.0  0.10
# 9            4.500000      2.0  0.777778  1.000000  ...       0.0  0.15
# 10           4.500000      1.5  0.700000  1.000000  ...       1.0  0.20
# 11           4.500000      0.0  0.636364  1.000000  ...       0.0  0.05
# 12           3.500000      0.0  0.583333  0.750000  ...       0.0  0.10
# 13           1.666667      0.0  0.538462  0.000000  ...       1.0  0.05
# 14           2.666667      2.0  0.642857  0.666667  ...       0.0  0.40
# 15           2.666667      1.0  0.600000  0.666667  ...       1.0  0.35
# 16           4.000000      1.0  0.687500  1.333333  ...       0.0  0.05
# 17           3.000000      1.0  0.647059  1.000000  ...       1.0  0.05
# 18           3.250000      1.5  0.777778  1.250000  ...       1.0  0.10
# 19           4.250000      2.0  0.789474  1.500000  ...       0.0  0.10
#
#        xA_30      xA_4  xG_2     xG_30      xG_4  Finished  Date  Price
# 0   0.100000  0.100000  0.10  0.100000  0.100000      True   NaN    NaN
# 1   0.100000  0.100000  0.10  0.100000  0.100000      True   NaN    NaN
# 2   0.050000  0.050000  0.10  0.100000  0.100000      True   NaN    NaN
# 3   0.066667  0.066667  0.05  0.066667  0.066667      True   NaN    NaN
# 4   0.075000  0.075000  0.05  0.075000  0.075000      True   NaN    NaN
# 5   0.100000  0.100000  0.05  0.060000  0.050000      True   NaN    NaN
# 6   0.100000  0.125000  0.05  0.066667  0.050000      True   NaN    NaN
# 7   0.114286  0.150000  0.05  0.057143  0.050000      True   NaN    NaN
# 8   0.100000  0.125000  0.00  0.050000  0.025000      True   NaN    NaN
# 9   0.122222  0.150000  0.00  0.044444  0.025000      True   NaN    NaN
# 10  0.120000  0.150000  0.05  0.050000  0.025000      True   NaN    NaN
# 11  0.109091  0.100000  0.05  0.045455  0.025000      True   NaN    NaN
# 12  0.116667  0.150000  0.00  0.041667  0.025000      True   NaN    NaN
# 13  0.107143  0.075000  0.00  0.035714  0.000000      True   NaN    NaN
# 14  0.146667  0.250000  0.00  0.033333  0.000000      True   NaN    NaN
# 15  0.137500  0.200000  0.00  0.031250  0.000000      True   NaN    NaN
# 16  0.135294  0.225000  0.00  0.029412  0.000000      True   NaN    NaN
# 17  0.127778  0.200000  0.10  0.038889  0.050000      True   NaN    NaN
# 18  0.131579  0.075000  0.10  0.036842  0.050000      True   NaN    NaN
# 19  0.125000  0.075000  0.05  0.040000  0.075000      True   NaN    NaN
#
# [20 rows x 73 columns]

# %%
df.to_csv("data/upcoming_fixtures_with_rating.csv")
