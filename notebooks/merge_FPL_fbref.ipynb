# %% [markdown]
# # Imports

# %%
import os
os.chdir("D:\PulpitE\FPL_ML")

# %%
import pandas as pd

# %% [markdown]
# # Getting raw data

# %%
fbref = pd.read_csv("data/logs_all.csv")

# %%
fbref
# Out:
#     Unnamed: 0        Date  Day            Comp         Round Venue  \
# 0            1  2022-08-06  Sat  Premier League   Matchweek 1  Away
# 1            2  2022-08-15  Mon  Premier League   Matchweek 2  Home
# 2            3  2022-08-22  Mon  Premier League   Matchweek 3  Away
# 3            4  2022-08-27  Sat  Premier League   Matchweek 4  Home
# 4            5  2022-08-31  Wed  Premier League   Matchweek 5  Home
# 5            6  2022-09-03  Sat  Premier League   Matchweek 6  Away
# 6           11  2022-10-01  Sat  Premier League   Matchweek 9  Home
# 7           13  2022-10-09  Sun  Premier League  Matchweek 10  Away
# 8           15  2022-10-16  Sun  Premier League  Matchweek 11  Home
# 9           16  2022-10-19  Wed  Premier League  Matchweek 12  Home
# 10          17  2022-10-22  Sat  Premier League  Matchweek 13  Away
# 11          19  2022-10-29  Sat  Premier League  Matchweek 14  Home
# 12          21  2022-11-06  Sun  Premier League  Matchweek 15  Away
# 13          23  2022-11-12  Sat  Premier League  Matchweek 16  Home
# 14          26  2022-12-26  Mon  Premier League  Matchweek 17  Away
# 15          27  2022-12-30  Fri  Premier League  Matchweek 18  Home
# 16          28  2023-01-02  Mon  Premier League  Matchweek 19  Away
# 17          30  2023-01-14  Sat  Premier League  Matchweek 20  Away
# 18          32  2023-01-21  Sat  Premier League  Matchweek 21  Home
#
#         Squad         Opponent Start    Pos  ...           Name   Season  WDL  \
# 0   Liverpool           Fulham     Y     RW  ...  Mohamed-Salah  2022-23    D
# 1   Liverpool   Crystal Palace     Y  RW,FW  ...  Mohamed-Salah  2022-23    D
# 2   Liverpool   Manchester Utd     Y     RW  ...  Mohamed-Salah  2022-23    L
# 3   Liverpool      Bournemouth     Y     RW  ...  Mohamed-Salah  2022-23    W
# 4   Liverpool    Newcastle Utd     Y     RW  ...  Mohamed-Salah  2022-23    W
# 5   Liverpool          Everton     Y     RW  ...  Mohamed-Salah  2022-23    D
# 6   Liverpool         Brighton     Y  RW,RM  ...  Mohamed-Salah  2022-23    D
# 7   Liverpool          Arsenal     Y     RW  ...  Mohamed-Salah  2022-23    L
# 8   Liverpool  Manchester City     Y     FW  ...  Mohamed-Salah  2022-23    W
# 9   Liverpool         West Ham     Y  RM,FW  ...  Mohamed-Salah  2022-23    W
# 10  Liverpool  Nott'ham Forest     Y     FW  ...  Mohamed-Salah  2022-23    L
# 11  Liverpool     Leeds United     Y     FW  ...  Mohamed-Salah  2022-23    L
# 12  Liverpool        Tottenham     Y     FW  ...  Mohamed-Salah  2022-23    W
# 13  Liverpool      Southampton     Y     RW  ...  Mohamed-Salah  2022-23    W
# 14  Liverpool      Aston Villa     Y  RW,FW  ...  Mohamed-Salah  2022-23    W
# 15  Liverpool   Leicester City     Y     RW  ...  Mohamed-Salah  2022-23    W
# 16  Liverpool        Brentford     Y     RW  ...  Mohamed-Salah  2022-23    L
# 17  Liverpool         Brighton     Y  FW,RW  ...  Mohamed-Salah  2022-23    L
# 18  Liverpool          Chelsea     Y     RW  ...  Mohamed-Salah  2022-23    D
#
#     GoalsTeams  Team Score  Opp Score   CS  Was Home  GW   FPL
# 0          2–2           2          2  0.0       0.0   1   7.0
# 1          1–1           1          1  0.0       1.0   2   2.0
# 2          1–2           1          2  0.0       0.0   3   7.0
# 3          9–0           9          0  1.0       1.0   4   3.0
# 4          2–1           2          1  0.0       1.0   5   8.0
# 5          0–0           0          0  1.0       0.0   6   3.0
# 6          3–3           3          3  0.0       1.0   9   5.0
# 7          2–3           2          3  0.0       0.0  10   2.0
# 8          1–0           1          0  1.0       1.0  11   8.0
# 9          1–0           1          0  1.0       1.0  12   3.0
# 10         0–1           0          1  0.0       0.0  13   2.0
# 11         1–2           1          2  0.0       1.0  14   7.0
# 12         2–1           2          1  0.0       0.0  15  12.0
# 13         3–1           3          1  0.0       1.0  16   2.0
# 14         3–1           3          1  0.0       0.0  17  10.0
# 15         2–1           2          1  0.0       1.0  18   2.0
# 16         1–3           1          3  0.0       0.0  19   2.0
# 17         0–3           0          3  0.0       0.0  20   2.0
# 18         0–0           0          0  1.0       1.0  21   3.0
#
# [19 rows x 47 columns]

# %%
fbref.iloc[0]
# Out:
# Unnamed: 0                   1
# Date                2022-08-06
# Day                        Sat
# Comp            Premier League
# Round              Matchweek 1
# Venue                     Away
# Squad                Liverpool
# Opponent                Fulham
# Start                        Y
# Pos                         RW
# Min                       90.0
# Gls                        1.0
# Ast                        0.0
# PK                         0.0
# PKatt                      0.0
# Sh                         2.0
# SoT                        1.0
# CrdY                       0.0
# CrdR                       0.0
# Touches                   47.0
# Tkl                        0.0
# Int                        1.0
# Blocks                     0.0
# xG                         0.4
# npxG                       0.4
# xAG                        0.1
# SCA                        2.0
# GCA                        0.0
# Cmp                       24.0
# Att                       34.0
# Cmp%                      70.6
# PrgP                       6.0
# Carries                   31.0
# PrgC                       4.0
# Att.1                      6.0
# Succ                       2.0
# Match Report      Match Report
# Name             Mohamed-Salah
# Season                 2022-23
# WDL                          D
# GoalsTeams                 2–2
# Team Score                   2
# Opp Score                    2
# CS                         0.0
# Was Home                   0.0
# GW                           1
# FPL                        7.0
# Name: 0, dtype: object

# %%
fpl = pd.read_csv("data/fpl_players.csv")

# %%
fpl.iloc[0]
# Out:
# Unnamed: 0                                       0
# index                                        49472
# season                                     2020-21
# name                                Aaron Connolly
# position                                       FWD
# team                                      Brighton
# assists                                          0
# bonus                                            0
# bps                                             -3
# clean_sheets                                     0
# creativity                                     0.3
# element                                         78
# fixture                                          7
# goals_conceded                                   2
# goals_scored                                     0
# ict_index                                      3.4
# influence                                      1.2
# kickoff_time                  2020-09-14T19:15:00Z
# minutes                                         45
# opponent_team                                    5
# opp_team_name                              Chelsea
# own_goals                                        0
# penalties_missed                                 0
# penalties_saved                                  0
# red_cards                                        0
# round                                            1
# saves                                            0
# selected                                     32205
# team_a_score                                   3.0
# team_h_score                                   1.0
# threat                                        32.0
# total_points                                     1
# transfers_balance                                0
# transfers_in                                     0
# transfers_out                                    0
# value                                           55
# was_home                                      True
# yellow_cards                                     0
# GW                                             1.0
# xP                                             NaN
# expected_assists                               NaN
# expected_goal_involvements                     NaN
# expected_goals                                 NaN
# expected_goals_conceded                        NaN
# starts                                         NaN
# Name: 0, dtype: object

# %%
fpl[(fpl["season"] == "2022-23") & (fpl["name"] == "Ben Davies") & (fpl["GW"] == 2)]
# Out:
#        Unnamed: 0  index   season        name position       team  assists  \
# 49676       49676    746  2022-23  Ben Davies      DEF  Liverpool        0
# 49910       49910    980  2022-23  Ben Davies      DEF      Spurs        1
#
#        bonus  bps  clean_sheets  ...  value  was_home  yellow_cards   GW   xP  \
# 49676      0    0             0  ...     40      True             0  2.0  0.0
# 49910      0   20             0  ...     50     False             0  2.0  3.0
#
#        expected_assists  expected_goal_involvements expected_goals  \
# 49676               0.0                         0.0            0.0
# 49910               0.0                         0.0            0.0
#
#        expected_goals_conceded  starts
# 49676                      0.0     0.0
# 49910                      0.0     0.0
#
# [2 rows x 45 columns]

# %%
sorted(fpl["team"].unique())
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brentford',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Fulham',
#  'Leeds',
#  'Leicester',
#  'Liverpool',
#  'Man City',
#  'Man Utd',
#  'Newcastle',
#  'Norwich',
#  "Nott'm Forest",
#  'Sheffield Utd',
#  'Southampton',
#  'Spurs',
#  'Watford',
#  'West Brom',
#  'West Ham',
#  'Wolves']

# %%
sorted(fbref["Squad"].unique())
# Out:
# ['Liverpool']

# %% [markdown]
# # Merging

# %%
def team_fbref_to_fpl(team_name):
    if team_name == "Nott'ham Forest":
        return "Nott'm Forest"
    if team_name == "Leicester City":
        return "Leicester"
    if team_name == "Leeds United":
        return "Leeds"
    if team_name == "Manchester City":
        return "Man City"
    if team_name == "Manchester Utd":
        return "Man Utd"
    if team_name == "Tottenham":
        return "Spurs"
    if team_name == "Newcastle Utd":
        return "Newcastle"
    
    return team_name

# %%
def neutralize_name(name):
    return name.replace(" ", "-").replace("ï", "i").replace("é", "e").replace("á", "a").replace("ó", "o").replace("Á", "A").replace("ø", "o").replace("ć", "c").replace("í", "i").replace("ú", "u").replace("Ć", "C").replace("ã", "a").replace("ğ", "g").replace("ş", "s").replace("É", "E").replace("ñ", "n").replace("Ł", "L").replace("ń", "n").replace("ß", "ss").replace("ç", "c").replace("İ", "I").replace("č", "c").replace("ö", "o").replace("ë", "e").replace("š", "s").replace("ä", "a").replace("Ç", "C").replace("ü", "u").replace("Ø", "O").replace("ú", "u").replace("ú", "u").replace("î", "i")

# %%
from src.match_names import name_fbref_to_fpl

# %%
# add neutralized columns
fpl["neutral_name"] = fpl["name"].apply(neutralize_name)
fbref["neutral_name"] = fbref["Name"].apply(neutralize_name)

# %%
# %%time
for i, row in fbref.iterrows():
    name = name_fbref_to_fpl(neutralize_name(row["Name"]))
    gw = row["GW"]
    season = row["Season"]
    team = team_fbref_to_fpl(row["Squad"])
    # print(name, gw, season)
    # print(type(season))
    # print("2022-2023" == "2022-23")
    fpl_row = fpl[(fpl["name"].apply(neutralize_name) == name) & (fpl["GW"] == gw) & (fpl["season"] == season) & (fpl["team"] == team)]
    fpl_position = fpl_row["position"].item()
    if not fpl_row.empty:
        try:
            fpl_points = fpl_row["total_points"]
            fpl_points = fpl_points.item()
        except:
            print("ERROR", fpl_row)
            print(name, gw, season)
    else:
        print(i, name, gw, season, team)
        fpl_points = None
    print(name, gw, fpl_points)
    fbref.at[i, "Total Points"] = fpl_points
    fbref.at[i, "FPL position"] = fpl_position
# Out:
# Mohamed-Salah 1 12
# MID
# <class 'str'>
# Mohamed-Salah 2 2
# MID
# <class 'str'>
# Mohamed-Salah 3 8
# MID
# <class 'str'>
# Mohamed-Salah 4 3
# MID
# <class 'str'>
# Mohamed-Salah 5 10
# MID
# <class 'str'>
# Mohamed-Salah 6 3
# MID
# <class 'str'>
# Mohamed-Salah 9 5
# MID
# <class 'str'>
# Mohamed-Salah 10 2
# MID
# <class 'str'>
# Mohamed-Salah 11 8
# MID
# <class 'str'>
# Mohamed-Salah 12 3
# MID
# <class 'str'>
# Mohamed-Salah 13 2
# MID
# <class 'str'>
# Mohamed-Salah 14 7
# MID
# <class 'str'>
# Mohamed-Salah 15 15
# MID
# <class 'str'>
# Mohamed-Salah 16 2
# MID
# <class 'str'>
# Mohamed-Salah 17 12
# MID
# <class 'str'>
# Mohamed-Salah 18 2
# MID
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed exec>:10, in <module>
#
# File C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\base.py:331, in IndexOpsMixin.item(self)
#     329 if len(self) == 1:
#     330     return next(iter(self))
# --> 331 raise ValueError("can only convert an array of size 1 to a Python scalar")
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
fbref[fbref["Name"] == "Tosin-Adarabioyo"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, Day, Comp, Round, Venue, Squad, Opponent, Start, Pos, Min, Gls, Ast, PK, PKatt, Sh, SoT, CrdY, CrdR, Touches, Tkl, Int, Blocks, xG, npxG, xAG, SCA, GCA, Cmp, Att, Cmp%, PrgP, Carries, PrgC, Att.1, Succ, Match Report, Name, Season, WDL, GoalsTeams, Team Score, Opp Score, CS, Was Home, GW, FPL, neutral_name, Total Points, FPL position]
# Index: []
#
# [0 rows x 50 columns]

# %% [markdown]
# # Saving merged df to file

# %%
# fbref[["Name", "GW", "Season", "Squad", "Total Points"]].to_csv("data/fpl_fbref_players.csv")
fbref.to_csv("data/fpl_fbref_players.csv")

# %%
fbref
# Out:
#     Unnamed: 0        Date  Day            Comp         Round Venue  \
# 0            1  2022-08-06  Sat  Premier League   Matchweek 1  Away
# 1            2  2022-08-15  Mon  Premier League   Matchweek 2  Home
# 2            3  2022-08-22  Mon  Premier League   Matchweek 3  Away
# 3            4  2022-08-27  Sat  Premier League   Matchweek 4  Home
# 4            5  2022-08-31  Wed  Premier League   Matchweek 5  Home
# 5            6  2022-09-03  Sat  Premier League   Matchweek 6  Away
# 6           11  2022-10-01  Sat  Premier League   Matchweek 9  Home
# 7           13  2022-10-09  Sun  Premier League  Matchweek 10  Away
# 8           15  2022-10-16  Sun  Premier League  Matchweek 11  Home
# 9           16  2022-10-19  Wed  Premier League  Matchweek 12  Home
# 10          17  2022-10-22  Sat  Premier League  Matchweek 13  Away
# 11          19  2022-10-29  Sat  Premier League  Matchweek 14  Home
# 12          21  2022-11-06  Sun  Premier League  Matchweek 15  Away
# 13          23  2022-11-12  Sat  Premier League  Matchweek 16  Home
# 14          26  2022-12-26  Mon  Premier League  Matchweek 17  Away
# 15          27  2022-12-30  Fri  Premier League  Matchweek 18  Home
# 16          28  2023-01-02  Mon  Premier League  Matchweek 19  Away
# 17          30  2023-01-14  Sat  Premier League  Matchweek 20  Away
# 18          32  2023-01-21  Sat  Premier League  Matchweek 21  Home
#
#         Squad         Opponent Start    Pos  ...  GoalsTeams  Team Score  \
# 0   Liverpool           Fulham     Y     RW  ...         2–2           2
# 1   Liverpool   Crystal Palace     Y  RW,FW  ...         1–1           1
# 2   Liverpool   Manchester Utd     Y     RW  ...         1–2           1
# 3   Liverpool      Bournemouth     Y     RW  ...         9–0           9
# 4   Liverpool    Newcastle Utd     Y     RW  ...         2–1           2
# 5   Liverpool          Everton     Y     RW  ...         0–0           0
# 6   Liverpool         Brighton     Y  RW,RM  ...         3–3           3
# 7   Liverpool          Arsenal     Y     RW  ...         2–3           2
# 8   Liverpool  Manchester City     Y     FW  ...         1–0           1
# 9   Liverpool         West Ham     Y  RM,FW  ...         1–0           1
# 10  Liverpool  Nott'ham Forest     Y     FW  ...         0–1           0
# 11  Liverpool     Leeds United     Y     FW  ...         1–2           1
# 12  Liverpool        Tottenham     Y     FW  ...         2–1           2
# 13  Liverpool      Southampton     Y     RW  ...         3–1           3
# 14  Liverpool      Aston Villa     Y  RW,FW  ...         3–1           3
# 15  Liverpool   Leicester City     Y     RW  ...         2–1           2
# 16  Liverpool        Brentford     Y     RW  ...         1–3           1
# 17  Liverpool         Brighton     Y  FW,RW  ...         0–3           0
# 18  Liverpool          Chelsea     Y     RW  ...         0–0           0
#
#     Opp Score   CS  Was Home  GW   FPL   neutral_name  Total Points  \
# 0           2  0.0       0.0   1   7.0  Mohamed-Salah          12.0
# 1           1  0.0       1.0   2   2.0  Mohamed-Salah           2.0
# 2           2  0.0       0.0   3   7.0  Mohamed-Salah           8.0
# 3           0  1.0       1.0   4   3.0  Mohamed-Salah           3.0
# 4           1  0.0       1.0   5   8.0  Mohamed-Salah          10.0
# 5           0  1.0       0.0   6   3.0  Mohamed-Salah           3.0
# 6           3  0.0       1.0   9   5.0  Mohamed-Salah           5.0
# 7           3  0.0       0.0  10   2.0  Mohamed-Salah           2.0
# 8           0  1.0       1.0  11   8.0  Mohamed-Salah           8.0
# 9           0  1.0       1.0  12   3.0  Mohamed-Salah           3.0
# 10          1  0.0       0.0  13   2.0  Mohamed-Salah           2.0
# 11          2  0.0       1.0  14   7.0  Mohamed-Salah           7.0
# 12          1  0.0       0.0  15  12.0  Mohamed-Salah          15.0
# 13          1  0.0       1.0  16   2.0  Mohamed-Salah           2.0
# 14          1  0.0       0.0  17  10.0  Mohamed-Salah          12.0
# 15          1  0.0       1.0  18   2.0  Mohamed-Salah           2.0
# 16          3  0.0       0.0  19   2.0  Mohamed-Salah           NaN
# 17          3  0.0       0.0  20   2.0  Mohamed-Salah           NaN
# 18          0  1.0       1.0  21   3.0  Mohamed-Salah           NaN
#
#     FPL position
# 0            MID
# 1            MID
# 2            MID
# 3            MID
# 4            MID
# 5            MID
# 6            MID
# 7            MID
# 8            MID
# 9            MID
# 10           MID
# 11           MID
# 12           MID
# 13           MID
# 14           MID
# 15           MID
# 16           NaN
# 17           NaN
# 18           NaN
#
# [19 rows x 50 columns]
