# %% [markdown]
# # Imports

# %%
import os
os.chdir("D:\PulpitE\FPL_ML")

# %%
import pandas as pd

# %% [markdown]
# # Getting raw data

# %%
fbref = pd.read_csv("data/logs_all.csv")

# %%
fbref
# Out:
#      Unnamed: 0        Date  Day            Comp         Round Venue  \
# 0             4  2022-08-28  Sun  Premier League   Matchweek 4  Away
# 1             5  2022-08-31  Wed  Premier League   Matchweek 5  Away
# 2             6  2022-09-03  Sat  Premier League   Matchweek 6  Home
# 3             8  2022-09-17  Sat  Premier League   Matchweek 8  Home
# 4            11  2022-10-01  Sat  Premier League   Matchweek 9  Away
# ..          ...         ...  ...             ...           ...   ...
# 100          14  2022-11-06  Sun  Premier League  Matchweek 15  Away
# 101          16  2022-11-12  Sat  Premier League  Matchweek 16  Away
# 102          18  2022-12-26  Mon  Premier League  Matchweek 17  Home
# 103          19  2022-12-31  Sat  Premier League  Matchweek 18  Away
# 104          20  2023-01-04  Wed  Premier League  Matchweek 19  Home
#
#               Squad         Opponent Start       Pos  ...  Match Report  \
# ...

# %%
fpl = pd.read_csv("data/fpl_players.csv")

# %%
fpl.iloc[0]
# Out:
# Unnamed: 0                                       0
# index                                        49472
# season                                     2020-21
# name                                Aaron Connolly
# position                                       FWD
# team                                      Brighton
# assists                                          0
# bonus                                            0
# bps                                             -3
# clean_sheets                                     0
# creativity                                     0.3
# element                                         78
# fixture                                          7
# goals_conceded                                   2
# goals_scored                                     0
# ict_index                                      3.4
# influence                                      1.2
# kickoff_time                  2020-09-14T19:15:00Z
# ...
