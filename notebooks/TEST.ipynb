# %%
import os
os.chdir("D:\PulpitE\FPL_ML")

# %%
import pandas as pd
from vaastav import getters

# %%
getters.get_data()["elements"]
# Out:
# [{'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 232223,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 4,
#   'ep_next': '1.5',
#   'ep_this': '1.5',
#   'event_points': 0,
#   'first_name': 'Folarin',
#   'form': '0.0',
#   'id': 1,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2023-08-07T15:30:05.135490Z',
#   'now_cost': 45,
#   'photo': '232223.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Balogun',
#   'selected_by_percent': '0.8',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 1129,
#   'transfers_in_event': 1129,
#   'transfers_out': 754,
#   'transfers_out_event': 754,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Balogun',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 253,
#   'influence_rank_type': 9,
#   'creativity_rank': 253,
#   'creativity_rank_type': 9,
#   'threat_rank': 248,
#   'threat_rank_type': 9,
#   'ict_index_rank': 253,
#   'ict_index_rank_type': 9,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 436,
#   'now_cost_rank_type': 68,
#   'form_rank': 283,
#   'form_rank_type': 12,
#   'points_per_game_rank': 283,
#   'points_per_game_rank_type': 12,
#   'selected_rank': 194,
#   'selected_rank_type': 37,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 58822,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '1.5',
#   'ep_this': '1.5',
#   'event_points': 0,
#   'first_name': 'Cédric',
#   'form': '0.0',
#   'id': 2,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 40,
#   'photo': '58822.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Alves Soares',
#   'selected_by_percent': '0.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 330,
#   'transfers_in_event': 330,
#   'transfers_out': 361,
#   'transfers_out_event': 361,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Cédric',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 22,
#   'influence_rank_type': 8,
#   'creativity_rank': 22,
#   'creativity_rank_type': 8,
#   'threat_rank': 17,
#   'threat_rank_type': 6,
#   'ict_index_rank': 22,
#   'ict_index_rank_type': 8,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 545,
#   'now_cost_rank_type': 154,
#   'form_rank': 62,
#   'form_rank_type': 22,
#   'points_per_game_rank': 62,
#   'points_per_game_rank_type': 22,
#   'selected_rank': 250,
#   'selected_rank_type': 89,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 153256,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Mohamed',
#   'form': '0.0',
#   'id': 3,
#   'in_dreamteam': False,
#   'news': 'Knee injury - Unknown return date',
#   'news_added': '2023-08-11T13:00:06.079379Z',
#   'now_cost': 45,
#   'photo': '153256.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Elneny',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'i',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 22,
#   'transfers_in_event': 22,
#   'transfers_out': 752,
#   'transfers_out_event': 752,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'M.Elneny',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 179,
#   'influence_rank_type': 14,
#   'creativity_rank': 179,
#   'creativity_rank_type': 15,
#   'threat_rank': 174,
#   'threat_rank_type': 12,
#   'ict_index_rank': 179,
#   'ict_index_rank_type': 14,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 362,
#   'now_cost_rank_type': 206,
#   'form_rank': 214,
#   'form_rank_type': 34,
#   'points_per_game_rank': 214,
#   'points_per_game_rank_type': 34,
#   'selected_rank': 417,
#   'selected_rank_type': 138,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 438098,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.6',
#   'ep_this': '2.6',
#   'event_points': 0,
#   'first_name': 'Fábio',
#   'form': '0.0',
#   'id': 4,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 55,
#   'photo': '438098.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Ferreira Vieira',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 138,
#   'transfers_in_event': 138,
#   'transfers_out': 197,
#   'transfers_out_event': 197,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Fábio Vieira',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 558,
#   'influence_rank_type': 224,
#   'creativity_rank': 558,
#   'creativity_rank_type': 224,
#   'threat_rank': 557,
#   'threat_rank_type': 223,
#   'ict_index_rank': 558,
#   'ict_index_rank_type': 224,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 137,
#   'now_cost_rank_type': 89,
#   'form_rank': 565,
#   'form_rank_type': 230,
#   'points_per_game_rank': 565,
#   'points_per_game_rank_type': 230,
#   'selected_rank': 414,
#   'selected_rank_type': 136,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 226597,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.8',
#   'ep_this': '2.8',
#   'event_points': 0,
#   'first_name': 'Gabriel',
#   'form': '0.0',
#   'id': 5,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '226597.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'dos Santos Magalhães',
#   'selected_by_percent': '33.6',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 9136,
#   'transfers_in_event': 9136,
#   'transfers_out': 9829,
#   'transfers_out_event': 9829,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Gabriel',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 454,
#   'influence_rank_type': 200,
#   'creativity_rank': 454,
#   'creativity_rank_type': 200,
#   'threat_rank': 452,
#   'threat_rank_type': 200,
#   'ict_index_rank': 454,
#   'ict_index_rank_type': 200,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 255,
#   'now_cost_rank_type': 31,
#   'form_rank': 472,
#   'form_rank_type': 204,
#   'points_per_game_rank': 472,
#   'points_per_game_rank_type': 204,
#   'selected_rank': 7,
#   'selected_rank_type': 3,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 219847,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '3.1',
#   'ep_this': '3.1',
#   'event_points': 1,
#   'first_name': 'Kai',
#   'form': '1.0',
#   'id': 6,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 75,
#   'photo': '219847.jpg',
#   'points_per_game': '1.0',
#   'second_name': 'Havertz',
#   'selected_by_percent': '5.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 1,
#   'transfers_in': 2031,
#   'transfers_in_event': 2031,
#   'transfers_out': 1895,
#   'transfers_out_event': 1895,
#   'value_form': '0.1',
#   'value_season': '0.1',
#   'web_name': 'Havertz',
#   'minutes': 20,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 3,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 1,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.43',
#   'influence_rank': 627,
#   'influence_rank_type': 265,
#   'creativity_rank': 627,
#   'creativity_rank_type': 265,
#   'threat_rank': 627,
#   'threat_rank_type': 265,
#   'ict_index_rank': 627,
#   'ict_index_rank_type': 265,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.0,
#   'expected_goal_involvements_per_90': 0.0,
#   'expected_goals_conceded_per_90': 1.94,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 24,
#   'now_cost_rank_type': 14,
#   'form_rank': 49,
#   'form_rank_type': 21,
#   'points_per_game_rank': 49,
#   'points_per_game_rank_type': 21,
#   'selected_rank': 68,
#   'selected_rank_type': 22,
#   'starts_per_90': 4.5,
#   'clean_sheets_per_90': 0.0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 156074,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.5',
#   'ep_this': '2.5',
#   'event_points': 0,
#   'first_name': 'Rob',
#   'form': '0.0',
#   'id': 7,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '156074.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Holding',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 190,
#   'transfers_in_event': 190,
#   'transfers_out': 282,
#   'transfers_out_event': 282,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Holding',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 181,
#   'influence_rank_type': 108,
#   'creativity_rank': 181,
#   'creativity_rank_type': 108,
#   'threat_rank': 176,
#   'threat_rank_type': 106,
#   'ict_index_rank': 181,
#   'ict_index_rank_type': 108,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 364,
#   'now_cost_rank_type': 74,
#   'form_rank': 216,
#   'form_rank_type': 118,
#   'points_per_game_rank': 216,
#   'points_per_game_rank_type': 118,
#   'selected_rank': 353,
#   'selected_rank_type': 135,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 205651,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 4,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Gabriel',
#   'form': '0.0',
#   'id': 8,
#   'in_dreamteam': False,
#   'news': 'Knee injury - Unknown return date',
#   'news_added': '2023-08-02T21:00:03.961365Z',
#   'now_cost': 80,
#   'photo': '205651.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Fernando de Jesus',
#   'selected_by_percent': '2.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'i',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 1106,
#   'transfers_in_event': 1106,
#   'transfers_out': 15014,
#   'transfers_out_event': 15014,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'G.Jesus',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 636,
#   'influence_rank_type': 81,
#   'creativity_rank': 636,
#   'creativity_rank_type': 81,
#   'threat_rank': 636,
#   'threat_rank_type': 81,
#   'ict_index_rank': 636,
#   'ict_index_rank_type': 81,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': 2,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 15,
#   'now_cost_rank_type': 6,
#   'form_rank': 638,
#   'form_rank_type': 81,
#   'points_per_game_rank': 638,
#   'points_per_game_rank_type': 81,
#   'selected_rank': 116,
#   'selected_rank_type': 22,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 85955,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.6',
#   'ep_this': '2.6',
#   'event_points': 0,
#   'first_name': 'Jorge Luiz',
#   'form': '0.0',
#   'id': 9,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2023-08-07T15:30:05.168632Z',
#   'now_cost': 55,
#   'photo': '85955.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Frello Filho',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 396,
#   'transfers_in_event': 396,
#   'transfers_out': 294,
#   'transfers_out_event': 294,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Jorginho',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 508,
#   'influence_rank_type': 189,
#   'creativity_rank': 507,
#   'creativity_rank_type': 189,
#   'threat_rank': 506,
#   'threat_rank_type': 188,
#   'ict_index_rank': 508,
#   'ict_index_rank_type': 189,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 85,
#   'now_cost_rank_type': 53,
#   'form_rank': 519,
#   'form_rank_type': 197,
#   'points_per_game_rank': 519,
#   'points_per_game_rank_type': 197,
#   'selected_rank': 333,
#   'selected_rank_type': 101,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 440854,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.5',
#   'ep_this': '2.5',
#   'event_points': 0,
#   'first_name': 'Jakub',
#   'form': '0.0',
#   'id': 10,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '440854.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Kiwior',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 36,
#   'transfers_in_event': 36,
#   'transfers_out': 143,
#   'transfers_out_event': 143,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Kiwior',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 291,
#   'influence_rank_type': 171,
#   'creativity_rank': 291,
#   'creativity_rank_type': 171,
#   'threat_rank': 286,
#   'threat_rank_type': 169,
#   'ict_index_rank': 291,
#   'ict_index_rank_type': 171,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 474,
#   'now_cost_rank_type': 137,
#   'form_rank': 319,
#   'form_rank_type': 176,
#   'points_per_game_rank': 319,
#   'points_per_game_rank_type': 176,
#   'selected_rank': 426,
#   'selected_rank_type': 161,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 479683,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '1.5',
#   'ep_this': '1.5',
#   'event_points': 0,
#   'first_name': 'Marcus',
#   'form': '0.0',
#   'id': 11,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '479683.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Oliveira Alencar',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 417,
#   'transfers_in_event': 417,
#   'transfers_out': 300,
#   'transfers_out_event': 300,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Marquinhos',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 314,
#   'influence_rank_type': 56,
#   'creativity_rank': 314,
#   'creativity_rank_type': 57,
#   'threat_rank': 310,
#   'threat_rank_type': 54,
#   'ict_index_rank': 314,
#   'ict_index_rank_type': 56,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 498,
#   'now_cost_rank_type': 248,
#   'form_rank': 341,
#   'form_rank_type': 75,
#   'points_per_game_rank': 341,
#   'points_per_game_rank_type': 75,
#   'selected_rank': 359,
#   'selected_rank_type': 111,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 444145,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '3.2',
#   'ep_this': '3.2',
#   'event_points': 1,
#   'first_name': 'Gabriel',
#   'form': '1.0',
#   'id': 12,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 80,
#   'photo': '444145.jpg',
#   'points_per_game': '1.0',
#   'second_name': 'Martinelli Silva',
#   'selected_by_percent': '14.9',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 1,
#   'transfers_in': 4484,
#   'transfers_in_event': 4484,
#   'transfers_out': 2490,
#   'transfers_out_event': 2490,
#   'value_form': '0.1',
#   'value_season': '0.1',
#   'web_name': 'Martinelli',
#   'minutes': 20,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 1,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 1,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.43',
#   'influence_rank': 637,
#   'influence_rank_type': 268,
#   'creativity_rank': 637,
#   'creativity_rank_type': 268,
#   'threat_rank': 637,
#   'threat_rank_type': 268,
#   'ict_index_rank': 637,
#   'ict_index_rank_type': 268,
#   'corners_and_indirect_freekicks_order': 4,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': 3,
#   'direct_freekicks_text': '',
#   'penalties_order': 3,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.0,
#   'expected_goal_involvements_per_90': 0.0,
#   'expected_goals_conceded_per_90': 1.94,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 16,
#   'now_cost_rank_type': 9,
#   'form_rank': 50,
#   'form_rank_type': 22,
#   'points_per_game_rank': 50,
#   'points_per_game_rank_type': 22,
#   'selected_rank': 29,
#   'selected_rank_type': 9,
#   'starts_per_90': 4.5,
#   'clean_sheets_per_90': 0.0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 205533,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 4,
#   'ep_next': '2.3',
#   'ep_this': '2.3',
#   'event_points': 1,
#   'first_name': 'Eddie',
#   'form': '1.0',
#   'id': 13,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 55,
#   'photo': '205533.jpg',
#   'points_per_game': '1.0',
#   'second_name': 'Nketiah',
#   'selected_by_percent': '2.7',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 1,
#   'transfers_in': 3517,
#   'transfers_in_event': 3517,
#   'transfers_out': 1846,
#   'transfers_out_event': 1846,
#   'value_form': '0.2',
#   'value_season': '0.2',
#   'web_name': 'Nketiah',
#   'minutes': 20,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 1,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 1,
#   'expected_goals': '0.06',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.06',
#   'expected_goals_conceded': '0.43',
#   'influence_rank': 543,
#   'influence_rank_type': 50,
#   'creativity_rank': 543,
#   'creativity_rank_type': 50,
#   'threat_rank': 542,
#   'threat_rank_type': 50,
#   'ict_index_rank': 543,
#   'ict_index_rank_type': 50,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.27,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.0,
#   'expected_goal_involvements_per_90': 0.27,
#   'expected_goals_conceded_per_90': 1.94,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 121,
#   'now_cost_rank_type': 33,
#   'form_rank': 45,
#   'form_rank_type': 5,
#   'points_per_game_rank': 45,
#   'points_per_game_rank_type': 5,
#   'selected_rank': 109,
#   'selected_rank_type': 19,
#   'starts_per_90': 4.5,
#   'clean_sheets_per_90': 0.0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 184029,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '3.4',
#   'ep_this': '3.4',
#   'event_points': 1,
#   'first_name': 'Martin',
#   'form': '1.0',
#   'id': 14,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 85,
#   'photo': '184029.jpg',
#   'points_per_game': '1.0',
#   'second_name': 'Ødegaard',
#   'selected_by_percent': '24.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 1,
#   'transfers_in': 13286,
#   'transfers_in_event': 13286,
#   'transfers_out': 3314,
#   'transfers_out_event': 3314,
#   'value_form': '0.1',
#   'value_season': '0.1',
#   'web_name': 'Ødegaard',
#   'minutes': 20,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 3,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 1,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.43',
#   'influence_rank': 639,
#   'influence_rank_type': 270,
#   'creativity_rank': 639,
#   'creativity_rank_type': 270,
#   'threat_rank': 639,
#   'threat_rank_type': 270,
#   'ict_index_rank': 639,
#   'ict_index_rank_type': 270,
#   'corners_and_indirect_freekicks_order': 3,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': 1,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.0,
#   'expected_goal_involvements_per_90': 0.0,
#   'expected_goals_conceded_per_90': 1.94,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 8,
#   'now_cost_rank_type': 6,
#   'form_rank': 51,
#   'form_rank_type': 23,
#   'points_per_game_rank': 51,
#   'points_per_game_rank_type': 23,
#   'selected_rank': 15,
#   'selected_rank_type': 6,
#   'starts_per_90': 4.5,
#   'clean_sheets_per_90': 0.0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 167199,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.1',
#   'ep_this': '2.1',
#   'event_points': 1,
#   'first_name': 'Thomas',
#   'form': '1.0',
#   'id': 15,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '167199.jpg',
#   'points_per_game': '1.0',
#   'second_name': 'Partey',
#   'selected_by_percent': '0.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 1,
#   'transfers_in': 460,
#   'transfers_in_event': 460,
#   'transfers_out': 567,
#   'transfers_out_event': 567,
#   'value_form': '0.2',
#   'value_season': '0.2',
#   'web_name': 'Thomas',
#   'minutes': 20,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 3,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 1,
#   'expected_goals': '0.00',
#   'expected_assists': '0.01',
#   'expected_goal_involvements': '0.01',
#   'expected_goals_conceded': '0.43',
#   'influence_rank': 409,
#   'influence_rank_type': 123,
#   'creativity_rank': 409,
#   'creativity_rank_type': 124,
#   'threat_rank': 406,
#   'threat_rank_type': 122,
#   'ict_index_rank': 409,
#   'ict_index_rank_type': 123,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.04,
#   'expected_goal_involvements_per_90': 0.04,
#   'expected_goals_conceded_per_90': 1.94,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 209,
#   'now_cost_rank_type': 135,
#   'form_rank': 32,
#   'form_rank_type': 10,
#   'points_per_game_rank': 32,
#   'points_per_game_rank_type': 10,
#   'selected_rank': 246,
#   'selected_rank_type': 77,
#   'starts_per_90': 4.5,
#   'clean_sheets_per_90': 0.0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 195735,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.1',
#   'ep_this': '2.1',
#   'event_points': 0,
#   'first_name': 'Nicolas',
#   'form': '0.0',
#   'id': 16,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '195735.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Pépé',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 80,
#   'transfers_in_event': 80,
#   'transfers_out': 126,
#   'transfers_out_event': 126,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Pepe',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 427,
#   'influence_rank_type': 137,
#   'creativity_rank': 427,
#   'creativity_rank_type': 138,
#   'threat_rank': 424,
#   'threat_rank_type': 136,
#   'ict_index_rank': 427,
#   'ict_index_rank_type': 137,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 227,
#   'now_cost_rank_type': 149,
#   'form_rank': 448,
#   'form_rank_type': 150,
#   'points_per_game_rank': 448,
#   'points_per_game_rank_type': 150,
#   'selected_rank': 445,
#   'selected_rank_type': 155,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 225321,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 1,
#   'ep_next': '3.7',
#   'ep_this': '3.7',
#   'event_points': 1,
#   'first_name': 'Aaron',
#   'form': '1.0',
#   'id': 17,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '225321.jpg',
#   'points_per_game': '1.0',
#   'second_name': 'Ramsdale',
#   'selected_by_percent': '18.8',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 1,
#   'transfers_in': 4769,
#   'transfers_in_event': 4769,
#   'transfers_out': 3967,
#   'transfers_out_event': 3967,
#   'value_form': '0.2',
#   'value_season': '0.2',
#   'web_name': 'Ramsdale',
#   'minutes': 20,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 3,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 1,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.43',
#   'influence_rank': 452,
#   'influence_rank_type': 71,
#   'creativity_rank': 452,
#   'creativity_rank_type': 70,
#   'threat_rank': 450,
#   'threat_rank_type': 70,
#   'ict_index_rank': 452,
#   'ict_index_rank_type': 71,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.0,
#   'expected_goal_involvements_per_90': 0.0,
#   'expected_goals_conceded_per_90': 1.94,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 253,
#   'now_cost_rank_type': 11,
#   'form_rank': 37,
#   'form_rank_type': 4,
#   'points_per_game_rank': 37,
#   'points_per_game_rank_type': 4,
#   'selected_rank': 19,
#   'selected_rank_type': 3,
#   'starts_per_90': 4.5,
#   'clean_sheets_per_90': 0.0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 115918,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 1,
#   'ep_next': '1.5',
#   'ep_this': '1.5',
#   'event_points': 0,
#   'first_name': 'Rúnar Alex',
#   'form': '0.0',
#   'id': 18,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 40,
#   'photo': '115918.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Rúnarsson',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 252,
#   'transfers_in_event': 252,
#   'transfers_out': 129,
#   'transfers_out_event': 129,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Rúnarsson',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 42,
#   'influence_rank_type': 19,
#   'creativity_rank': 42,
#   'creativity_rank_type': 18,
#   'threat_rank': 37,
#   'threat_rank_type': 18,
#   'ict_index_rank': 42,
#   'ict_index_rank_type': 19,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 565,
#   'now_cost_rank_type': 47,
#   'form_rank': 82,
#   'form_rank_type': 22,
#   'points_per_game_rank': 82,
#   'points_per_game_rank_type': 22,
#   'selected_rank': 354,
#   'selected_rank_type': 54,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 223340,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '3.4',
#   'ep_this': '3.4',
#   'event_points': 1,
#   'first_name': 'Bukayo',
#   'form': '1.0',
#   'id': 19,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 85,
#   'photo': '223340.jpg',
#   'points_per_game': '1.0',
#   'second_name': 'Saka',
#   'selected_by_percent': '60.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 1,
#   'transfers_in': 21559,
#   'transfers_in_event': 21559,
#   'transfers_out': 2245,
#   'transfers_out_event': 2245,
#   'value_form': '0.1',
#   'value_season': '0.1',
#   'web_name': 'Saka',
#   'minutes': 20,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 5,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 1,
#   'expected_goals': '0.00',
#   'expected_assists': '0.10',
#   'expected_goal_involvements': '0.10',
#   'expected_goals_conceded': '0.43',
#   'influence_rank': 640,
#   'influence_rank_type': 271,
#   'creativity_rank': 640,
#   'creativity_rank_type': 271,
#   'threat_rank': 640,
#   'threat_rank_type': 271,
#   'ict_index_rank': 640,
#   'ict_index_rank_type': 271,
#   'corners_and_indirect_freekicks_order': 1,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': 1,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.45,
#   'expected_goal_involvements_per_90': 0.45,
#   'expected_goals_conceded_per_90': 1.94,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 9,
#   'now_cost_rank_type': 7,
#   'form_rank': 52,
#   'form_rank_type': 24,
#   'points_per_game_rank': 52,
#   'points_per_game_rank_type': 24,
#   'selected_rank': 2,
#   'selected_rank_type': 1,
#   'starts_per_90': 4.5,
#   'clean_sheets_per_90': 0.0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 462424,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.8',
#   'ep_this': '2.8',
#   'event_points': 1,
#   'first_name': 'William',
#   'form': '1.0',
#   'id': 20,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '462424.jpg',
#   'points_per_game': '1.0',
#   'second_name': 'Saliba',
#   'selected_by_percent': '18.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 1,
#   'transfers_in': 10947,
#   'transfers_in_event': 10947,
#   'transfers_out': 2753,
#   'transfers_out_event': 2753,
#   'value_form': '0.2',
#   'value_season': '0.2',
#   'web_name': 'Saliba',
#   'minutes': 20,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 9,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 1,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.43',
#   'influence_rank': 485,
#   'influence_rank_type': 203,
#   'creativity_rank': 484,
#   'creativity_rank_type': 203,
#   'threat_rank': 483,
#   'threat_rank_type': 203,
#   'ict_index_rank': 485,
#   'ict_index_rank_type': 203,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.0,
#   'expected_goal_involvements_per_90': 0.0,
#   'expected_goals_conceded_per_90': 1.94,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 286,
#   'now_cost_rank_type': 34,
#   'form_rank': 40,
#   'form_rank_type': 17,
#   'points_per_game_rank': 40,
#   'points_per_game_rank_type': 17,
#   'selected_rank': 20,
#   'selected_rank_type': 8,
#   'starts_per_90': 4.5,
#   'clean_sheets_per_90': 0.0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 437742,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.1',
#   'ep_this': '2.1',
#   'event_points': 0,
#   'first_name': 'Albert',
#   'form': '0.0',
#   'id': 21,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '437742.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Sambi Lokonga',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 14,
#   'transfers_in_event': 14,
#   'transfers_out': 32,
#   'transfers_out_event': 32,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Sambi',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 473,
#   'influence_rank_type': 164,
#   'creativity_rank': 472,
#   'creativity_rank_type': 164,
#   'threat_rank': 471,
#   'threat_rank_type': 163,
#   'ict_index_rank': 473,
#   'ict_index_rank_type': 164,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 274,
#   'now_cost_rank_type': 176,
#   'form_rank': 489,
#   'form_rank_type': 174,
#   'points_per_game_rank': 489,
#   'points_per_game_rank_type': 174,
#   'selected_rank': 586,
#   'selected_rank_type': 235,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 209289,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.6',
#   'ep_this': '2.6',
#   'event_points': 0,
#   'first_name': 'Emile',
#   'form': '0.0',
#   'id': 22,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 55,
#   'photo': '209289.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Smith Rowe',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 110,
#   'transfers_in_event': 110,
#   'transfers_out': 275,
#   'transfers_out_event': 275,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Smith Rowe',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
# ...
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 197,
#   'now_cost_rank_type': 7,
#   'form_rank': 423,
#   'form_rank_type': 68,
#   'points_per_game_rank': 423,
#   'points_per_game_rank_type': 68,
#   'selected_rank': 158,
#   'selected_rank_type': 21,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 88484,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '1.6',
#   'ep_this': '1.1',
#   'event_points': 0,
#   'first_name': 'Pablo',
#   'form': '0.0',
#   'id': 570,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '88484.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Sarabia',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 34,
#   'transfers_in_event': 34,
#   'transfers_out': 69,
#   'transfers_out_event': 69,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Sarabia',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 376,
#   'influence_rank_type': 99,
#   'creativity_rank': 376,
#   'creativity_rank_type': 100,
#   'threat_rank': 372,
#   'threat_rank_type': 97,
#   'ict_index_rank': 376,
#   'ict_index_rank_type': 99,
#   'corners_and_indirect_freekicks_order': 2,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': 2,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 173,
#   'now_cost_rank_type': 110,
#   'form_rank': 402,
#   'form_rank_type': 117,
#   'points_per_game_rank': 402,
#   'points_per_game_rank_type': 117,
#   'selected_rank': 438,
#   'selected_rank_type': 150,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 216208,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 1,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Matija',
#   'form': '0.0',
#   'id': 571,
#   'in_dreamteam': False,
#   'news': 'Permanent transfer to Millwall',
#   'news_added': '2023-08-07T07:47:40.181414Z',
#   'now_cost': 40,
#   'photo': '216208.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Šarkić',
#   'selected_by_percent': '0.7',
#   'special': False,
#   'squad_number': None,
#   'status': 'u',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 0,
#   'transfers_in_event': 0,
#   'transfers_out': 1154,
#   'transfers_out_event': 1154,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Šarkić',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 72,
#   'influence_rank_type': 32,
#   'creativity_rank': 72,
#   'creativity_rank_type': 31,
#   'threat_rank': 67,
#   'threat_rank_type': 31,
#   'ict_index_rank': 72,
#   'ict_index_rank_type': 32,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 595,
#   'now_cost_rank_type': 60,
#   'form_rank': 112,
#   'form_rank_type': 35,
#   'points_per_game_rank': 112,
#   'points_per_game_rank_type': 35,
#   'selected_rank': 200,
#   'selected_rank_type': 30,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 200402,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.0',
#   'ep_this': '1.5',
#   'event_points': 0,
#   'first_name': 'Nélson',
#   'form': '0.0',
#   'id': 572,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '200402.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Cabral Semedo',
#   'selected_by_percent': '0.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 59,
#   'transfers_in_event': 59,
#   'transfers_out': 129,
#   'transfers_out_event': 129,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'N.Semedo',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 215,
#   'influence_rank_type': 132,
#   'creativity_rank': 215,
#   'creativity_rank_type': 132,
#   'threat_rank': 210,
#   'threat_rank_type': 130,
#   'ict_index_rank': 215,
#   'ict_index_rank_type': 132,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 398,
#   'now_cost_rank_type': 98,
#   'form_rank': 247,
#   'form_rank_type': 139,
#   'points_per_game_rank': 247,
#   'points_per_game_rank_type': 139,
#   'selected_rank': 271,
#   'selected_rank_type': 100,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 510362,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.0',
#   'ep_this': '1.5',
#   'event_points': 0,
#   'first_name': 'Toti António',
#   'form': '0.0',
#   'id': 573,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '510362.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Gomes',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 10,
#   'transfers_in_event': 10,
#   'transfers_out': 80,
#   'transfers_out_event': 80,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Toti',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 339,
#   'influence_rank_type': 183,
#   'creativity_rank': 339,
#   'creativity_rank_type': 183,
#   'threat_rank': 335,
#   'threat_rank_type': 182,
#   'ict_index_rank': 339,
#   'ict_index_rank_type': 183,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 523,
#   'now_cost_rank_type': 150,
#   'form_rank': 366,
#   'form_rank_type': 187,
#   'points_per_game_rank': 366,
#   'points_per_game_rank_type': 187,
#   'selected_rank': 439,
#   'selected_rank_type': 166,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 476502,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '1.0',
#   'ep_this': '0.5',
#   'event_points': 0,
#   'first_name': 'Boubacar',
#   'form': '0.0',
#   'id': 574,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '476502.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Traoré',
#   'selected_by_percent': '0.6',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 331,
#   'transfers_in_event': 331,
#   'transfers_out': 448,
#   'transfers_out_event': 448,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Boubacar Traore',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 309,
#   'influence_rank_type': 52,
#   'creativity_rank': 309,
#   'creativity_rank_type': 53,
#   'threat_rank': 304,
#   'threat_rank_type': 50,
#   'ict_index_rank': 309,
#   'ict_index_rank_type': 52,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 492,
#   'now_cost_rank_type': 244,
#   'form_rank': 336,
#   'form_rank_type': 71,
#   'points_per_game_rank': 336,
#   'points_per_game_rank_type': 71,
#   'selected_rank': 217,
#   'selected_rank_type': 69,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': 75,
#   'chance_of_playing_this_round': 75,
#   'code': 430871,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 4,
#   'ep_next': '1.4',
#   'ep_this': '1.0',
#   'event_points': 0,
#   'first_name': 'Matheus',
#   'form': '0.0',
#   'id': 590,
#   'in_dreamteam': False,
#   'news': 'Knock - 75% chance of playing',
#   'news_added': '2023-08-11T13:30:07.246810Z',
#   'now_cost': 55,
#   'photo': '430871.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Santos Carneiro Da Cunha',
#   'selected_by_percent': '0.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'd',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 76,
#   'transfers_in_event': 76,
#   'transfers_out': 797,
#   'transfers_out_event': 797,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Cunha',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 555,
#   'influence_rank_type': 51,
#   'creativity_rank': 555,
#   'creativity_rank_type': 51,
#   'threat_rank': 554,
#   'threat_rank_type': 51,
#   'ict_index_rank': 555,
#   'ict_index_rank_type': 51,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': 1,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 134,
#   'now_cost_rank_type': 34,
#   'form_rank': 562,
#   'form_rank_type': 52,
#   'points_per_game_rank': 562,
#   'points_per_game_rank_type': 52,
#   'selected_rank': 291,
#   'selected_rank_type': 52,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 87835,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '2.0',
#   'ep_this': '1.5',
#   'event_points': 0,
#   'first_name': 'Matt',
#   'form': '0.0',
#   'id': 598,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '87835.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Doherty',
#   'selected_by_percent': '0.3',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 70,
#   'transfers_in_event': 70,
#   'transfers_out': 109,
#   'transfers_out_event': 109,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Doherty',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 151,
#   'influence_rank_type': 87,
#   'creativity_rank': 151,
#   'creativity_rank_type': 87,
#   'threat_rank': 146,
#   'threat_rank_type': 85,
#   'ict_index_rank': 151,
#   'ict_index_rank_type': 87,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 334,
#   'now_cost_rank_type': 53,
#   'form_rank': 187,
#   'form_rank_type': 98,
#   'points_per_game_rank': 187,
#   'points_per_game_rank_type': 98,
#   'selected_rank': 267,
#   'selected_rank_type': 98,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0}]

# %%
df1 = pd.read_csv("data/upcoming_fixtures.csv")
# Out:
# C:\users\user\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3369: DtypeWarning: Columns (2,3,4,7,8,36,42,43,44,45,46,59,82,83,84) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.shape
# Out:
# (38663, 87)

# %%
# NaNs
df1[["Team rating"]].isna().sum().sort_values(ascending=False)
# Out:
# Team rating    24573
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38663 entries, 0 to 38662
# Data columns (total 87 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         38663 non-null  int64
#  1   Date               38663 non-null  object
#  2   Day                24573 non-null  object
#  3   Venue              24573 non-null  object
#  4   Team               24573 non-null  object
#  5   Opponent           38663 non-null  object
#  6   Name               38663 non-null  object
#  7   Start              24573 non-null  object
#  8   Pos                24550 non-null  object
#  9   Min                24570 non-null  float64
#  10  Gls                24573 non-null  float64
#  11  Ast                24573 non-null  float64
#  12  PK                 24573 non-null  float64
#  13  PKatt              24573 non-null  float64
#  14  Sh                 24573 non-null  float64
#  15  SoT                24573 non-null  float64
#  16  CrdY               24573 non-null  float64
#  17  CrdR               24573 non-null  float64
#  18  Touches            24378 non-null  float64
#  19  Tkl                24378 non-null  float64
#  20  Int                24573 non-null  float64
#  21  Blocks             24378 non-null  float64
#  22  xG                 24378 non-null  float64
#  23  npxG               24378 non-null  float64
#  24  xA                 24378 non-null  float64
#  25  SCA                24378 non-null  float64
#  26  GCA                24378 non-null  float64
#  27  Cmp                24378 non-null  float64
#  28  Att                24378 non-null  float64
#  29  Cmp%               24167 non-null  float64
#  30  PrgP               24378 non-null  float64
#  31  Carries            24378 non-null  float64
#  32  PrgC               24378 non-null  float64
#  33  T_att              24378 non-null  float64
#  34  T_succ             24378 non-null  float64
#  35  Season             38663 non-null  object
#  36  WDL                24573 non-null  object
#  37  Team_score         24573 non-null  float64
#  38  Opp_score          24573 non-null  float64
#  39  Team_CS            24573 non-null  float64
#  40  Was_home           38663 non-null  float64
#  41  GW                 38663 non-null  float64
#  42  Clean_name         24573 non-null  object
#  43  FPL_name           24573 non-null  object
#  44  FPL_team           24573 non-null  object
#  45  FPL_opp_team       24573 non-null  object
#  46  Name_original      22151 non-null  object
#  47  FPL_pos            35710 non-null  object
#  48  FPL_ast            22151 non-null  float64
#  49  Bonus              22151 non-null  float64
#  50  Bps                22151 non-null  float64
#  51  Player_CS          22151 non-null  float64
#  52  Creativity         22151 non-null  float64
#  53  Element            22151 non-null  float64
#  54  Fixture            22151 non-null  float64
#  55  Player_GC          22151 non-null  float64
#  56  Goals_scored       22151 non-null  float64
#  57  ICT_index          22151 non-null  float64
#  58  Influence          22151 non-null  float64
#  59  Kickoff_time       22151 non-null  object
#  60  FPL_min            22151 non-null  float64
#  61  Own_goals          22151 non-null  float64
#  62  Penalties_missed   22151 non-null  float64
#  63  Penalties_saved    22151 non-null  float64
#  64  Saves              22151 non-null  float64
#  65  Selected           22151 non-null  float64
#  66  Threat             22151 non-null  float64
#  67  FPL_points         22151 non-null  float64
#  68  Transfers_balance  22151 non-null  float64
#  69  Transfers_in       22151 non-null  float64
#  70  Transfers_out      22151 non-null  float64
#  71  Value              22151 non-null  float64
#  72  FPL_GW             22151 non-null  float64
#  73  xP                 14128 non-null  float64
#  74  FPL_xA             14128 non-null  float64
#  75  FPL_xGI            14128 non-null  float64
#  76  FPL_xG             14128 non-null  float64
#  77  FPL_xGC            14128 non-null  float64
#  78  Opp_rating         24047 non-null  float64
#  79  Team_rating        24542 non-null  float64
#  80  Min_points         0 non-null      float64
#  81  Finished           38663 non-null  bool
#  82  Squad              14090 non-null  object
#  83  Squad H            14090 non-null  object
#  84  Squad A            14090 non-null  object
#  85  Opp rating         14090 non-null  float64
#  86  Team rating        14090 non-null  float64
# dtypes: bool(1), float64(65), int64(1), object(20)
# memory usage: 25.4+ MB

# %%
df1.describe()
# Out:
#          Unnamed: 0           Min           Gls           Ast            PK  \
# count  38663.000000  24570.000000  24573.000000  24573.000000  24573.000000
# mean    9092.125779     54.403541      0.077850      0.054694      0.005819
# std     7161.027541     38.821960      0.299769      0.243463      0.079209
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     3221.500000      7.000000      0.000000      0.000000      0.000000
# 50%     6443.000000     75.000000      0.000000      0.000000      0.000000
# 75%    14906.500000     90.000000      0.000000      0.000000      0.000000
# max    24572.000000     90.000000      4.000000      3.000000      2.000000
#
#               PKatt            Sh           SoT          CrdY          CrdR  \
# count  24573.000000  24573.000000  24573.000000  24573.000000  24573.000000
# mean       0.007488      0.698287      0.233020      0.098808      0.002604
# std        0.089907      1.169487      0.565494      0.302339      0.050969
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      1.000000      0.000000      0.000000      0.000000
# max        2.000000     11.000000      5.000000      2.000000      1.000000
#
#        ...            xP        FPL_xA       FPL_xGI        FPL_xG  \
# count  ...  14128.000000  14128.000000  14128.000000  14128.000000
# mean   ...      2.183126      0.030140      0.074943      0.050075
# std    ...      2.390554      0.088199      0.193966      0.159853
# min    ...     -3.000000      0.000000      0.000000      0.000000
# 25%    ...      0.500000      0.000000      0.000000      0.000000
# 50%    ...      1.500000      0.000000      0.000000      0.000000
# 75%    ...      3.200000      0.011425      0.040000      0.000000
# max    ...     23.600000      1.285270      2.380000      2.370000
#
#             FPL_xGC    Opp_rating   Team_rating  Min_points    Opp rating  \
# count  14128.000000  24047.000000  24542.000000         0.0  14090.000000
# mean       0.546999   1784.406199   1788.778345         NaN   1788.313465
# std        0.817357    108.176336    108.325591         NaN    111.202981
# min        0.000000   1588.183105   1588.285278         NaN   1606.522583
# 25%        0.000000   1706.252930   1710.515381         NaN   1708.234497
# 50%        0.000000   1756.213135   1758.774292         NaN   1779.449829
# 75%        0.920000   1854.798462   1857.627441         NaN   1828.169067
# max        5.130000   2091.929932   2091.929932         NaN   2077.251953
#
#         Team rating
# count  14090.000000
# mean    1801.155442
# std      103.979910
# min     1660.637939
# 25%     1719.037964
# 50%     1788.094360
# 75%     1873.631104
# max     2077.251953
#
# [8 rows x 66 columns]

# %%
df_final = pd.read_csv("data/final_dataset.csv")
# Out:
# C:\users\user\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3369: DtypeWarning: Columns (53) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_final.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Day', 'Comp', 'Round', 'Venue', 'Squad',
#        'Opponent', 'Start', 'Pos',
#        ...
#        'MinAvgOverall', 'GlsAvgOverall', 'AstAvgOverall', 'CrdYAvgOverall',
#        'CrdRAvgOverall', 'xGAvgOverall', 'xAGAvgOverall', 'CSAvgOverall',
#        'Team ScoreAvgOverall', 'Opp ScoreAvgOverall'],
#       dtype='object', length=118)

# %%
df_final[df_final["Name"] == "Mohamed-Salah"]
