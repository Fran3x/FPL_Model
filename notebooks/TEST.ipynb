# %%
import os
os.chdir("D:\PulpitE\FPL_ML")

# %%
import pandas as pd

# %%
df1 = pd.read_csv("data/fpl_fbref_players.csv")

# %%
df2 = pd.read_csv("data/fpl_fbref_players2.csv")
# Out:
# C:\users\user\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3369: DtypeWarning: Columns (54) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24683 entries, 0 to 24682
# Data columns (total 58 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    24683 non-null  int64
#  1   Unnamed: 0.1  24683 non-null  int64
#  2   Date          24683 non-null  object
#  3   Day           24683 non-null  object
#  4   Comp          24683 non-null  object
#  5   Round         24683 non-null  object
#  6   Venue         24683 non-null  object
#  7   Squad         24683 non-null  object
#  8   Opponent      24683 non-null  object
#  9   Start         24683 non-null  object
#  10  Pos           24640 non-null  object
#  11  Min           24680 non-null  float64
#  12  Gls           24683 non-null  float64
#  13  Ast           24683 non-null  float64
#  14  PK            24683 non-null  float64
#  15  PKatt         24683 non-null  float64
#  16  Sh            24583 non-null  float64
#  17  SoT           24583 non-null  float64
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0_x', 'Date', 'Day', 'Comp', 'Round', 'Venue',
#        'Squad', 'Opponent', 'Start',
#        ...
#        'was_home', 'yellow_cards', 'GW_y', 'xP', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'starts', 'neutral_name_y'],
#       dtype='object', length=105)

# %%
df2.describe()
# Out:
#          Unnamed: 0  Unnamed: 0_x           Min           Gls           Ast  \
# count  24683.000000  24683.000000  24680.000000  24683.000000  24683.000000
# mean   12341.000000     24.415104     54.452796      0.078394      0.055139
# std     7125.512683     15.395819     38.799696      0.300670      0.245365
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     6170.500000     11.000000      7.000000      0.000000      0.000000
# 50%    12341.000000     24.000000     75.000000      0.000000      0.000000
# 75%    18511.500000     36.000000     90.000000      0.000000      0.000000
# max    24682.000000     86.000000     90.000000      4.000000      3.000000
#
#                  PK         PKatt            Sh           SoT          CrdY  \
# count  24683.000000  24683.000000  24583.000000  24583.000000  24683.000000
# mean       0.005915      0.007617      0.698003      0.232925      0.098894
# ...

# %%
df1.describe()

# %%
df_final = pd.read_csv("data/final_dataset.csv")
# Out:
# C:\users\user\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3369: DtypeWarning: Columns (53) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_final.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Day', 'Comp', 'Round', 'Venue', 'Squad',
#        'Opponent', 'Start', 'Pos', 'Min', 'Gls', 'Ast', 'PK', 'PKatt', 'Sh',
#        'SoT', 'CrdY', 'CrdR', 'Touches', 'Tkl', 'Int', 'Blocks', 'xG', 'npxG',
#        'xAG', 'SCA', 'GCA', 'Cmp', 'Att', 'Cmp%', 'PrgP', 'Carries', 'PrgC',
#        'Att.1', 'Succ', 'Match Report', 'Name', 'Season', 'Fls', 'Fld', 'Off',
#        'Crs', 'TklW', 'OG', 'PKwon', 'PKcon', 'WDL', 'GoalsTeams',
#        'Team Score', 'Opp Score', 'CS', 'Was Home', 'GW', 'neutral_name',
#        'Total Points', 'FPL position', 'Opp rating', 'Team rating',
#        'ScoreForLast5', 'ScoreAgainstLast5', 'MinAvgOverall', 'GlsAvgOverall',
#        'AstAvgOverall', 'CrdYAvgOverall', 'CrdRAvgOverall', 'xGAvgOverall',
#        'xAGAvgOverall', 'CSAvgOverall', 'Team ScoreAvgOverall',
#        'Opp ScoreAvgOverall'],
#       dtype='object')

# %%
df_final[""].unique()

# %%
df_final[df_final["Name"] == "Mohamed-Salah"]
# Out:
#        Unnamed: 0        Date  Day            Comp         Round Venue  \
# 17289       17289  2021-08-14  Sat  Premier League   Matchweek 1  Away
# 17290       17290  2021-08-21  Sat  Premier League   Matchweek 2  Home
# 17291       17291  2021-08-28  Sat  Premier League   Matchweek 3  Home
# 17292       17292  2021-09-12  Sun  Premier League   Matchweek 4  Away
# 17293       17293  2021-09-18  Sat  Premier League   Matchweek 5  Home
# ...           ...         ...  ...             ...           ...   ...
# 17357       17357  2023-05-03  Wed  Premier League  Matchweek 28  Home
# 17358       17358  2023-05-06  Sat  Premier League  Matchweek 35  Home
# 17359       17359  2023-05-15  Mon  Premier League  Matchweek 36  Away
# 17360       17360  2023-05-20  Sat  Premier League  Matchweek 37  Home
# 17361       17361  2023-05-28  Sun  Premier League  Matchweek 38  Away
#
#            Squad        Opponent Start    Pos  ...  MinAvgOverall  \
# ...
