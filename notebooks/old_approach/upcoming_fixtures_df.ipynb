# %% [markdown]
# # Imports

# %%
import os
os.chdir("D:\PulpitE\FPL_ML")

# %%
import pandas as pd
import numpy as np
from vaastav.getters import *
from datetime import datetime

# %% [markdown]
# # Constants

# %%
NEXT_GW = 25

# fixtures in sample
FIS = 8

CURRENT_SEASON = '2022-23'

# %% [markdown]
# # Upcoming fixtures

# %%
fixtures = get_fixtures_data()

# %%
df_fixtures = pd.DataFrame(fixtures)

# %%
df_fixtures
# Out:
#         code  event  finished  finished_provisional   id  \
# 0    2367552    NaN     False                 False   15
# 1    2367713    NaN     False                 False  176
# 2    2367538    1.0     False                 False    1
# 3    2367540    1.0     False                 False    2
# 4    2367539    1.0     False                 False    3
# ..       ...    ...       ...                   ...  ...
# 375  2367913   38.0     False                 False  376
# 376  2367914   38.0     False                 False  377
# 377  2367915   38.0     False                 False  378
# 378  2367916   38.0     False                 False  379
# 379  2367917   38.0     False                 False  380
#
#              kickoff_time  minutes  provisional_start_time started  team_a  \
# 0                    None        0                   False    None       6
# 1                    None        0                   False    None       4
# 2    2023-08-11T19:00:00Z        0                   False   False      13
# 3    2023-08-12T11:30:00Z        0                   False   False      16
# 4    2023-08-12T14:00:00Z        0                   False   False      19
# ..                    ...      ...                     ...     ...     ...
# 375  2024-05-19T15:00:00Z        0                   False   False       2
# 376  2024-05-19T15:00:00Z        0                   False   False      20
# 377  2024-05-19T15:00:00Z        0                   False   False      10
# 378  2024-05-19T15:00:00Z        0                   False   False      19
# 379  2024-05-19T15:00:00Z        0                   False   False      18
#
#     team_a_score  team_h team_h_score stats  team_h_difficulty  \
# 0           None      12         None    []                  2
# 1           None      13         None    []                  3
# 2           None       6         None    []                  5
# 3           None       1         None    []                  2
# 4           None       3         None    []                  2
# ..           ...     ...          ...   ...                ...
# 375         None       8         None    []                  3
# 376         None      11         None    []                  2
# 377         None      12         None    []                  2
# 378         None      13         None    []                  2
# 379         None      17         None    []                  3
#
#      team_a_difficulty  pulse_id
# 0                    2     93335
# 1                    5     93496
# 2                    2     93321
# 3                    4     93322
# 4                    2     93323
# ..                 ...       ...
# 375                  2     93696
# 376                  4     93697
# 377                  2     93698
# 378                  5     93699
# 379                  2     93700
#
# [380 rows x 17 columns]

# %%
df_upcoming_fixtures = df_fixtures[df_fixtures["event"] >= NEXT_GW]

# %%
def team_id_to_name(team_id):
    teams = ['Arsenal',
     'Aston Villa',
     'Bournemouth',
     'Brentford',
     'Brighton',
     'Chelsea',
     'Crystal Palace',
     'Everton',
     'Fulham',
     'Leicester City',
     'Leeds United',
     'Liverpool',
     'Manchester City',
     'Manchester Utd',
     'Newcastle Utd',
     "Nott'ham Forest",
     'Southampton',
     'Tottenham',
     'West Ham',
     'Wolves']
    return teams[team_id - 1]

# %%
df_upcoming_fixtures["Squad H"] = df_upcoming_fixtures["team_h"].apply(team_id_to_name)
df_upcoming_fixtures["Squad A"] = df_upcoming_fixtures["team_a"].apply(team_id_to_name)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13536\3776683092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_upcoming_fixtures["Squad H"] = df_upcoming_fixtures["team_h"].apply(team_id_to_name)
# C:\Users\user\AppData\Local\Temp\ipykernel_13536\3776683092.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_upcoming_fixtures["Squad A"] = df_upcoming_fixtures["team_a"].apply(team_id_to_name)

# %%
df_upcoming_fixtures.rename(columns={"event": "GW"}, inplace=True)
# Out:
# C:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
# df_upcoming_fixtures

# %%
df_upcoming_fixtures = df_upcoming_fixtures[["GW", "kickoff_time", "Squad H", "Squad A"]]

# %%
df_upcoming_fixtures["kickoff_time"] = df_upcoming_fixtures["kickoff_time"].str[:10]

# %%
# df_upcoming_fixtures.head(15)

# %% [markdown]
# # Active players

# %%
def get_active_players():
    previous_fixtures = pd.read_csv("data/final_dataset.csv")
    name_counts = previous_fixtures.groupby('Name').size()
    filtered_names = name_counts[name_counts >= FIS].index
    result = previous_fixtures[previous_fixtures['Name'].isin(filtered_names)].groupby('Name').tail(1)
    result = result.loc[:, ~result.columns.str.contains('^Unnamed')]
    return result

# %%
active_players = get_active_players()

# %%
active_players[["Name", "Squad", "FPL position"]]
# Out:
#                      Name         Squad FPL position
# 18       Brenden-Aaronson  Leeds United          MID
# 38              Che-Adams   Southampton          FWD
# 55            Tyler-Adams  Leeds United          MID
# 76       Tosin-Adarabioyo        Fulham          DEF
# 101       Rayan-Ait-Nouri        Wolves          DEF
# ...                   ...           ...          ...
# 7392        Jordan-Zemura   Bournemouth          DEF
# 7404  Oleksandr-Zinchenko       Arsenal          DEF
# 7422         Hakim-Ziyech       Chelsea          MID
# 7438           Kurt-Zouma      West Ham          DEF
# 7456      Martin-Odegaard       Arsenal          MID
#
# [434 rows x 3 columns]

# %%
picked_columns = ["Name", "GW", "kickoff_time", "Squad", "Squad H", "Squad A", "Was Home", "Opponent", "FPL position"]

# %%
upcoming_player_fixtures_home = active_players.rename(columns={"Squad": "Squad H"}).drop(columns=["GW"]).set_index(["Squad H"]).join(df_upcoming_fixtures.set_index(["Squad H"])).reset_index(level=0)
upcoming_player_fixtures_home["Squad"] = upcoming_player_fixtures_home["Squad H"]
upcoming_player_fixtures_home["Was Home"] = 1
# upcoming_player_fixtures_home.loc[upcoming_player_fixtures_home["GW_left"].isnull(), "GW_left"] = 77
# upcoming_player_fixtures_home['C'] = upcoming_player_fixtures_home['GW_left'].fillna(upcoming_player_fixtures_home['GW_right'])
upcoming_player_fixtures_home["Opponent"] = upcoming_player_fixtures_home["Squad A"]
upcoming_player_fixtures_home = upcoming_player_fixtures_home[picked_columns]

# %%
# upcoming_player_fixtures_home

# %%
upcoming_player_fixtures_home['GW'].unique()
# Out:
# array([25., 26., 28., 29., 32., 34., 36., 38., 30., 31., 33., 27., 35.,
#        37.])

# %%
upcoming_player_fixtures_away = active_players.rename(columns={"Squad": "Squad A"}).drop(columns=["GW"]).set_index("Squad A").join(df_upcoming_fixtures.set_index("Squad A")).reset_index(level=0)
upcoming_player_fixtures_away["Squad"] = upcoming_player_fixtures_away["Squad A"]
upcoming_player_fixtures_away["Was Home"] = 0
upcoming_player_fixtures_away["Opponent"] = upcoming_player_fixtures_away["Squad H"]
upcoming_player_fixtures_away = upcoming_player_fixtures_away[picked_columns]

# %%
upcoming_player_fixtures = pd.concat([upcoming_player_fixtures_home, upcoming_player_fixtures_away]).sort_values(by=["Name", "GW"])

# %%
upcoming_player_fixtures["Season"] = CURRENT_SEASON
upcoming_player_fixtures["Finished"] = False

# %%
upcoming_player_fixtures = upcoming_player_fixtures.rename(columns={"kickoff_time": "Date"})

# %%
# upcoming_player_fixtures[upcoming_player_fixtures["Name"] == "Gabriel-Dos-Santos"]

# %%
upcoming_player_fixtures
# Out:
#                  Name    GW        Date      Squad          Squad H  \
# 2930  Aaron-Cresswell  25.0  2023-02-25   West Ham         West Ham
# 2922  Aaron-Cresswell  26.0  2023-03-04   West Ham         Brighton
# 2931  Aaron-Cresswell  27.0  2023-03-12   West Ham         West Ham
# 2923  Aaron-Cresswell  28.0  2023-03-19   West Ham  Manchester City
# 2932  Aaron-Cresswell  29.0  2023-04-02   West Ham         West Ham
# ...               ...   ...         ...        ...              ...
# 2723    Yves-Bissouma  34.0  2023-04-30  Tottenham        Liverpool
# 2726    Yves-Bissouma  35.0  2023-05-06  Tottenham        Tottenham
# 2724    Yves-Bissouma  36.0  2023-05-13  Tottenham      Aston Villa
# 2727    Yves-Bissouma  37.0  2023-05-20  Tottenham        Tottenham
# 2725    Yves-Bissouma  38.0  2023-05-28  Tottenham     Leeds United
#
#               Squad A  Was Home         Opponent FPL position   Season  ...  \
# 2930  Nott'ham Forest         1  Nott'ham Forest          DEF  2022-23  ...
# 2922         West Ham         0         Brighton          DEF  2022-23  ...
# 2931      Aston Villa         1      Aston Villa          DEF  2022-23  ...
# 2923         West Ham         0  Manchester City          DEF  2022-23  ...
# 2932      Southampton         1      Southampton          DEF  2022-23  ...
# ...               ...       ...              ...          ...      ...  ...
# 2723        Tottenham         0        Liverpool          MID  2022-23  ...
# 2726   Crystal Palace         1   Crystal Palace          MID  2022-23  ...
# 2724        Tottenham         0      Aston Villa          MID  2022-23  ...
# 2727        Brentford         1        Brentford          MID  2022-23  ...
# 2725        Tottenham         0     Leeds United          MID  2022-23  ...
#
#       CrdYAvgOverall  CrdRAvgOverall  xGAvgOverall  xAGAvgOverall  \
# 2930        0.105263             0.0      0.005263       0.131579
# 2922        0.105263             0.0      0.005263       0.131579
# 2931        0.105263             0.0      0.005263       0.131579
# 2923        0.105263             0.0      0.005263       0.131579
# 2932        0.105263             0.0      0.005263       0.131579
# ...              ...             ...           ...            ...
# 2723        0.250000             0.0      0.000000       0.025000
# 2726        0.250000             0.0      0.000000       0.025000
# 2724        0.250000             0.0      0.000000       0.025000
# 2727        0.250000             0.0      0.000000       0.025000
# 2725        0.250000             0.0      0.000000       0.025000
#
#       CSAvgOverall  Team ScoreAvgOverall  Opp ScoreAvgOverall  FPLAvgOverall  \
# 2930      0.210526              0.842105             1.210526       2.105263
# 2922      0.210526              0.842105             1.210526       2.105263
# 2931      0.210526              0.842105             1.210526       2.105263
# 2923      0.210526              0.842105             1.210526       2.105263
# 2932      0.210526              0.842105             1.210526       2.105263
# ...            ...                   ...                  ...            ...
# 2723      0.250000              1.800000             1.550000       1.600000
# 2726      0.250000              1.800000             1.550000       1.600000
# 2724      0.250000              1.800000             1.550000       1.600000
# 2727      0.250000              1.800000             1.550000       1.600000
# 2725      0.250000              1.800000             1.550000       1.600000
#
#       ScoreForLast5  ScoreAgainstLast5
# 2930            1.0                1.6
# 2922            1.0                1.6
# 2931            1.0                1.6
# 2923            1.0                1.6
# 2932            1.0                1.6
# ...             ...                ...
# 2723            1.0                2.0
# 2726            1.0                2.0
# 2724            1.0                2.0
# 2727            1.0                2.0
# 2725            1.0                2.0
#
# [6422 rows x 26 columns]

# %%
upcoming_player_fixtures.shape
# Out:
# (6422, 11)

# %% [markdown]
# # Loading previous fixtures

# %%
previous_fixtures = pd.read_csv("data/final_dataset.csv")

# %%
previous_fixtures["Finished"] = True

# %% [markdown]
# # Assigning team elo

# %%
team_ratings = pd.read_csv("data/team_ratings_history.csv")

# %%
# function to assign rating for team
def get_rating_for_team(team_ratings, team_name, date):
    rating = None
    try:
        rating = team_ratings[(team_ratings['From'] <= date.strftime("%Y-%m-%d")) & (team_ratings['Club'] == team_name)].iloc[-1]['Elo']
    except:
        print(team_name, date)
    return rating

# %%
def fbref_to_team_elo(team_name):
    # changes name of a team
    if team_name == "Leicester City":
        return "Leicester"
    if team_name == "Manchester City":
        return "Man City"
    if team_name == "Manchester Utd":
        return "Man United"
    if team_name == "Newcastle Utd":
        return "Newcastle"
    if team_name == "Nott'ham Forest":
        return "Forest"
    if team_name == "Leeds United":
        return "Leeds"
    return team_name

# %%
# %%time
upcoming_player_fixtures["Opp rating"] = upcoming_player_fixtures.apply(lambda row : get_rating_for_team(team_ratings,
                     fbref_to_team_elo(row['Opponent']), datetime.strptime(row['Date'], '%Y-%m-%d')), axis=1)
# Out:
# CPU times: total: 1min 25s
# Wall time: 1min 29s

# %%
# %%time
upcoming_player_fixtures["Team rating"] = upcoming_player_fixtures.apply(lambda row : get_rating_for_team(team_ratings,
                     fbref_to_team_elo(row['Squad']), datetime.strptime(row['Date'], '%Y-%m-%d')), axis=1)
# Out:
# CPU times: total: 1min 19s
# Wall time: 1min 20s

# %%
upcoming_player_fixtures[upcoming_player_fixtures["Name"] == "Gabriel-Dos-Santos"]
# Out:
#                  Name    GW        Date    Squad          Squad H  \
# 0  Gabriel-Dos-Santos  25.0  2023-03-01  Arsenal          Arsenal
# 0  Gabriel-Dos-Santos  25.0  2023-02-25  Arsenal   Leicester City
# 1  Gabriel-Dos-Santos  26.0  2023-03-04  Arsenal          Arsenal
# 1  Gabriel-Dos-Santos  27.0  2023-03-12  Arsenal           Fulham
# 2  Gabriel-Dos-Santos  28.0  2023-03-19  Arsenal          Arsenal
# 3  Gabriel-Dos-Santos  29.0  2023-04-01  Arsenal          Arsenal
# 2  Gabriel-Dos-Santos  30.0  2023-04-09  Arsenal        Liverpool
# 3  Gabriel-Dos-Santos  31.0  2023-04-16  Arsenal         West Ham
# 4  Gabriel-Dos-Santos  32.0  2023-04-21  Arsenal          Arsenal
# 4  Gabriel-Dos-Santos  33.0  2023-04-26  Arsenal  Manchester City
# 5  Gabriel-Dos-Santos  34.0  2023-04-29  Arsenal          Arsenal
# 5  Gabriel-Dos-Santos  35.0  2023-05-06  Arsenal    Newcastle Utd
# 6  Gabriel-Dos-Santos  36.0  2023-05-13  Arsenal          Arsenal
# 6  Gabriel-Dos-Santos  37.0  2023-05-20  Arsenal  Nott'ham Forest
# 7  Gabriel-Dos-Santos  38.0  2023-05-28  Arsenal          Arsenal
#
#           Squad A  Was Home         Opponent FPL position   Season  Finished  \
# 0         Everton         1          Everton          DEF  2022-23     False
# 0         Arsenal         0   Leicester City          DEF  2022-23     False
# 1     Bournemouth         1      Bournemouth          DEF  2022-23     False
# 1         Arsenal         0           Fulham          DEF  2022-23     False
# 2  Crystal Palace         1   Crystal Palace          DEF  2022-23     False
# 3    Leeds United         1     Leeds United          DEF  2022-23     False
# 2         Arsenal         0        Liverpool          DEF  2022-23     False
# 3         Arsenal         0         West Ham          DEF  2022-23     False
# 4     Southampton         1      Southampton          DEF  2022-23     False
# 4         Arsenal         0  Manchester City          DEF  2022-23     False
# 5         Chelsea         1          Chelsea          DEF  2022-23     False
# 5         Arsenal         0    Newcastle Utd          DEF  2022-23     False
# 6        Brighton         1         Brighton          DEF  2022-23     False
# 6         Arsenal         0  Nott'ham Forest          DEF  2022-23     False
# 7          Wolves         1           Wolves          DEF  2022-23     False
#
#     Opp rating  Team rating
# 0  1667.462280  1946.912109
# 0  1746.499023  1946.912109
# 1  1636.081665  1946.912109
# 1  1717.072754  1946.912109
# 2  1742.434937  1946.912109
# 3  1708.115723  1946.912109
# 2  1963.465210  1946.912109
# 3  1748.305420  1946.912109
# 4  1651.960449  1946.912109
# 4  2026.310791  1946.912109
# 5  1870.791016  1946.912109
# 5  1855.404907  1946.912109
# 6  1822.430054  1946.912109
# 6  1655.643188  1946.912109
# 7  1695.581787  1946.912109

# %% [markdown]
# # Adding features

# %%
# %%time
# calculating features for every player
overall_average_columns = ["Min", "Gls", "Ast", "CrdY", "CrdR", "xG", "xAG", "CS", "Team Score", "Opp Score", "FPL"]

for name in upcoming_player_fixtures["Name"].unique():
    for col in overall_average_columns:
        value = previous_fixtures[previous_fixtures["Name"] == name][col].mean()
        upcoming_player_fixtures.loc[upcoming_player_fixtures["Name"] == name, col + "AvgOverall"] = value
        
    upcoming_player_fixtures.loc[upcoming_player_fixtures["Name"] == name, 'ScoreForLast5'] = previous_fixtures[previous_fixtures["Name"] == name]['Team Score'].tail(5).mean()
    upcoming_player_fixtures.loc[upcoming_player_fixtures["Name"] == name, 'ScoreAgainstLast5'] = previous_fixtures[previous_fixtures["Name"] == name]['Opp Score'].tail(5).mean()
# Out:
# CPU times: total: 9.61 s
# Wall time: 9.75 s

# %%
upcoming_player_fixtures.columns
# Out:
# Index(['Name', 'GW', 'Date', 'Squad', 'Squad H', 'Squad A', 'Was Home',
#        'Opponent', 'FPL position', 'Season', 'Finished', 'Opp rating',
#        'Team rating', 'MinAvgOverall', 'GlsAvgOverall', 'AstAvgOverall',
#        'CrdYAvgOverall', 'CrdRAvgOverall', 'xGAvgOverall', 'xAGAvgOverall',
#        'CSAvgOverall', 'Team ScoreAvgOverall', 'Opp ScoreAvgOverall',
#        'FPLAvgOverall', 'ScoreForLast5', 'ScoreAgainstLast5'],
#       dtype='object')

# %% [markdown]
# # Concat dataframes

# %%
all_fixtures = pd.concat([previous_fixtures, upcoming_player_fixtures])

# %%
# all_fixtures.tail(20)

# %%
all_fixtures.to_csv("data/upcoming_fixtures.csv")
