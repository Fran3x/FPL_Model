# %%
from understat import *
import getters as g
from mergers import *
from cleaners import *
from data_prep import *

from next_gameweek import *
import pandas as pd

# %%
data = get_fixtures_data()
data[50]
# Out:
# {'code': 2292864,
#  'event': 6,
#  'finished': False,
#  'finished_provisional': False,
#  'id': 55,
#  'kickoff_time': '2022-09-03T11:30:00Z',
#  'minutes': 0,
#  'provisional_start_time': False,
#  'started': False,
#  'team_a': 12,
#  'team_a_score': None,
#  'team_h': 8,
#  'team_h_score': None,
#  'stats': [],
#  'team_h_difficulty': 5,
#  'team_a_difficulty': 2,
#  'pulse_id': 74965}

# %%
data = get_entry_gws_data(1, 1)
# data

# %%
data = pd.read_csv('data/2022-23/fixtures.csv')
data
# Out:
#         code  event  finished  finished_provisional   id  \
# 0    2292810      1      True                  True    1
# 1    2292813      1      True                  True    4
# 2    2292811      1      True                  True    2
# 3    2292814      1      True                  True    5
# 4    2292816      1      True                  True    7
# ..       ...    ...       ...                   ...  ...
# 375  2293185     38     False                 False  376
# 376  2293186     38     False                 False  377
# 377  2293187     38     False                 False  378
# 378  2293188     38     False                 False  379
# 379  2293189     38     False                 False  380
#
#              kickoff_time  minutes  provisional_start_time  started  team_a  \
# 0    2022-08-05T19:00:00Z       90                   False     True       1
# 1    2022-08-06T11:30:00Z       90                   False     True      12
# ...

# %%
dataset = merged_understat_and_fpl([], False)
# Out:
# C:\Users\user\Desktop\FPL_ML\data_prep.py:75: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   fpl_data = pd.read_csv('fpl_players.csv')
# HMS        Unnamed: 0 season           name position team_x  assists  bonus  bps  \
# 69             69   2016  Heung-Min Son      MID    NaN        0      0    0
# 262           262   2016  Heung-Min Son      MID    NaN        0      0    4
# 468           468   2016  Heung-Min Son      MID    NaN        0      0    8
# 674           674   2016  Heung-Min Son      MID    NaN        2      0   19
# 881           881   2016  Heung-Min Son      MID    NaN        0      0    2
# ...           ...    ...            ...      ...    ...      ...    ...  ...
# 95436       95436   2021  Heung-Min Son      MID  Spurs        0      0   14
# 96194       96194   2021  Heung-Min Son      MID  Spurs        1      3   58
# 97424       97424   2021  Heung-Min Son      MID  Spurs        0      0   25
# ...
